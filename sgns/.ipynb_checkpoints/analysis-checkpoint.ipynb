# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
#from collections import Counter

# %%
file_path = Path("dwtch_results.csv")

# %%
df = pd.read_csv(file_path, sep=";", index_col=0)

# %%
df
# Out:
#                 frq2004  frq2005  frq2006  frq2007  frq2008  frq2009  \
# att             97400.0  99526.0  98762.0  97083.0  98499.0  97225.0
# det             79026.0  85296.0  82918.0  81550.0  83997.0  83708.0
# är              70956.0  75735.0  75740.0  76980.0  78461.0  77925.0
# och             65916.0  68760.0  69664.0  70406.0  70639.0  70337.0
# som             60568.0  60950.0  60856.0  60847.0  60890.0  61336.0
# ...                 ...      ...      ...      ...      ...      ...
# lif                 5.0      NaN      NaN      NaN      NaN      NaN
# brommaskolorna      5.0      NaN      NaN      NaN      NaN      NaN
# språktestet         5.0      NaN      NaN      NaN      NaN      NaN
# lovdagar            5.0      NaN      NaN      NaN      NaN      NaN
# möp                 5.0      NaN      NaN      NaN      NaN      NaN
#
#                  frq2010   frq2011   frq2012   frq2013  ...  rsim_2004:2005  \
# att             101378.0  100638.0  103579.0  103715.0  ...        0.592157
# det              86731.0   86465.0   87003.0   87504.0  ...       -1.971088
# är               80669.0   81784.0   83019.0   82689.0  ...        0.452267
# och              73676.0   74699.0   76127.0   76901.0  ...       -0.914725
# som              63021.0   64125.0   65773.0   66585.0  ...        0.452267
# ...                  ...       ...       ...       ...  ...             ...
# lif                  NaN       NaN       NaN       NaN  ...             NaN
# brommaskolorna       NaN       NaN       NaN       NaN  ...             NaN
# språktestet          NaN       NaN       NaN       NaN  ...             NaN
# lovdagar             NaN       NaN       NaN       NaN  ...             NaN
# möp                  NaN       NaN       NaN       NaN  ...             NaN
#
#                 rsim_2005:2006  rsim_2006:2007  rsim_2007:2008  \
# att                   0.703526        0.862924        0.301511
# det                  -0.541083       -2.843776       -0.192308
# är                    0.738549        0.452267        0.452267
# och                   0.646312       -2.035064       -0.568679
# som                        NaN        0.560968        0.818182
# ...                        ...             ...             ...
# lif                        NaN             NaN             NaN
# brommaskolorna             NaN             NaN             NaN
# språktestet                NaN             NaN             NaN
# lovdagar                   NaN             NaN             NaN
# möp                        NaN             NaN             NaN
#
#                 rsim_2008:2009  rsim_2009:2010  rsim_2010:2011  \
# att                   0.545455        0.301511             NaN
# det                  -0.183872       -1.714984       -1.529039
# är                    0.738549        0.301511        0.592157
# och                  -1.840084       -3.231827        0.883636
# som                   0.301511        0.452267        0.545455
# ...                        ...             ...             ...
# lif                        NaN             NaN             NaN
# brommaskolorna             NaN             NaN             NaN
# språktestet                NaN             NaN             NaN
# lovdagar                   NaN             NaN             NaN
# möp                        NaN             NaN             NaN
#
#                 rsim_2011:2012  rsim_2012:2013  rsim_2013:2014
# att                   0.738549        0.592157        0.545455
# det                   0.444682       -1.680547       -0.111873
# är                    0.301511        0.301511        0.904534
# och                   1.530147        0.395339       -0.674248
# som                   0.423793        0.452267        0.423793
# ...                        ...             ...             ...
# lif                        NaN             NaN             NaN
# brommaskolorna             NaN             NaN             NaN
# språktestet                NaN             NaN             NaN
# lovdagar                   NaN             NaN             NaN
# möp                        NaN             NaN             NaN
#
# [28681 rows x 101 columns]

# %%
df.describe()
# Out:
#             frq2004       frq2005       frq2006       frq2007      frq2008  \
# count  28681.000000  19992.000000  19249.000000  19350.000000  18670.00000
# mean      99.194449    136.276160    139.496701    138.957519    143.59143
# std     1364.236090   1676.068311   1695.184401   1682.987651   1733.44091
# min        5.000000      5.000000      5.000000      5.000000      5.00000
# 25%        7.000000      9.000000      9.000000      9.000000      9.00000
# 50%       12.000000     16.000000     16.000000     16.000000     16.00000
# 75%       29.000000     41.000000     42.000000     42.000000     42.00000
# max    97400.000000  99526.000000  98762.000000  97083.000000  98499.00000
#
#             frq2009        frq2010        frq2011        frq2012  \
# count  18576.000000   18328.000000   18428.000000   18474.000000
# mean     144.267926     150.408392     149.531203     151.360182
# std     1734.233110    1804.724038    1799.655341    1828.141309
# min        5.000000       5.000000       5.000000       5.000000
# 25%        9.000000       9.000000       9.000000       9.000000
# 50%       17.000000      17.000000      17.000000      17.000000
# 75%       42.000000      44.000000      44.000000      44.000000
# max    97225.000000  101378.000000  100638.000000  103579.000000
#
#              frq2013  ...  rsim_2004:2005  rsim_2005:2006  rsim_2006:2007  \
# count   18379.000000  ...    1.998700e+04    1.727800e+04    1.704900e+04
# mean      152.101638  ...            -inf            -inf            -inf
# std      1834.835287  ...             NaN             NaN             NaN
# min         5.000000  ...            -inf            -inf            -inf
# 25%         9.000000  ...   -9.138463e-01   -9.168406e-01   -6.108053e-01
# 50%        17.000000  ...    4.390108e-01    4.522670e-01    5.269313e-01
# 75%        44.000000  ...    8.657418e-01    8.790986e-01    8.787416e-01
# max    103715.000000  ...    2.180492e+01    2.331363e+01    2.464402e+01
#
#        rsim_2007:2008  rsim_2008:2009  rsim_2009:2010  rsim_2010:2011  \
# count    1.691800e+04    1.662600e+04    1.648600e+04    1.640000e+04
# mean             -inf            -inf            -inf            -inf
# std               NaN             NaN             NaN             NaN
# min              -inf            -inf            -inf            -inf
# 25%     -3.315271e-01   -1.943058e-01   -9.470814e-02    8.060155e-03
# 50%      5.672379e-01    5.742073e-01    5.802638e-01    5.864594e-01
# 75%      8.834687e-01    8.844077e-01    8.871176e-01    8.904657e-01
# max      2.274472e+01    2.673681e+01    2.171372e+01    2.280176e+01
#
#        rsim_2011:2012  rsim_2012:2013  rsim_2013:2014
# count    1.657000e+04    1.653400e+04    1.642900e+04
# mean             -inf            -inf            -inf
# std               NaN             NaN             NaN
# min              -inf            -inf            -inf
# 25%      6.231961e-02    1.134879e-01    1.739330e-01
# 50%      5.892931e-01    5.908068e-01    6.083735e-01
# 75%      8.902996e-01    8.891581e-01    8.916032e-01
# max      2.200963e+01    2.224007e+01    2.310680e+01
#
# [8 rows x 101 columns]

# %%
list(df.columns)
# Out:
# ['frq2004',
#  'frq2005',
#  'frq2006',
#  'frq2007',
#  'frq2008',
#  'frq2009',
#  'frq2010',
#  'frq2011',
#  'frq2012',
#  'frq2013',
#  'frq2014',
#  'diff_2004:2005',
#  'diff_2005:2006',
#  'diff_2006:2007',
#  'diff_2007:2008',
#  'diff_2008:2009',
#  'diff_2009:2010',
#  'diff_2010:2011',
#  'diff_2011:2012',
#  'diff_2012:2013',
#  'diff_2013:2014',
#  'gch_2010:2011',
#  'gch_2013:2014',
#  'gch_2008:2009',
#  'gch_2009:2010',
#  'gch_2007:2008',
#  'gch_2005:2006',
#  'gch_2012:2013',
#  'gch_2006:2007',
#  'gch_2011:2012',
#  'gch_2004:2005',
#  'mccc_2004:2005',
#  'stdc_2004:2005',
#  'mccc_2005:2006',
#  'stdc_2005:2006',
#  'mccc_2006:2007',
#  'stdc_2006:2007',
#  'mccc_2007:2008',
#  'stdc_2007:2008',
#  'mccc_2008:2009',
#  'stdc_2008:2009',
#  'mccc_2009:2010',
#  'stdc_2009:2010',
#  'mccc_2010:2011',
#  'stdc_2010:2011',
#  'mccc_2011:2012',
#  'stdc_2011:2012',
#  'mccc_2012:2013',
#  'stdc_2012:2013',
#  'mccc_2013:2014',
#  'stdc_2013:2014',
#  'rch_2004:2005',
#  'rch_2005:2006',
#  'rch_2006:2007',
#  'rch_2007:2008',
#  'rch_2008:2009',
#  'rch_2009:2010',
#  'rch_2010:2011',
#  'rch_2011:2012',
#  'rch_2012:2013',
#  'rch_2013:2014',
#  'gsim_2010:2011',
#  'gsim_2013:2014',
#  'gsim_2008:2009',
#  'gsim_2009:2010',
#  'gsim_2007:2008',
#  'gsim_2005:2006',
#  'gsim_2012:2013',
#  'gsim_2006:2007',
#  'gsim_2011:2012',
#  'gsim_2004:2005',
#  'mcsim_2004:2005',
#  'stdsim_2004:2005',
#  'mcsim_2005:2006',
#  'stdsim_2005:2006',
#  'mcsim_2006:2007',
#  'stdsim_2006:2007',
#  'mcsim_2007:2008',
#  'stdsim_2007:2008',
#  'mcsim_2008:2009',
#  'stdsim_2008:2009',
#  'mcsim_2009:2010',
#  'stdsim_2009:2010',
#  'mcsim_2010:2011',
#  'stdsim_2010:2011',
#  'mcsim_2011:2012',
#  'stdsim_2011:2012',
#  'mcsim_2012:2013',
#  'stdsim_2012:2013',
#  'mcsim_2013:2014',
#  'stdsim_2013:2014',
#  'rsim_2004:2005',
#  'rsim_2005:2006',
#  'rsim_2006:2007',
#  'rsim_2007:2008',
#  'rsim_2008:2009',
#  'rsim_2009:2010',
#  'rsim_2010:2011',
#  'rsim_2011:2012',
#  'rsim_2012:2013',
#  'rsim_2013:2014']

# %%
def jaccard(a, b):
    return len(a.intersection(b)) / len(a.union(b))

# %%
def q_show(var, k=100):
    
    ser = [(col, set(df[col].sort_values(ascending=False)[:k].index)) for col in df.columns if col.startswith(var)]
    
    for i, (col, s) in enumerate(ser):
        if i > 0:
            jac = round(jaccard(s, ser[i-1][-1]), 2)
        else:
            jac = None
        
        print()
        print(col, "jaccard =", jac)
        print(s)

# %%
#q_show("rch")
#q_show("rsim")
#q_show("gch")
#q_show("gsim")

# %%
dwt = [w for w in df.index if w.startswith("V1") or w.startswith("N1")]
dwt
# Out:
# ['V1_berika', 'N1_kulturberikare']

# %%
def change_show(var, targets, th=4.781):
    for w in targets:
        for col in [col for col in df.columns if col.startswith(var)]:
            change = df.loc[w][col]
            print(col, w, round(change, 3), change > th)

# %%
change_show("rch", dwt)
# Out:
# rch_2004:2005 V1_berika 0.911 False
# rch_2005:2006 V1_berika -1.728 False
# rch_2006:2007 V1_berika 1.911 False
# rch_2007:2008 V1_berika -0.592 False
# rch_2008:2009 V1_berika 0.02 False
# rch_2009:2010 V1_berika -2.641 False
# rch_2010:2011 V1_berika -0.731 False
# rch_2011:2012 V1_berika -0.302 False
# rch_2012:2013 V1_berika -1.377 False
# rch_2013:2014 V1_berika -0.449 False
# rch_2004:2005 N1_kulturberikare -0.302 False
# rch_2005:2006 N1_kulturberikare 1.097 False
# rch_2006:2007 N1_kulturberikare -0.733 False
# rch_2007:2008 N1_kulturberikare 1.006 False
# rch_2008:2009 N1_kulturberikare -1.096 False
# rch_2009:2010 N1_kulturberikare 1.271 False
# rch_2010:2011 N1_kulturberikare 0.208 False
# rch_2011:2012 N1_kulturberikare -0.293 False
# rch_2012:2013 N1_kulturberikare -1.1 False
# rch_2013:2014 N1_kulturberikare -0.722 False

# %%
change_show("rsim", dwt, th=0.5)
# Out:
# rsim_2004:2005 V1_berika -0.914 False
# rsim_2005:2006 V1_berika 1.549 True
# rsim_2006:2007 V1_berika -3.181 False
# rsim_2007:2008 V1_berika 0.591 True
# rsim_2008:2009 V1_berika 0.298 False
# rsim_2009:2010 V1_berika 2.48 True
# rsim_2010:2011 V1_berika 0.711 True
# rsim_2011:2012 V1_berika 0.302 False
# rsim_2012:2013 V1_berika 1.363 True
# rsim_2013:2014 V1_berika 0.438 False
# rsim_2004:2005 N1_kulturberikare 0.302 False
# rsim_2005:2006 N1_kulturberikare -1.256 False
# rsim_2006:2007 N1_kulturberikare 0.723 True
# rsim_2007:2008 N1_kulturberikare -1.597 False
# rsim_2008:2009 N1_kulturberikare 1.067 True
# rsim_2009:2010 N1_kulturberikare -1.174 False
# rsim_2010:2011 N1_kulturberikare 0.234 False
# rsim_2011:2012 N1_kulturberikare 0.742 True
# rsim_2012:2013 N1_kulturberikare 1.077 True
# rsim_2013:2014 N1_kulturberikare 0.684 True

# %%
change_show("gch", dwt)
# Out:
# gch_2010:2011 V1_berika 0.0 False
# gch_2013:2014 V1_berika 0.0 False
# gch_2008:2009 V1_berika 0.181 False
# gch_2009:2010 V1_berika 0.0 False
# gch_2007:2008 V1_berika 0.0 False
# gch_2005:2006 V1_berika 0.0 False
# gch_2012:2013 V1_berika 0.0 False
# gch_2006:2007 V1_berika 0.289 False
# gch_2011:2012 V1_berika 0.0 False
# gch_2004:2005 V1_berika 0.181 False
# gch_2010:2011 N1_kulturberikare 0.113 False
# gch_2013:2014 N1_kulturberikare 0.0 False
# gch_2008:2009 N1_kulturberikare 0.0 False
# gch_2009:2010 N1_kulturberikare 0.206 False
# gch_2007:2008 N1_kulturberikare 0.27 False
# gch_2005:2006 N1_kulturberikare 0.237 False
# gch_2012:2013 N1_kulturberikare 0.0 False
# gch_2006:2007 N1_kulturberikare 0.0 False
# gch_2011:2012 N1_kulturberikare 0.114 False
# gch_2004:2005 N1_kulturberikare 0.0 False

# %%
change_show("gsim", dwt)
# Out:
# gsim_2010:2011 V1_berika 1.0 False
# gsim_2013:2014 V1_berika 1.0 False
# gsim_2008:2009 V1_berika 0.843 False
# gsim_2009:2010 V1_berika 1.0 False
# gsim_2007:2008 V1_berika 1.0 False
# gsim_2005:2006 V1_berika 1.0 False
# gsim_2012:2013 V1_berika 1.0 False
# gsim_2006:2007 V1_berika 0.614 False
# gsim_2011:2012 V1_berika 1.0 False
# gsim_2004:2005 V1_berika 0.843 False
# gsim_2010:2011 N1_kulturberikare 0.937 False
# gsim_2013:2014 N1_kulturberikare 1.0 False
# gsim_2008:2009 N1_kulturberikare 1.0 False
# gsim_2009:2010 N1_kulturberikare 0.798 False
# gsim_2007:2008 N1_kulturberikare 0.662 False
# gsim_2005:2006 N1_kulturberikare 0.735 False
# gsim_2012:2013 N1_kulturberikare 1.0 False
# gsim_2006:2007 N1_kulturberikare 1.0 False
# gsim_2011:2012 N1_kulturberikare 0.936 False
# gsim_2004:2005 N1_kulturberikare 1.0 False
