# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
#from collections import Counter

# %%
file_path = Path("../../dw_results/fb_pol-yearly-radical3.csv")
#file_path = Path("fb_pol-yearly-radical3.csv")

# %%
df = pd.read_csv(file_path, sep=";", index_col=0)

# %%
df
# Out:
#             frq2000  frq2001  frq2002  frq2003   frq2004   frq2005   frq2006  \
# att         42105.0  25557.0  32545.0  24739.0  113352.0  163299.0  311092.0
# och         35133.0  23030.0  24259.0  17270.0   76585.0  112181.0  218930.0
# det         33806.0  20428.0  25624.0  19513.0   91891.0  139462.0  261809.0
# är          33621.0  20688.0  24205.0  18151.0   82483.0  123434.0  238735.0
# som         27860.0  18475.0  21468.0  15508.0   70632.0   99593.0  191680.0
# ...             ...      ...      ...      ...       ...       ...       ...
# whimsical       5.0      NaN      NaN      NaN       NaN       NaN       NaN
# kalven          5.0      NaN      NaN      NaN       NaN       NaN       NaN
# dbfare          5.0      NaN      NaN      NaN       NaN       NaN       NaN
# filosofiom      5.0      NaN      NaN      NaN       NaN       NaN       NaN
# fuckoff         5.0      NaN      NaN      NaN       NaN       NaN       NaN
#
#              frq2007   frq2008   frq2009  ...  rsim_2012:2013  rsim_2013:2014  \
# att         429217.0  774386.0  892858.0  ...       -1.381699       -1.809068
# och         312084.0  557594.0  648163.0  ...       -9.740222       -5.347180
# det         362186.0  662882.0  772296.0  ...       -5.068088       -2.141684
# är          340995.0  618666.0  719012.0  ...        0.452267        0.592157
# som         270995.0  481803.0  562122.0  ...        0.301511        0.904534
# ...              ...       ...       ...  ...             ...             ...
# whimsical        NaN       NaN       NaN  ...             NaN             NaN
# kalven           NaN       NaN       NaN  ...             NaN             NaN
# dbfare           NaN       5.0       NaN  ...             NaN             NaN
# filosofiom       NaN       NaN       NaN  ...             NaN             NaN
# fuckoff          NaN       NaN       NaN  ...             NaN             NaN
#
#             rsim_2014:2015  rsim_2015:2016  rsim_2016:2017  rsim_2017:2018  \
# att              -1.107823       -2.713602   -1.381699e+00       -1.381699
# och              -3.543285       -2.741451    8.230798e+00       -4.522980
# det              -3.330784       -2.330089   -5.380988e+00       -2.857146
# är                0.703526        0.452267   -5.498581e+06        0.452267
# som               0.592157        0.301511             NaN        0.738549
# ...                    ...             ...             ...             ...
# whimsical              NaN             NaN             NaN             NaN
# kalven                 NaN             NaN             NaN             NaN
# dbfare                 NaN             NaN             NaN             NaN
# filosofiom             NaN             NaN             NaN             NaN
# fuckoff                NaN             NaN             NaN             NaN
#
#             rsim_2018:2019  rsim_2019:2020  rsim_2020:2021  rsim_2021:2022
# att              -0.904534       -1.381699       -0.818182       -0.347441
# och              -5.093037       -1.583638       -1.332101       -7.591886
# det              -2.920365       -0.154104       -3.689925       -6.736829
# är                0.545455        0.592157        0.452267        0.301511
# som               0.592157        0.301511        0.452267        0.301511
# ...                    ...             ...             ...             ...
# whimsical              NaN             NaN             NaN             NaN
# kalven                 NaN             NaN             NaN             NaN
# dbfare                 NaN             NaN             NaN             NaN
# filosofiom             NaN             NaN             NaN             NaN
# fuckoff                NaN             NaN             NaN             NaN
#
# [18291 rows x 229 columns]

# %%
df.describe()
# Out:
#             frq2000       frq2001       frq2002       frq2003        frq2004  \
# count  18291.000000   9980.000000  10357.000000   8440.000000   14277.000000
# mean      77.464491     85.463928     91.265135     78.596209     218.641241
# std      802.851976    694.379721    778.211794    635.044132    2245.233015
# min        5.000000      5.000000      5.000000      5.000000       5.000000
# 25%        7.000000      8.000000      8.000000      7.000000      14.000000
# 50%       11.000000     14.000000     15.000000     13.000000      30.000000
# 75%       26.000000     33.000000     34.000000     30.000000      74.000000
# max    42105.000000  25557.000000  32545.000000  24739.000000  113352.000000
#
#              frq2005        frq2006        frq2007        frq2008  \
# count   14746.000000   15664.000000   16151.000000   16502.000000
# mean      293.609453     523.736083     717.957216    1251.518664
# std      3189.595517    5910.223309    8162.089208   14540.930576
# min         5.000000       5.000000       5.000000       5.000000
# 25%        16.000000      23.000000      31.000000      47.000000
# 50%        35.000000      59.000000      80.000000     129.000000
# 75%        94.000000     163.000000     222.000000     376.750000
# max    163299.000000  311092.000000  429217.000000  774386.000000
#
#              frq2009  ...  rsim_2012:2013  rsim_2013:2014  rsim_2014:2015  \
# count   16620.000000  ...    1.598100e+04    1.588700e+04    1.588500e+04
# mean     1447.026775  ...            -inf            -inf            -inf
# std     16855.121494  ...             NaN             NaN             NaN
# min         5.000000  ...            -inf            -inf            -inf
# 25%        53.000000  ...   -6.736742e-01   -6.493986e-01   -6.347136e-01
# 50%       149.000000  ...    4.175834e-01    4.436178e-01    4.498466e-01
# 75%       432.000000  ...    8.990740e-01    8.989932e-01    8.989256e-01
# max    892858.000000  ...    2.111258e+01    2.428172e+01    2.458746e+01
#
#        rsim_2015:2016  rsim_2016:2017  rsim_2017:2018  rsim_2018:2019  \
# count    1.586900e+04    1.575200e+04    1.571700e+04    1.571900e+04
# mean             -inf            -inf            -inf            -inf
# std               NaN             NaN             NaN             NaN
# min              -inf            -inf            -inf            -inf
# 25%     -5.983182e-01   -4.766412e-01   -5.310688e-01   -4.573082e-01
# 50%      4.502403e-01    4.522670e-01    4.518986e-01    4.522670e-01
# 75%      8.995019e-01    9.002554e-01    8.992699e-01    8.996546e-01
# max      3.288866e+01    2.256029e+01    2.203136e+01    2.459298e+01
#
#        rsim_2019:2020  rsim_2020:2021  rsim_2021:2022
# count    1.562300e+04    1.557000e+04    1.563600e+04
# mean             -inf            -inf            -inf
# std               NaN             NaN             NaN
# min              -inf            -inf            -inf
# 25%     -5.125945e-01   -5.284434e-01   -7.476927e-01
# 50%      4.522110e-01    4.522651e-01    4.481579e-01
# 75%      8.988976e-01    8.995076e-01    8.992443e-01
# max      2.104461e+01    3.269971e+01    2.485344e+01
#
# [8 rows x 229 columns]

# %%
list(df.columns)
# Out:
# ['frq2000',
#  'frq2001',
#  'frq2002',
#  'frq2003',
#  'frq2004',
#  'frq2005',
#  'frq2006',
#  'frq2007',
#  'frq2008',
#  'frq2009',
#  'frq2010',
#  'frq2011',
#  'frq2012',
#  'frq2013',
#  'frq2014',
#  'frq2015',
#  'frq2016',
#  'frq2017',
#  'frq2018',
#  'frq2019',
#  'frq2020',
#  'frq2021',
#  'frq2022',
#  'diff_2000:2001',
#  'diff_2001:2002',
#  'diff_2002:2003',
#  'diff_2003:2004',
#  'diff_2004:2005',
#  'diff_2005:2006',
#  'diff_2006:2007',
#  'diff_2007:2008',
#  'diff_2008:2009',
#  'diff_2009:2010',
#  'diff_2010:2011',
#  'diff_2011:2012',
#  'diff_2012:2013',
#  'diff_2013:2014',
#  'diff_2014:2015',
#  'diff_2015:2016',
#  'diff_2016:2017',
#  'diff_2017:2018',
#  'diff_2018:2019',
#  'diff_2019:2020',
#  'diff_2020:2021',
#  'diff_2021:2022',
#  'gch_2003:2007',
#  'gch_2007:2011',
#  'gch_2011:2015',
#  'gch_2015:2019',
#  'gch_2000:2001',
#  'gch_2001:2002',
#  'gch_2002:2003',
#  'gch_2003:2004',
#  'gch_2004:2005',
#  'gch_2005:2006',
#  'gch_2006:2007',
#  'gch_2007:2008',
#  'gch_2008:2009',
#  'gch_2009:2010',
#  'gch_2010:2011',
#  'gch_2011:2012',
#  'gch_2012:2013',
#  'gch_2013:2014',
#  'gch_2014:2015',
#  'gch_2015:2016',
#  'gch_2016:2017',
#  'gch_2017:2018',
#  'gch_2018:2019',
#  'gch_2019:2020',
#  'gch_2020:2021',
#  'gch_2021:2022',
#  'mccc_2000:2001',
#  'stdc_2000:2001',
#  'mccc_2001:2002',
#  'stdc_2001:2002',
#  'mccc_2002:2003',
#  'stdc_2002:2003',
#  'mccc_2003:2004',
#  'stdc_2003:2004',
#  'mccc_2004:2005',
#  'stdc_2004:2005',
#  'mccc_2005:2006',
#  'stdc_2005:2006',
#  'mccc_2006:2007',
#  'stdc_2006:2007',
#  'mccc_2007:2008',
#  'stdc_2007:2008',
#  'mccc_2008:2009',
#  'stdc_2008:2009',
#  'mccc_2009:2010',
#  'stdc_2009:2010',
#  'mccc_2010:2011',
#  'stdc_2010:2011',
#  'mccc_2011:2012',
#  'stdc_2011:2012',
#  'mccc_2012:2013',
#  'stdc_2012:2013',
#  'mccc_2013:2014',
#  'stdc_2013:2014',
#  'mccc_2014:2015',
#  'stdc_2014:2015',
#  'mccc_2015:2016',
#  'stdc_2015:2016',
#  'mccc_2016:2017',
#  'stdc_2016:2017',
#  'mccc_2017:2018',
#  'stdc_2017:2018',
#  'mccc_2018:2019',
#  'stdc_2018:2019',
#  'mccc_2019:2020',
#  'stdc_2019:2020',
#  'mccc_2020:2021',
#  'stdc_2020:2021',
#  'mccc_2021:2022',
#  'stdc_2021:2022',
#  'rch_2000:2001',
#  'rch_2001:2002',
#  'rch_2002:2003',
#  'rch_2003:2004',
#  'rch_2004:2005',
#  'rch_2005:2006',
#  'rch_2006:2007',
#  'rch_2007:2008',
#  'rch_2008:2009',
#  'rch_2009:2010',
#  'rch_2010:2011',
#  'rch_2011:2012',
#  'rch_2012:2013',
#  'rch_2013:2014',
#  'rch_2014:2015',
#  'rch_2015:2016',
#  'rch_2016:2017',
#  'rch_2017:2018',
#  'rch_2018:2019',
#  'rch_2019:2020',
#  'rch_2020:2021',
#  'rch_2021:2022',
#  'gsim_2003:2007',
#  'gsim_2007:2011',
#  'gsim_2011:2015',
#  'gsim_2015:2019',
#  'gsim_2000:2001',
#  'gsim_2001:2002',
#  'gsim_2002:2003',
#  'gsim_2003:2004',
#  'gsim_2004:2005',
#  'gsim_2005:2006',
#  'gsim_2006:2007',
#  'gsim_2007:2008',
#  'gsim_2008:2009',
#  'gsim_2009:2010',
#  'gsim_2010:2011',
#  'gsim_2011:2012',
#  'gsim_2012:2013',
#  'gsim_2013:2014',
#  'gsim_2014:2015',
#  'gsim_2015:2016',
#  'gsim_2016:2017',
#  'gsim_2017:2018',
#  'gsim_2018:2019',
#  'gsim_2019:2020',
#  'gsim_2020:2021',
#  'gsim_2021:2022',
#  'mcsim_2000:2001',
#  'stdsim_2000:2001',
#  'mcsim_2001:2002',
#  'stdsim_2001:2002',
#  'mcsim_2002:2003',
#  'stdsim_2002:2003',
#  'mcsim_2003:2004',
#  'stdsim_2003:2004',
#  'mcsim_2004:2005',
#  'stdsim_2004:2005',
#  'mcsim_2005:2006',
#  'stdsim_2005:2006',
#  'mcsim_2006:2007',
#  'stdsim_2006:2007',
#  'mcsim_2007:2008',
#  'stdsim_2007:2008',
#  'mcsim_2008:2009',
#  'stdsim_2008:2009',
#  'mcsim_2009:2010',
#  'stdsim_2009:2010',
#  'mcsim_2010:2011',
#  'stdsim_2010:2011',
#  'mcsim_2011:2012',
#  'stdsim_2011:2012',
#  'mcsim_2012:2013',
#  'stdsim_2012:2013',
#  'mcsim_2013:2014',
#  'stdsim_2013:2014',
#  'mcsim_2014:2015',
#  'stdsim_2014:2015',
#  'mcsim_2015:2016',
#  'stdsim_2015:2016',
#  'mcsim_2016:2017',
#  'stdsim_2016:2017',
#  'mcsim_2017:2018',
#  'stdsim_2017:2018',
#  'mcsim_2018:2019',
#  'stdsim_2018:2019',
#  'mcsim_2019:2020',
#  'stdsim_2019:2020',
#  'mcsim_2020:2021',
#  'stdsim_2020:2021',
#  'mcsim_2021:2022',
#  'stdsim_2021:2022',
#  'rsim_2000:2001',
#  'rsim_2001:2002',
#  'rsim_2002:2003',
#  'rsim_2003:2004',
#  'rsim_2004:2005',
#  'rsim_2005:2006',
#  'rsim_2006:2007',
#  'rsim_2007:2008',
#  'rsim_2008:2009',
#  'rsim_2009:2010',
#  'rsim_2010:2011',
#  'rsim_2011:2012',
#  'rsim_2012:2013',
#  'rsim_2013:2014',
#  'rsim_2014:2015',
#  'rsim_2015:2016',
#  'rsim_2016:2017',
#  'rsim_2017:2018',
#  'rsim_2018:2019',
#  'rsim_2019:2020',
#  'rsim_2020:2021',
#  'rsim_2021:2022']

# %%
def jaccard(a, b):
    return len(a.intersection(b)) / len(a.union(b))

# %%
def q_show(var, k=100):
    
    ser = [(col, set(df[col].sort_values(ascending=False)[:k].index)) for col in df.columns if col.startswith(var)]
    
    for i, (col, s) in enumerate(ser):
        if i > 0:
            jac = round(jaccard(s, ser[i-1][-1]), 2)
        else:
            jac = None
        
        print()
        print(col, "jaccard =", jac)
        print(s)

# %%
#q_show("rch")
#q_show("rsim")
#q_show("gch")
#q_show("gsim")

# %%
df.index
# Out:
# Index(['att', 'och', 'det', 'är', 'som', 'i', 'en', 'inte', 'på', 'för',
#        ...
#        'nukelära', 'sms', 'republikan', 'monarkism', 'eco', 'whimsical',
#        'kalven', 'dbfare', 'filosofiom', 'fuckoff'],
#       dtype='object', length=18291)

# %%
dwt = [w for w in [str(token) for token in df.index] if w.startswith("V1") or w.startswith("N1")]
dwt.sort()
dwt
# Out:
# ['N1_berikare',
#  'N1_förortsgäng',
#  'N1_kulturberikare',
#  'V1_berika',
#  'V1_kulturberika']

# %%
df["berikats"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'berikats'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-db137f45a5a0> in <module>
# ----> 1 df["berikats"]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'berikats'

# %%
def change_show(var, targets, th=4.781):
    for w in targets:
        for col in [col for col in df.columns if col.startswith(var)]:
            change = df.loc[w][col]
            print(col, w, round(change, 3), change > th)

# %%
change_show("rch", dwt)

# %%
change_show("rsim", dwt, th=0.5)

# %%
change_show("gch", dwt)

# %%
change_show("gsim", dwt)
