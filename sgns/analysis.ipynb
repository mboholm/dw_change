# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import re
from util import load_metric
from scipy.stats import spearmanr, pearsonr
#from collections import Counter

# %% [markdown]
# ## Functions

# %%
def jaccard(a, b):
    return len(a.intersection(b)) / len(a.union(b))

# %%
def q_show(df, var, k = 40, as_table = False):
    # Note: as_table only for transition variables!
    
    ser = [(col, list(df[col].sort_values(ascending=False)[:k].index)) for col in df.columns if col.startswith(var)]
    
    for i, (col, s) in enumerate(ser):
        if i > 0:
            jac = round(jaccard(set(s), ser[i-1][-1]), 2)
        else:
            jac = None
        
        print()
        print(col, "jaccard =", jac)
        
        if as_table == False:
            print(s)
        else:
            trans  = col.split("_")[-1]
            ti, tj = tuple(trans.split(":"))
            table  = [] 
            for word in s:
                v    = df.loc[word][col]
                f_ti = int(df.loc[word][f"frq_{ti}"])
                f_tj = int(df.loc[word][f"frq_{tj}"])
                gch  = df.loc[word][f"gch_{trans}"]
                m    = df.loc[word][f"mccc_{trans}"]
                std  = df.loc[word][f"stdc_{trans}"]
                columns = ["Word", var.upper(), "n_i", "n_j", "GCH", "Mctrl", "Sctrl"]
                table.append([word, v, f_ti, f_tj, gch, m, std])
            print(pd.DataFrame(table, columns=columns))

# %%
def change_show(df, var, targets, th=4.781):

    for col in sorted([col for col in df.columns if col.startswith(var)]):
        trans  = col.split("_")[-1]
        ti, tj = tuple(trans.split(":"))
        table  = [] 
        
        for word in targets:
            v    = df.loc[word][col]
            f_ti = int(df.loc[word][f"frq_{ti}"])
            f_tj = int(df.loc[word][f"frq_{tj}"])
            
            if th != None:
                if v > th:
                    table.append([word, v, f_ti, f_tj])
            else:
                table.append([word, v, f_ti, f_tj])
        
        columns = ["Word", "Value", f"n_{ti}", f"n_{tj}"]
        if table != []:
            display = pd.DataFrame(table, columns=columns)
            print()
            print(col)
            print(display)

# %%
def read_csv(path):
    return pd.read_csv(path, sep=";", index_col=0)

# %%
def get_dwts(df, path):
    with open(Path(path), "r") as f:
        dwt_roots = [w.strip("\n") for w in f.readlines()]
    dwt_regex = re.compile(f"({'|'.join(dwt_roots)})")    
    dwts = [str(w) for w in df.index if re.search(dwt_regex, str(w)) != None]
    return dwts

# %%
def get_variables(df):
    
    yr_prefix = set()
    tr_prefix = set()
    years = set()
    transitions = set()
    
    for v in df.columns:
        prefix, suffix = tuple(v.split("_"))
        if ":" in suffix:
            tr_prefix.add(prefix)
            transitions.add(suffix)
        else:
            yr_prefix.add(prefix)
            years.add(suffix)
    
    return {"yr_prefix": yr_prefix, 
            "tr_prefix": tr_prefix,
            "years": years,
            "transitions": transitions
           }

# %%
def checker(word, transition, controls_dir, n_ctrl=10, variable="cosine_change"):
    """
    param word
    param transition    tupple of ti and tj 
    param controls_dir  where to find controls
    param variable      "cosine_change" or "cosine_sim"
    """
    
    ti, tj = transition
    basename = Path(controls_dir) / variable 
    
    filenames = [f"{ti}_{tj}_control{n}.txt" for n in range(1, n_ctrl+1)]
    
    values = []
    
    for file in filenames:
        data = load_metric(basename / file)
        value = data[word]
        values.append(value)
        print(file, value)
        
    return values

# %%
def ncd(DATA, CORPUS, VAR, VAL): # No Chnage Detector
#     VAR = "gsim"
#     VAL = 1.0
#     TRANSIITON = "2007:2011"

    corpus = Path(CORPUS)
    transitions = find_transitions(corpus / "vocab")    

    for yi, yj in transitions:
        print()
        print(f"{yi}:{yj}")
        
        A = list(DATA[DATA[f"{VAR}_{yi}:{yj}"] == VAL].index)
        print("No change (A):", len(A))
        B = list(DATA[DATA[f"{VAR}_{yi}:{yj}"] != VAL].index)
        print("Other (B):", len(B))
        # u = list(toypol[toypol[f"{VAR}_2007:2011"] == np.nan].index)
        # print("Undefined (U):", len(u))
        print()
        print("{: <20} {}".format("A", "B"))
        print("{: <20} {}".format("---", "---"))
        for w1, w2 in zip(A[:100], B[:100]):
            print(f"{w1: <20} {w2}")

# %%
def find_transitions(vocabs):
    
    years = [int(file.strip(".txt")) for file in os.listdir(vocabs)]
    years.sort()
    transitions = [(year, years[i]) for i, year in enumerate(years[:-1], start=1)]
    
    return transitions

# %%
def w_overlap_checker(corpus, th_c):
    
    corpus = Path(corpus)
    transitions = find_transitions(corpus / "vocab")
    
    for yi, yj in transitions:
        print()
        print(f"{yi}:{yj}")
        
        voc_a = load_metric(corpus / f"vocab/{yi}.txt")
        voc_b = load_metric(corpus / f"vocab/{yj}.txt")

        voc_a = {w: c for w, c in voc_a.items() if c >= th_c}
        voc_b = {w: c for w, c in voc_b.items() if c >= th_c}
        print(f"{yi}:", len(voc_a))
        print(f"{yj}:", len(voc_b))
        print(f"{yi} and {yj}:", len([w for w in voc_a.keys() if w in voc_b.keys()]))
        print(f"{yi} or {yj}:", len(set(voc_a.keys()).union(set(voc_b.keys()))))
        print(f"{yi} - {yj}:", len(set(voc_a.keys()).difference(set(voc_b.keys()))))

# %%
def correlation(df, var1, var2, corpus, mode=1, metric="pearson"):

    transitions = find_transitions(Path(corpus) / "vocab")

    if mode == 1:
        correlation = df[[f"{var1}_{ti}:{tj}" for ti, tj in transitions]].corrwith(df[[f"{var2}_{ti}:{tj}" for ti, tj in transitions]], axis=1)
    
    if mode == 2:
        table = []
        for w in df.index:
            valid = []
            X = df[[f"{var1}_{ti}:{tj}" for ti, tj in transitions]].loc[w]
            Y = df[[f"{var2}_{ti}:{tj}" for ti, tj in transitions]].loc[w]
            for x, y in zip(X, Y):
                if pd.isna(x):
                    continue
                if pd.isna(y):
                    continue
                valid.append((x, y))
            
            N = len(valid)
            
            if N < 2:
                v = np.nan
                p = np.nan
            else:
                if metric == "pearson":
                    X, Y = zip(*valid)
                    R_data = pearsonr(X, Y)
                    v = R_data.statistic
                    p = R_data.pvalue
                    
#                     print("X", [round(x*100000000, 2) for x in X])
#                     print("Y", [round(y, 2) for y in Y])

                if metric == "spearman":
                    X, Y = zip(*valid)
                    R_data = spearmanr(X, Y)
                    v = R_data.statistic
                    p = R_data.pvalue
                    
            table.append([w, round(v, 2), round(p, 2), N])
        correlation = pd.DataFrame(table, columns=["Word", "Correlation", "p", "N"])
        
    return correlation

# %% [markdown]
# ## Files

# %%
#file_path = Path("../../dw_results/fb_pol-yearly-radical3.csv")
#file_path = Path("fb_pol-yearly-radical3.csv")
results_dir = Path("../../dw_results")

# %%
files = os.listdir(results_dir)
_ = [print(file) for file in files]
# Out:
# fb_pol-yearly-radical3-restricted.csv
# fb_pol-yearly-radical3-full.csv

# %%
dwt_path = "../data/utils/dwts.txt"

# %%
#corpus = Path("/srv/data/gusbohom/root/corpora/toypol/time_bin/radical3/")
corpus = Path("/home/max/Corpora/flashback-pol-time/yearly/fb-pt-radical3")

# %% [markdown]
# ## Q-Show

# %%
df_yearly = read_csv(results_dir / "fb_pol-yearly-radical3-full.csv")

# %%
df_time_bin = read_csv(results_dir / "fb_pol-time_bin-radical3-full.csv")

# %%
toypol = read_csv(Path("../../toypol-time_bin.csv"))

# %% [markdown]
# ### Check

# %% [raw]
# ncd(DATA=df_yearly, CORPUS=corpus, VAR="gsim", VAL=1.0)

# %% [raw]
# w_overlap_checker(corpus=corpus, th_c=100)

# %% [markdown]
# ### Yearly

# %%
q_show(df_yearly, "rch", as_table = True)
# q_show("rsim")
# q_show("gch")
# q_show("gsim")
# Out:
# rch_2000:2001 jaccard = None
#            Word         RCH   n_i   n_j       GCH     Mctrl     Sctrl
# 0      bidragit  235.059543    11    14  0.167895  0.080191  0.000356
# 1   individuell   25.213364    10    11  0.161957  0.122159  0.001505
# 2    avslöjande   22.048312    11    10  0.076490  0.053672  0.000987
# 3             $   21.444180    17    22  0.205694  0.026920  0.007949
# 4     interests   17.946884    12    10  0.034739  0.023519  0.000596
# 5   självkänsla   14.758416    10    10  0.113900  0.100157  0.000888
# 6     gåsfonden   14.398690    13    93  0.227088  0.036601  0.012614
# 7            bo   13.568608   123   225  0.335645  0.080635  0.017919
# 8            re   12.918446    47   367  0.209023  0.078862  0.009607
# 9       gyllene   11.470559    11    10  0.113252  0.079837  0.002778
# 10        about   10.527548    93    44  0.046623  0.023362  0.002107
# 11      element   10.152353   109    35  0.403042  0.173649  0.021543
# 12        björn    9.599879    37  1472  0.289176  0.117116  0.017089
# 13   tillgången    9.377967    10    10  0.103961  0.091681  0.001249
# 14        svara    9.268731   305   493  0.340180  0.140976  0.020492
# 15       tensta    9.212602    12    10  0.206819  0.058929  0.015306
# 16      värdera    9.162200    10    11  0.197169  0.143250  0.005611
# 17          has    9.030096   100   509  0.169943  0.046438  0.013041
# 18     koppling    8.814234    10    10  0.106683  0.062626  0.004766
# 19       anders    8.558508    84   142  0.278942  0.060178  0.024371
# 20     cannabis    8.500967   145   114  0.329677  0.113669  0.024227
# 21       jewish    8.235725   122    84  0.059746  0.037004  0.002633
# 22      patriot    8.115809   129   936  0.256694  0.093963  0.019118
# 23       talmud    7.440938    64    75  0.325084  0.165390  0.020463
# 24      because    7.417777    49    56  0.051537  0.026621  0.003203
# 25         hans    7.310609  1352   985  0.247331  0.128364  0.015516
# 26         does    7.275259    23    10  0.039357  0.019691  0.002577
# 27         case    7.272685    28    39  0.053701  0.028918  0.003249
# 28      nilsson    7.149578    15   112  0.266145  0.076882  0.025240
# 29      himmler    7.072880    63    38  0.242234  0.118278  0.016710
# 30       utgöra    6.868156    35    34  0.217886  0.147805  0.009729
# 23          grannländer   20.202896   767    2044  0.251482  0.163884
# 24           okränkbara   19.968300    27     295  0.287459  0.079155
# 25               kremls   19.313810    75    1549  0.267815  0.168430
# 26            förbanden   19.256451    21     498  0.294534  0.193905
# 27                kreml   19.250487   463    9442  0.251464  0.126110
# 28                lease   19.182370    12     207  0.350507  0.171298
# 29          anfallskrig   19.089727    54    1863  0.279403  0.162315
# 30           ammunition   18.972755   267    3033  0.236348  0.162757
# 31               archer   18.806623    10     545  0.396141  0.193909
# 32               treaty   18.496013    41     458  0.224261  0.099215
# 33               civila   18.246280  1576   18582  0.193560  0.106608
# 34             invasion   17.982366   673   10007  0.230516  0.129853
# 35             ryssarna   17.857791  1351   51792  0.230215  0.106090
# 36         örlogsfartyg   17.797528    10     100  0.288332  0.149960
# 37             djokovic   17.778627    10     304  0.380933  0.179633
# 38   militärstrategiskt   17.773263    11     180  0.316747  0.171665
# 39  vattenförsörjningen   17.690045    10      91  0.315309  0.147960
#
#        Sctrl
# 0   0.000301
# 1   0.000303
# 2   0.005001
# 3   0.002949
# 4   0.002346
# 5   0.003453
# 6   0.006998
# 7   0.004260
# 8   0.005337
# 9   0.008503
# 10  0.007231
# 11  0.003531
# 12  0.007117
# 13  0.003534
# 14  0.005061
# 15  0.006245
# 16  0.004741
# 17  0.005778
# 18  0.007166
# 19  0.005032
# 20  0.004980
# 21  0.006799
# 22  0.007593
# 23  0.004134
# 24  0.009946
# 25  0.004906
# 26  0.004983
# 27  0.006209
# 28  0.008908
# 29  0.005848
# 30  0.003698
# 31  0.010253
# 32  0.006446
# 33  0.004544
# 34  0.005337
# 35  0.006627
# 36  0.007413
# 37  0.010796
# 38  0.007783
# 39  0.009020

# %%
q_show(toypol, "rch", as_table = True)

# %%
q_show(toypol, "gsim", as_table = True)

# %% [markdown]
# ### Time bin

# %%
q_show(df_time_bin, "rch", as_table = True)

# %% [markdown]
# ## Change Show

# %%
df_yearly_dwt = read_csv(results_dir / "fb_pol-yearly-radical3-restricted.csv")

# %%
df_time_bin_dwt = read_csv(results_dir / "fb_pol-time_bin-radical3-restricted.csv")

# %% [markdown]
# ### Yearly

# %%
# change_show(df, var, targets, th=4.781)
change_show(df_yearly_dwt, "rch", get_dwts(df_yearly_dwt, dwt_path))
# Out:
# rch_2006:2007
#                 Word     Value  n_2006  n_2007
# 0  N1_kulturberikare  5.140348      51     255
# 1        N1_berikare  7.390323      14     185
#
# rch_2007:2008
#            Word     Value  n_2007  n_2008
# 0  N1_globalist  9.722278      26     294
#
# rch_2009:2010
#                 Word     Value  n_2009  n_2010
# 0  N1_kulturberikare  8.116137     525     925
#
# rch_2017:2018
#               Word     Value  n_2017  n_2018
# 0  N1_återvandring  11.08269     165    3288
#
# rch_2018:2019
#               Word     Value  n_2018  n_2019
# 0  N1_återvandring  6.600887    3288    1510

# %%
change_show(df_yearly_dwt, "rch", get_dwts(df_yearly_dwt, dwt_path), th=None)
# Out:
# rch_2000:2001
#                               Word     Value  n_2000  n_2001
# 0                        V1_berika  3.112465      41      20
# 1                N1_kulturberikare -1.504499      40      28
# 2                      N1_berikare       NaN      12       0
# 3                  V1_kulturberika       NaN       8       0
# 4                   N1_förortsgäng       NaN       8       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2001:2002
#                               Word     Value  n_2001  n_2002
# 0                        V1_berika  2.056634      20      25
# 1                N1_kulturberikare       NaN      28       9
# 2                      N1_berikare       NaN       0       0
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2002:2003
#                               Word     Value  n_2002  n_2003
# 0                        V1_berika -2.531236      25      14
# 1                N1_kulturberikare       NaN       9       5
# 2                      N1_berikare       NaN       0       8
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2003:2004
#                               Word     Value  n_2003  n_2004
# 0                        V1_berika  3.490279      14      54
# 1                N1_kulturberikare       NaN       5      20
# 2                      N1_berikare       NaN       8       0
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2004:2005
#                               Word     Value  n_2004  n_2005
# 0                        V1_berika  0.202163      54      55
# 1                N1_kulturberikare -3.282184      20      14
# 2                      N1_berikare       NaN       0       0
# 3                  V1_kulturberika       NaN       0       5
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0      18
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2005:2006
#                               Word     Value  n_2005  n_2006
# 0                        V1_berika  0.222672      55     164
# 1                N1_kulturberikare  1.182535      14      51
# 2                      N1_berikare       NaN       0      14
# 3                  V1_kulturberika       NaN       5      11
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist  0.258608      18      28
# 6                  N1_återvandring       NaN       0       9
# 7                  A1_globalistisk       NaN       0       6
# 8                  antiglobalister       NaN       0       6
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2006:2007
#                               Word     Value  n_2006  n_2007
# 0                        V1_berika  1.606794     164     611
# 1                N1_kulturberikare  5.140348      51     255
# 2                      N1_berikare  7.390323      14     185
# 3                  V1_kulturberika  3.735038      11     121
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist -1.718685      28      26
# 6                  N1_återvandring       NaN       9      47
# 7                  A1_globalistisk       NaN       6       7
# 8                  antiglobalister       NaN       6       5
# 9                    V1_återvandra       NaN       0      19
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
# rch_2007:2008
#                               Word     Value  n_2007  n_2008
# 0                        V1_berika  1.556598     611    1356
# 1                N1_kulturberikare  0.416677     255     689
# 2                      N1_berikare  2.030875     185     602
# 3                  V1_kulturberika  0.802065     121     213
# 4                   N1_förortsgäng       NaN       0       7
# 5                     N1_globalist  9.722278      26     294
# 6                  N1_återvandring  4.196763      47     112
# 7                  A1_globalistisk       NaN       7      33
# 8                  antiglobalister       NaN       5       0
# 9                    V1_återvandra -0.404192      19      23
# 10                        oberikat       NaN       0       5
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2008:2009
#                               Word     Value  n_2008  n_2009
# 0                        V1_berika  1.028856    1356    1860
# 1                N1_kulturberikare  1.137954     689     525
# 2                      N1_berikare  2.864684     602     611
# 3                  V1_kulturberika -1.672088     213     247
# 4                   N1_förortsgäng       NaN       7      18
# 5                     N1_globalist -0.865550     294     204
# 6                  N1_återvandring -6.990048     112      51
# 7                  A1_globalistisk -1.560021      33      41
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra -2.096791      23      26
# 10                        oberikat       NaN       5       8
# 11              V1_hjälpa_på_plats       NaN       0      14
# 12                       oberikade       NaN       0      11
# 13                        oberikad       NaN       0       5
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2009:2010
#                               Word     Value  n_2009  n_2010
# 0                        V1_berika -0.252072    1860    1813
# 1                N1_kulturberikare  8.116137     525     925
# 2                      N1_berikare  0.596096     611     441
# 3                  V1_kulturberika -0.412800     247     283
# 4                   N1_förortsgäng       NaN      18       0
# 5                     N1_globalist -1.001501     204     264
# 6                  N1_återvandring  1.328554      51     168
# 7                  A1_globalistisk -4.723134      41      54
# 8                  antiglobalister       NaN       0       6
# 9                    V1_återvandra -0.119337      26      44
# 10                        oberikat       NaN       8       6
# 11              V1_hjälpa_på_plats  3.495977      14      30
# 12                       oberikade -0.890909      11      10
# 13                        oberikad       NaN       5       0
# 14                 N2_återvandrare       NaN       0       7
# 15                   antiglobalist       NaN       0       5
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2010:2011
#                               Word     Value  n_2010  n_2011
# 0                        V1_berika -0.696753    1813    1792
# 1                N1_kulturberikare  1.127005     925     533
# 2                      N1_berikare  0.418116     441     376
# 3                  V1_kulturberika -1.508914     283     249
# 4                   N1_förortsgäng       NaN       0       6
# 5                     N1_globalist  0.436881     264     355
# 6                  N1_återvandring -8.246478     168      51
# 7                  A1_globalistisk  0.006778      54     111
# 8                  antiglobalister       NaN       6       5
# 9                    V1_återvandra -2.564660      44      31
# 10                        oberikat       NaN       6       0
# 11              V1_hjälpa_på_plats -3.094487      30      25
# 12                       oberikade       NaN      10       0
# 13                        oberikad       NaN       0       5
# 14                 N2_återvandrare       NaN       7       0
# 15                   antiglobalist       NaN       5       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2011:2012
#                               Word     Value  n_2011  n_2012
# 0                        V1_berika -0.885508    1792    1515
# 1                N1_kulturberikare -1.205050     533     533
# 2                      N1_berikare -1.800813     376     393
# 3                  V1_kulturberika -2.253837     249     235
# 4                   N1_förortsgäng       NaN       6       9
# 5                     N1_globalist  0.203334     355     737
# 6                  N1_återvandring -0.003662      51     146
# 7                  A1_globalistisk  2.087735     111     215
# 8                  antiglobalister       NaN       5       5
# 9                    V1_återvandra -4.617295      31      37
# 10                        oberikat       NaN       0      10
# 11              V1_hjälpa_på_plats -1.649952      25      41
# 12                       oberikade       NaN       0       9
# 13                        oberikad       NaN       5       6
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       5
# 17  P1_självständig_utrikespolitik       NaN       0       5
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2012:2013
#                               Word     Value  n_2012  n_2013
# 0                        V1_berika  1.428116    1515    1227
# 1                N1_kulturberikare  0.687678     533     401
# 2                      N1_berikare -5.740617     393     237
# 3                  V1_kulturberika -1.295055     235     180
# 4                   N1_förortsgäng       NaN       9       9
# 5                     N1_globalist -0.394851     737     680
# 6                  N1_återvandring -1.447401     146     185
# 7                  A1_globalistisk -1.070616     215     174
# 8                  antiglobalister       NaN       5       0
# 9                    V1_återvandra -1.389685      37      52
# 10                        oberikat       NaN      10       5
# 11              V1_hjälpa_på_plats -3.005501      41      50
# 12                       oberikade       NaN       9       8
# 13                        oberikad       NaN       6       0
# 14                 N2_återvandrare       NaN       0       5
# 15                   antiglobalist       NaN       0       5
# 16                antiglobalistisk       NaN       5       0
# 17  P1_självständig_utrikespolitik       NaN       5      11
# 18            biståndsåtervandring       NaN       0       5
# 19               antiglobalistiska       NaN       0       5
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2013:2014
#                               Word     Value  n_2013  n_2014
# 0                        V1_berika -0.400075    1227    1001
# 1                N1_kulturberikare -2.290237     401     172
# 2                      N1_berikare -2.515295     237     174
# 3                  V1_kulturberika -2.535031     180     101
# 4                   N1_förortsgäng       NaN       9      24
# 5                     N1_globalist -2.777211     680     722
# 6                  N1_återvandring -2.469129     185     157
# 7                  A1_globalistisk -1.241801     174     209
# 8                  antiglobalister       NaN       0      11
# 9                    V1_återvandra -3.035853      52      32
# 10                        oberikat       NaN       5       0
# 11              V1_hjälpa_på_plats -0.497677      50     106
# 12                       oberikade       NaN       8       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       5       5
# 15                   antiglobalist       NaN       5       5
# 16                antiglobalistisk       NaN       0      11
# 17  P1_självständig_utrikespolitik -0.286057      11      10
# 18            biståndsåtervandring       NaN       5       0
# 19               antiglobalistiska       NaN       5      10
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2014:2015
#                               Word     Value  n_2014  n_2015
# 0                        V1_berika  1.363301    1001    1095
# 1                N1_kulturberikare -3.496329     172     128
# 2                      N1_berikare -3.039826     174     198
# 3                  V1_kulturberika -1.415994     101     120
# 4                   N1_förortsgäng -1.436558      24      15
# 5                     N1_globalist -0.840169     722     676
# 6                  N1_återvandring -3.893727     157     136
# 7                  A1_globalistisk -3.165283     209     132
# 8                  antiglobalister       NaN      11       0
# 9                    V1_återvandra -3.578348      32      28
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -0.002356     106     251
# 12                       oberikade       NaN       0       5
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       5       0
# 15                   antiglobalist       NaN       5       7
# 16                antiglobalistisk -1.001030      11      10
# 17  P1_självständig_utrikespolitik       NaN      10       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN      10      10
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
# rch_2015:2016
#                               Word     Value  n_2015  n_2016
# 0                        V1_berika -0.781521    1095    1247
# 1                N1_kulturberikare -0.206462     128     171
# 2                      N1_berikare -2.922248     198     145
# 3                  V1_kulturberika -2.600950     120      98
# 4                   N1_förortsgäng -2.541556      15      12
# 5                     N1_globalist  0.759366     676    1836
# 6                  N1_återvandring -2.478115     136     200
# 7                  A1_globalistisk -0.538985     132     261
# 8                  antiglobalister       NaN       0      14
# 9                    V1_återvandra -3.196311      28      19
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -8.184708     251      65
# 12                       oberikade       NaN       5       0
# 13                        oberikad       NaN       0       6
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       7      19
# 16                antiglobalistisk -2.237120      10      10
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska  0.109796      10      20
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2016:2017
#                               Word     Value  n_2016  n_2017
# 0                        V1_berika  2.582885    1247     769
# 1                N1_kulturberikare -3.912238     171     104
# 2                      N1_berikare -8.029519     145     112
# 3                  V1_kulturberika -5.661943      98      56
# 4                   N1_förortsgäng -7.061690      12      10
# 5                     N1_globalist -1.337408    1836    2458
# 6                  N1_återvandring -2.335478     200     165
# 7                  A1_globalistisk -1.316700     261     420
# 8                  antiglobalister  0.790679      14      25
# 9                    V1_återvandra -4.795469      19      24
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -4.959607      65      61
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       6       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist  0.240317      19      26
# 16                antiglobalistisk -0.285099      10      24
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska -0.985140      20      32
# 20               antiglobalistiskt       NaN       0       9
# 21              vänsterglobalister       NaN       0       6
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2017:2018
#                               Word      Value  n_2017  n_2018
# 0                        V1_berika   1.324375     769     840
# 1                N1_kulturberikare   0.293801     104     223
# 2                      N1_berikare  -3.695148     112     126
# 3                  V1_kulturberika  -3.901295      56      63
# 4                   N1_förortsgäng  -1.962136      10      21
# 5                     N1_globalist   0.720072    2458    3784
# 6                  N1_återvandring  11.082690     165    3288
# 7                  A1_globalistisk  -0.574667     420     559
# 8                  antiglobalister  -1.691442      25      29
# 9                    V1_återvandra   1.797420      24     262
# 10                        oberikat        NaN       0       0
# 11              V1_hjälpa_på_plats  -7.881296      61      52
# 12                       oberikade        NaN       0       0
# 13                        oberikad        NaN       0       0
# 14                 N2_återvandrare        NaN       0      34
# 15                   antiglobalist  -3.643991      26      19
# 16                antiglobalistisk        NaN      24       8
# 17  P1_självständig_utrikespolitik        NaN       0       0
# 18            biståndsåtervandring        NaN       0       0
# 19               antiglobalistiska  -3.661908      32      26
# 20               antiglobalistiskt        NaN       9       8
# 21              vänsterglobalister        NaN       6       0
# 22                massåtervandring        NaN       0      27
# 23                     återvandras        NaN       0      10
# 24              massåtervandringen        NaN       0       9
# 25            vänsterglobalisterna        NaN       0       0
#
# rch_2018:2019
#                               Word     Value  n_2018  n_2019
# 0                        V1_berika  0.281219     840     901
# 1                N1_kulturberikare -2.583699     223     166
# 2                      N1_berikare -2.501273     126     117
# 3                  V1_kulturberika -7.809190      63      53
# 4                   N1_förortsgäng -3.139237      21      23
# 5                     N1_globalist  1.116383    3784    3391
# 6                  N1_återvandring  6.600887    3288    1510
# 7                  A1_globalistisk -1.187758     559     650
# 8                  antiglobalister -3.794695      29      16
# 9                    V1_återvandra -2.197829     262     124
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -5.411019      52      40
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare -2.868137      34      10
# 15                   antiglobalist -4.468480      19      12
# 16                antiglobalistisk       NaN       8       9
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       8
# 19               antiglobalistiska       NaN      26       9
# 20               antiglobalistiskt       NaN       8       5
# 21              vänsterglobalister       NaN       0      15
# 22                massåtervandring -0.379089      27      18
# 23                     återvandras       NaN      10       0
# 24              massåtervandringen       NaN       9       0
# 25            vänsterglobalisterna       NaN       0       0
#
# rch_2019:2020
#                               Word     Value  n_2019  n_2020
# 0                        V1_berika  1.654064     901     711
# 1                N1_kulturberikare -3.367654     166      79
# 2                      N1_berikare -4.630948     117      72
# 3                  V1_kulturberika -3.290654      53      52
# 4                   N1_förortsgäng       NaN      23       8
# 5                     N1_globalist -1.178561    3391    3398
# 6                  N1_återvandring  1.119764    1510    1076
# 7                  A1_globalistisk -0.947354     650     624
# 8                  antiglobalister -3.989964      16      18
# 9                    V1_återvandra -3.305335     124      97
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -5.508149      40      42
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN      10       0
# 15                   antiglobalist -2.064225      12      19
# 16                antiglobalistisk       NaN       9      14
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       8      18
# 19               antiglobalistiska       NaN       9      10
# 20               antiglobalistiskt       NaN       5       0
# 21              vänsterglobalister       NaN      15       8
# 22                massåtervandring  0.895930      18      43
# 23                     återvandras       NaN       0       7
# 24              massåtervandringen       NaN       0       8
# 25            vänsterglobalisterna       NaN       0       5
#
# rch_2020:2021
#                               Word     Value  n_2020  n_2021
# 0                        V1_berika  0.405180     711     464
# 1                N1_kulturberikare -1.733575      79     101
# 2                      N1_berikare -5.107640      72      31
# 3                  V1_kulturberika -3.986949      52      32
# 4                   N1_förortsgäng       NaN       8      14
# 5                     N1_globalist -0.142242    3398    2641
# 6                  N1_återvandring -1.678562    1076    1129
# 7                  A1_globalistisk -2.539357     624     430
# 8                  antiglobalister -3.944088      18      14
# 9                    V1_återvandra -2.332365      97     130
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -6.449432      42      36
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN      19       9
# 16                antiglobalistisk       NaN      14       6
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN      18       6
# 19               antiglobalistiska       NaN      10       8
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       8       5
# 22                massåtervandring -5.325034      43      19
# 23                     återvandras       NaN       7       8
# 24              massåtervandringen       NaN       8       0
# 25            vänsterglobalisterna       NaN       5       6
#
# rch_2021:2022
#                               Word     Value  n_2021  n_2022
# 0                        V1_berika -1.535086     464     591
# 1                N1_kulturberikare -3.341082     101      80
# 2                      N1_berikare -5.839256      31      28
# 3                  V1_kulturberika -5.260880      32      30
# 4                   N1_förortsgäng  0.823941      14      24
# 5                     N1_globalist  0.000288    2641    4423
# 6                  N1_återvandring  0.952365    1129    1492
# 7                  A1_globalistisk  0.430356     430     557
# 8                  antiglobalister -1.289632      14      27
# 9                    V1_återvandra -2.476085     130     144
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats -4.404145      36      26
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       8
# 15                   antiglobalist       NaN       9      41
# 16                antiglobalistisk       NaN       6       9
# 17  P1_självständig_utrikespolitik       NaN       0      10
# 18            biståndsåtervandring       NaN       6       0
# 19               antiglobalistiska       NaN       8      25
# 20               antiglobalistiskt       NaN       0      10
# 21              vänsterglobalister       NaN       5      10
# 22                massåtervandring -2.285766      19      16
# 23                     återvandras       NaN       8       0
# 24              massåtervandringen       NaN       0       5
# 25            vänsterglobalisterna       NaN       6      12

# %%
change_show(df_yearly_dwt, "gsim", get_dwts(df_yearly_dwt, dwt_path), th=None)
# Out:
# gsim_2000:2001
#                               Word     Value  n_2000  n_2001
# 0                        V1_berika  0.802447      41      20
# 1                N1_kulturberikare  0.904334      40      28
# 2                      N1_berikare       NaN      12       0
# 3                  V1_kulturberika       NaN       8       0
# 4                   N1_förortsgäng       NaN       8       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2001:2002
#                               Word     Value  n_2001  n_2002
# 0                        V1_berika  0.858144      20      25
# 1                N1_kulturberikare       NaN      28       9
# 2                      N1_berikare       NaN       0       0
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2002:2003
#                               Word     Value  n_2002  n_2003
# 0                        V1_berika  0.984046      25      14
# 1                N1_kulturberikare       NaN       9       5
# 2                      N1_berikare       NaN       0       8
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2003:2004
#                               Word     Value  n_2003  n_2004
# 0                        V1_berika  0.862588      14      54
# 1                N1_kulturberikare       NaN       5      20
# 2                      N1_berikare       NaN       8       0
# 3                  V1_kulturberika       NaN       0       0
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0       0
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2004:2005
#                               Word     Value  n_2004  n_2005
# 0                        V1_berika  0.852281      54      55
# 1                N1_kulturberikare  0.923744      20      14
# 2                      N1_berikare       NaN       0       0
# 3                  V1_kulturberika       NaN       0       5
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist       NaN       0      18
# 6                  N1_återvandring       NaN       0       0
# 7                  A1_globalistisk       NaN       0       0
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2005:2006
#                               Word     Value  n_2005  n_2006
# 0                        V1_berika  0.726316      55     164
# 1                N1_kulturberikare  0.775632      14      51
# 2                      N1_berikare       NaN       0      14
# 3                  V1_kulturberika       NaN       5      11
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist  0.703722      18      28
# 6                  N1_återvandring       NaN       0       9
# 7                  A1_globalistisk       NaN       0       6
# 8                  antiglobalister       NaN       0       6
# 9                    V1_återvandra       NaN       0       0
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2006:2007
#                               Word     Value  n_2006  n_2007
# 0                        V1_berika  0.697722     164     611
# 1                N1_kulturberikare  0.639949      51     255
# 2                      N1_berikare  0.611367      14     185
# 3                  V1_kulturberika  0.630965      11     121
# 4                   N1_förortsgäng       NaN       0       0
# 5                     N1_globalist  0.860426      28      26
# 6                  N1_återvandring       NaN       9      47
# 7                  A1_globalistisk       NaN       6       7
# 8                  antiglobalister       NaN       6       5
# 9                    V1_återvandra       NaN       0      19
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2007:2008
#                               Word     Value  n_2007  n_2008
# 0                        V1_berika  0.790483     611    1356
# 1                N1_kulturberikare  0.737500     255     689
# 2                      N1_berikare  0.696950     185     602
# 3                  V1_kulturberika  0.746534     121     213
# 4                   N1_förortsgäng       NaN       0       7
# 5                     N1_globalist  0.617287      26     294
# 6                  N1_återvandring  0.771877      47     112
# 7                  A1_globalistisk       NaN       7      33
# 8                  antiglobalister       NaN       5       0
# 9                    V1_återvandra  0.895261      19      23
# 10                        oberikat       NaN       0       5
# 11              V1_hjälpa_på_plats       NaN       0       0
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
# gsim_2008:2009
#                               Word     Value  n_2008  n_2009
# 0                        V1_berika  0.813770    1356    1860
# 1                N1_kulturberikare  0.720900     689     525
# 2                      N1_berikare  0.721555     602     611
# 3                  V1_kulturberika  0.782498     213     247
# 4                   N1_förortsgäng       NaN       7      18
# 5                     N1_globalist  0.839476     294     204
# 6                  N1_återvandring  0.935985     112      51
# 7                  A1_globalistisk  0.885135      33      41
# 8                  antiglobalister       NaN       0       0
# 9                    V1_återvandra  0.907361      23      26
# 10                        oberikat       NaN       5       8
# 11              V1_hjälpa_på_plats       NaN       0      14
# 12                       oberikade       NaN       0      11
# 13                        oberikad       NaN       0       5
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2009:2010
#                               Word     Value  n_2009  n_2010
# 0                        V1_berika  0.853625    1860    1813
# 1                N1_kulturberikare  0.613244     525     925
# 2                      N1_berikare  0.720045     611     441
# 3                  V1_kulturberika  0.751559     247     283
# 4                   N1_förortsgäng       NaN      18       0
# 5                     N1_globalist  0.813986     204     264
# 6                  N1_återvandring  0.836426      51     168
# 7                  A1_globalistisk  0.890612      41      54
# 8                  antiglobalister       NaN       0       6
# 9                    V1_återvandra  0.865011      26      44
# 10                        oberikat       NaN       8       6
# 11              V1_hjälpa_på_plats  0.803620      14      30
# 12                       oberikade  0.906505      11      10
# 13                        oberikad       NaN       5       0
# 14                 N2_återvandrare       NaN       0       7
# 15                   antiglobalist       NaN       0       5
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2010:2011
#                               Word     Value  n_2010  n_2011
# 0                        V1_berika  0.848808    1813    1792
# 1                N1_kulturberikare  0.717161     925     533
# 2                      N1_berikare  0.699566     441     376
# 3                  V1_kulturberika  0.767523     283     249
# 4                   N1_förortsgäng       NaN       0       6
# 5                     N1_globalist  0.767242     264     355
# 6                  N1_återvandring  0.949588     168      51
# 7                  A1_globalistisk  0.807574      54     111
# 8                  antiglobalister       NaN       6       5
# 9                    V1_återvandra  0.924646      44      31
# 10                        oberikat       NaN       6       0
# 11              V1_hjälpa_på_plats  0.946140      30      25
# 12                       oberikade       NaN      10       0
# 13                        oberikad       NaN       0       5
# 14                 N2_återvandrare       NaN       7       0
# 15                   antiglobalist       NaN       5       0
# 16                antiglobalistisk       NaN       0       0
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2011:2012
#                               Word     Value  n_2011  n_2012
# 0                        V1_berika  0.847766    1792    1515
# 1                N1_kulturberikare  0.735538     533     533
# 2                      N1_berikare  0.743882     376     393
# 3                  V1_kulturberika  0.788470     249     235
# 4                   N1_förortsgäng       NaN       6       9
# 5                     N1_globalist  0.766920     355     737
# 6                  N1_återvandring  0.881786      51     146
# 7                  A1_globalistisk  0.746691     111     215
# 8                  antiglobalister       NaN       5       5
# 9                    V1_återvandra  0.917557      31      37
# 10                        oberikat       NaN       0      10
# 11              V1_hjälpa_på_plats  0.922911      25      41
# 12                       oberikade       NaN       0       9
# 13                        oberikad       NaN       5       6
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       0       0
# 16                antiglobalistisk       NaN       0       5
# 17  P1_självständig_utrikespolitik       NaN       0       5
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska       NaN       0       0
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2012:2013
#                               Word     Value  n_2012  n_2013
# 0                        V1_berika  0.796217    1515    1227
# 1                N1_kulturberikare  0.707103     533     401
# 2                      N1_berikare  0.809898     393     237
# 3                  V1_kulturberika  0.778753     235     180
# 4                   N1_förortsgäng       NaN       9       9
# 5                     N1_globalist  0.823610     737     680
# 6                  N1_återvandring  0.877333     146     185
# 7                  A1_globalistisk  0.794933     215     174
# 8                  antiglobalister       NaN       5       0
# 9                    V1_återvandra  0.905475      37      52
# 10                        oberikat       NaN      10       5
# 11              V1_hjälpa_på_plats  0.920670      41      50
# 12                       oberikade       NaN       9       8
# 13                        oberikad       NaN       6       0
# 14                 N2_återvandrare       NaN       0       5
# 15                   antiglobalist       NaN       0       5
# 16                antiglobalistisk       NaN       5       0
# 17  P1_självständig_utrikespolitik       NaN       5      11
# 18            biståndsåtervandring       NaN       0       5
# 19               antiglobalistiska       NaN       0       5
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2013:2014
#                               Word     Value  n_2013  n_2014
# 0                        V1_berika  0.821053    1227    1001
# 1                N1_kulturberikare  0.769750     401     172
# 2                      N1_berikare  0.784129     237     174
# 3                  V1_kulturberika  0.827417     180     101
# 4                   N1_förortsgäng       NaN       9      24
# 5                     N1_globalist  0.831376     680     722
# 6                  N1_återvandring  0.889120     185     157
# 7                  A1_globalistisk  0.809632     174     209
# 8                  antiglobalister       NaN       0      11
# 9                    V1_återvandra  0.941880      52      32
# 10                        oberikat       NaN       5       0
# 11              V1_hjälpa_på_plats  0.854335      50     106
# 12                       oberikade       NaN       8       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       5       5
# 15                   antiglobalist       NaN       5       5
# 16                antiglobalistisk       NaN       0      11
# 17  P1_självständig_utrikespolitik  0.907086      11      10
# 18            biståndsåtervandring       NaN       5       0
# 19               antiglobalistiska       NaN       5      10
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2014:2015
#                               Word     Value  n_2014  n_2015
# 0                        V1_berika  0.788336    1001    1095
# 1                N1_kulturberikare  0.821051     172     128
# 2                      N1_berikare  0.778524     174     198
# 3                  V1_kulturberika  0.786451     101     120
# 4                   N1_förortsgäng  0.899544      24      15
# 5                     N1_globalist  0.799325     722     676
# 6                  N1_återvandring  0.906297     157     136
# 7                  A1_globalistisk  0.835128     209     132
# 8                  antiglobalister       NaN      11       0
# 9                    V1_återvandra  0.941473      32      28
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.843080     106     251
# 12                       oberikade       NaN       0       5
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       5       0
# 15                   antiglobalist       NaN       5       7
# 16                antiglobalistisk  0.924737      11      10
# 17  P1_självständig_utrikespolitik       NaN      10       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska  0.860709      10      10
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
# gsim_2015:2016
#                               Word     Value  n_2015  n_2016
# 0                        V1_berika  0.824113    1095    1247
# 1                N1_kulturberikare  0.734825     128     171
# 2                      N1_berikare  0.782705     198     145
# 3                  V1_kulturberika  0.872261     120      98
# 4                   N1_förortsgäng  0.927844      15      12
# 5                     N1_globalist  0.800942     676    1836
# 6                  N1_återvandring  0.889528     136     200
# 7                  A1_globalistisk  0.785606     132     261
# 8                  antiglobalister       NaN       0      14
# 9                    V1_återvandra  0.962083      28      19
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.931879     251      65
# 12                       oberikade       NaN       5       0
# 13                        oberikad       NaN       0       6
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN       7      19
# 16                antiglobalistisk  0.939904      10      10
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska  0.885024      10      20
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       0       0
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2016:2017
#                               Word     Value  n_2016  n_2017
# 0                        V1_berika  0.753672    1247     769
# 1                N1_kulturberikare  0.801771     171     104
# 2                      N1_berikare  0.851082     145     112
# 3                  V1_kulturberika  0.913321      98      56
# 4                   N1_förortsgäng  0.960695      12      10
# 5                     N1_globalist  0.867421    1836    2458
# 6                  N1_återvandring  0.886374     200     165
# 7                  A1_globalistisk  0.791964     261     420
# 8                  antiglobalister  0.802863      14      25
# 9                    V1_återvandra  0.952272      19      24
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.943305      65      61
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       6       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist  0.815554      19      26
# 16                antiglobalistisk  0.902251      10      24
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska  0.871383      20      32
# 20               antiglobalistiskt       NaN       0       9
# 21              vänsterglobalister       NaN       0       6
# 22                massåtervandring       NaN       0       0
# 23                     återvandras       NaN       0       0
# 24              massåtervandringen       NaN       0       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2017:2018
#                               Word     Value  n_2017  n_2018
# 0                        V1_berika  0.807749     769     840
# 1                N1_kulturberikare  0.709372     104     223
# 2                      N1_berikare  0.803784     112     126
# 3                  V1_kulturberika  0.902283      56      63
# 4                   N1_förortsgäng  0.884809      10      21
# 5                     N1_globalist  0.867112    2458    3784
# 6                  N1_återvandring  0.826178     165    3288
# 7                  A1_globalistisk  0.776882     420     559
# 8                  antiglobalister  0.889935      25      29
# 9                    V1_återvandra  0.768756      24     262
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.951822      61      52
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0      34
# 15                   antiglobalist  0.937759      26      19
# 16                antiglobalistisk       NaN      24       8
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       0
# 19               antiglobalistiska  0.920552      32      26
# 20               antiglobalistiskt       NaN       9       8
# 21              vänsterglobalister       NaN       6       0
# 22                massåtervandring       NaN       0      27
# 23                     återvandras       NaN       0      10
# 24              massåtervandringen       NaN       0       9
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2018:2019
#                               Word     Value  n_2018  n_2019
# 0                        V1_berika  0.809319     840     901
# 1                N1_kulturberikare  0.817285     223     166
# 2                      N1_berikare  0.798538     126     117
# 3                  V1_kulturberika  0.905887      63      53
# 4                   N1_förortsgäng  0.917739      21      23
# 5                     N1_globalist  0.857974    3784    3391
# 6                  N1_återvandring  0.864239    3288    1510
# 7                  A1_globalistisk  0.803209     559     650
# 8                  antiglobalister  0.943055      29      16
# 9                    V1_återvandra  0.876538     262     124
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.955858      52      40
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare  0.965472      34      10
# 15                   antiglobalist  0.917831      19      12
# 16                antiglobalistisk       NaN       8       9
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       0       8
# 19               antiglobalistiska       NaN      26       9
# 20               antiglobalistiskt       NaN       8       5
# 21              vänsterglobalister       NaN       0      15
# 22                massåtervandring  0.901964      27      18
# 23                     återvandras       NaN      10       0
# 24              massåtervandringen       NaN       9       0
# 25            vänsterglobalisterna       NaN       0       0
#
# gsim_2019:2020
#                               Word     Value  n_2019  n_2020
# 0                        V1_berika  0.809915     901     711
# 1                N1_kulturberikare  0.854745     166      79
# 2                      N1_berikare  0.889511     117      72
# 3                  V1_kulturberika  0.921029      53      52
# 4                   N1_förortsgäng       NaN      23       8
# 5                     N1_globalist  0.893221    3391    3398
# 6                  N1_återvandring  0.860088    1510    1076
# 7                  A1_globalistisk  0.815663     650     624
# 8                  antiglobalister  0.939468      16      18
# 9                    V1_återvandra  0.903878     124      97
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.954204      40      42
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN      10       0
# 15                   antiglobalist  0.935336      12      19
# 16                antiglobalistisk       NaN       9      14
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN       8      18
# 19               antiglobalistiska       NaN       9      10
# 20               antiglobalistiskt       NaN       5       0
# 21              vänsterglobalister       NaN      15       8
# 22                massåtervandring  0.890506      18      43
# 23                     återvandras       NaN       0       7
# 24              massåtervandringen       NaN       0       8
# 25            vänsterglobalisterna       NaN       0       5
#
# gsim_2020:2021
#                               Word     Value  n_2020  n_2021
# 0                        V1_berika  0.823502     711     464
# 1                N1_kulturberikare  0.833634      79     101
# 2                      N1_berikare  0.931500      72      31
# 3                  V1_kulturberika  0.946783      52      32
# 4                   N1_förortsgäng       NaN       8      14
# 5                     N1_globalist  0.869169    3398    2641
# 6                  N1_återvandring  0.893905    1076    1129
# 7                  A1_globalistisk  0.826992     624     430
# 8                  antiglobalister  0.973584      18      14
# 9                    V1_återvandra  0.878737      97     130
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.964379      42      36
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       0
# 15                   antiglobalist       NaN      19       9
# 16                antiglobalistisk       NaN      14       6
# 17  P1_självständig_utrikespolitik       NaN       0       0
# 18            biståndsåtervandring       NaN      18       6
# 19               antiglobalistiska       NaN      10       8
# 20               antiglobalistiskt       NaN       0       0
# 21              vänsterglobalister       NaN       8       5
# 22                massåtervandring  0.966520      43      19
# 23                     återvandras       NaN       7       8
# 24              massåtervandringen       NaN       8       0
# 25            vänsterglobalisterna       NaN       5       6
#
# gsim_2021:2022
#                               Word     Value  n_2021  n_2022
# 0                        V1_berika  0.827388     464     591
# 1                N1_kulturberikare  0.868248     101      80
# 2                      N1_berikare  0.950733      31      28
# 3                  V1_kulturberika  0.954386      32      30
# 4                   N1_förortsgäng  0.831587      14      24
# 5                     N1_globalist  0.884826    2641    4423
# 6                  N1_återvandring  0.877021    1129    1492
# 7                  A1_globalistisk  0.779141     430     557
# 8                  antiglobalister  0.900734      14      27
# 9                    V1_återvandra  0.887189     130     144
# 10                        oberikat       NaN       0       0
# 11              V1_hjälpa_på_plats  0.961401      36      26
# 12                       oberikade       NaN       0       0
# 13                        oberikad       NaN       0       0
# 14                 N2_återvandrare       NaN       0       8
# 15                   antiglobalist       NaN       9      41
# 16                antiglobalistisk       NaN       6       9
# 17  P1_självständig_utrikespolitik       NaN       0      10
# 18            biståndsåtervandring       NaN       6       0
# 19               antiglobalistiska       NaN       8      25
# 20               antiglobalistiskt       NaN       0      10
# 21              vänsterglobalister       NaN       5      10
# 22                massåtervandring  0.954530      19      16
# 23                     återvandras       NaN       8       0
# 24              massåtervandringen       NaN       0       5
# 25            vänsterglobalisterna       NaN       6      12

# %% [markdown]
# ### Time bin

# %%
change_show(df_time_bin_dwt, "rch", get_dwts(df_time_bin_dwt, dwt_path))

# %%
change_show(df_time_bin_dwt, "gsim", get_dwts(df_time_bin_dwt, dwt_path), th=None)

# %%
a=load_metric("/srv/data/gusbohom/root/corpora/fb_pol/time_bin/radical3/vocab/2015.txt")["V1_berika"]
b=load_metric("/srv/data/gusbohom/root/corpora/fb_pol/time_bin/radical3/vocab/2019.txt")["V1_berika"]
print(a, b)

# %% [markdown]
# ## Correlation

# %%
get_variables(df_yearly_dwt)
# Out:
# {'yr_prefix': {'fpm', 'frq'},
#  'tr_prefix': {'dif',
#   'diffpm',
#   'gch',
#   'gsim',
#   'mccc',
#   'mcsim',
#   'rch',
#   'rsim',
#   'stdc',
#   'stdsim'},
#  'years': {'2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013',
#   '2014',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   'doc',
#   'tot'},
#  'transitions': {'2000:2001',
#   '2001:2002',
#   '2002:2003',
#   '2003:2004',
#   '2004:2005',
#   '2005:2006',
#   '2006:2007',
#   '2007:2008',
#   '2008:2009',
#   '2009:2010',
#   '2010:2011',
#   '2011:2012',
#   '2012:2013',
#   '2013:2014',
#   '2014:2015',
#   '2015:2016',
#   '2016:2017',
#   '2017:2018',
#   '2018:2019',
#   '2019:2020',
#   '2020:2021',
#   '2021:2022'}}

# %%
correlation(df=df_yearly_dwt, var1="diffpm", var2="rch", corpus=corpus, mode=2, metric = "pearson")
# Out:
#                               Word  Correlation     p   N
# 0                        V1_berika        -0.13  0.56  22
# 1                N1_kulturberikare        -0.39  0.10  19
# 2                      N1_berikare        -0.43  0.10  16
# 3                  V1_kulturberika        -0.53  0.04  16
# 4                   N1_förortsgäng         0.02  0.98   6
# 5                     N1_globalist        -0.19  0.47  17
# 6                  N1_återvandring        -0.40  0.14  15
# 7                  A1_globalistisk        -0.32  0.27  14
# 8                  antiglobalister        -0.88  0.02   6
# 9                    V1_återvandra        -0.56  0.03  15
# 10                        oberikat          NaN   NaN   0
# 11              V1_hjälpa_på_plats        -0.63  0.02  13
# 12                       oberikade          NaN   NaN   1
# 13                        oberikad          NaN   NaN   0
# 14                 N2_återvandrare          NaN   NaN   1
# 15                   antiglobalist        -0.89  0.11   4
# 16                antiglobalistisk        -0.73  0.48   3
# 17  P1_självständig_utrikespolitik          NaN   NaN   1
# 18            biståndsåtervandring          NaN   NaN   0
# 19               antiglobalistiska        -0.84  0.36   3
# 20               antiglobalistiskt          NaN   NaN   0
# 21              vänsterglobalister          NaN   NaN   0
# 22                massåtervandring        -0.90  0.10   4
# 23                     återvandras          NaN   NaN   0
# 24              massåtervandringen          NaN   NaN   0
# 25            vänsterglobalisterna          NaN   NaN   0

# %%
correlation(df=df_yearly_dwt, var1="stdc", var2="rch", corpus=corpus, mode=2, metric = "pearson")
# Out:
#                               Word  Correlation     p   N
# 0                        V1_berika         0.21  0.35  22
# 1                N1_kulturberikare        -0.29  0.23  19
# 2                      N1_berikare        -0.11  0.69  16
# 3                  V1_kulturberika         0.04  0.88  16
# 4                   N1_förortsgäng         0.36  0.49   6
# 5                     N1_globalist        -0.13  0.63  17
# 6                  N1_återvandring        -0.39  0.15  15
# 7                  A1_globalistisk         0.26  0.36  14
# 8                  antiglobalister         0.17  0.75   6
# 9                    V1_återvandra        -0.01  0.97  15
# 10                        oberikat          NaN   NaN   0
# 11              V1_hjälpa_på_plats         0.39  0.18  13
# 12                       oberikade          NaN   NaN   1
# 13                        oberikad          NaN   NaN   0
# 14                 N2_återvandrare          NaN   NaN   1
# 15                   antiglobalist         0.81  0.19   4
# 16                antiglobalistisk        -0.11  0.93   3
# 17  P1_självständig_utrikespolitik          NaN   NaN   1
# 18            biståndsåtervandring          NaN   NaN   0
# 19               antiglobalistiska         1.00  0.04   3
# 20               antiglobalistiskt          NaN   NaN   0
# 21              vänsterglobalister          NaN   NaN   0
# 22                massåtervandring         0.32  0.68   4
# 23                     återvandras          NaN   NaN   0
# 24              massåtervandringen          NaN   NaN   0
# 25            vänsterglobalisterna          NaN   NaN   0

# %%
correlation(df=df_yearly_dwt, var1="diffpm", var2="rch", corpus=corpus, mode=2, metric = "spearman")
# Out:
#                               Word  Correlation     p   N
# 0                        V1_berika        -0.03  0.90  22
# 1                N1_kulturberikare        -0.38  0.11  19
# 2                      N1_berikare        -0.14  0.60  16
# 3                  V1_kulturberika        -0.08  0.78  16
# 4                   N1_förortsgäng         0.09  0.87   6
# 5                     N1_globalist        -0.47  0.06  17
# 6                  N1_återvandring        -0.21  0.44  15
# 7                  A1_globalistisk        -0.30  0.30  14
# 8                  antiglobalister        -0.60  0.21   6
# 9                    V1_återvandra        -0.19  0.51  15
# 10                        oberikat          NaN   NaN   0
# 11              V1_hjälpa_på_plats        -0.77  0.00  13
# 12                       oberikade          NaN   NaN   1
# 13                        oberikad          NaN   NaN   0
# 14                 N2_återvandrare          NaN   NaN   1
# 15                   antiglobalist        -0.80  0.20   4
# 16                antiglobalistisk        -0.50  0.67   3
# 17  P1_självständig_utrikespolitik          NaN   NaN   1
# 18            biståndsåtervandring          NaN   NaN   0
# 19               antiglobalistiska        -0.50  0.67   3
# 20               antiglobalistiskt          NaN   NaN   0
# 21              vänsterglobalister          NaN   NaN   0
# 22                massåtervandring        -1.00  0.00   4
# 23                     återvandras          NaN   NaN   0
# 24              massåtervandringen          NaN   NaN   0
# 25            vänsterglobalisterna          NaN   NaN   0
