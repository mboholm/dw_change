# %%
import re
import os
import json
#import csv
from pathlib import Path
import time
import json

# %%
output_dir = Path("/home/max/tmp")

# %%
corpus = Path("/home/max/Corpora/flashback-pol-time/yearly/fb-pt-radical3/files")

# %%
dwt_seeds = Path("utils/dwts.txt")

# %%
def read_util(file_path):
    with open(file_path, "r") as f:
        terms = [line.strip("\n").split("#")[0] for line in f.readlines()]
    terms = [term for term in terms if term != ""]
    return terms

# %%
read_util(dwt_seeds)
# Out:
# ['förortsgäng',
#  'återvandr',
#  'berika',
#  'kulturberika',
#  'ordning_och_reda_i_flyktingpolitiken',
#  'globalist',
#  'hjälpa_på_plats',
#  'självständig_utrikespolitik']

# %%
def read_paradigm(file_path):
    paradigms = read_util(file_path)
    paradigms = [tuple([re.sub(r" \Z", r"", column) for column in p.split(" -> ")]) for p in paradigms]
    return paradigms

# %%
read_paradigm("utils/dwts.paradigm")
# Out:
# [('förortsgäng', 'N1', '\\bförortsgäng(|et|en|s|ets|ens)\\b', 'förortsgäng'),
#  ('förortsgäng',
#   'N1C',
#   '\\b(förortsgäng)s?([^(\\s|et|en|s|ets|ens)].*?)\\b',
#   'förortsgängX'),
#  ('återvandr',
#   'N1',
#   '\\båtervandring(|en|ar|s|ens|ars|arna|arnas)\\b',
#   'återvandring'),
#  ('återvandr', 'N2', '\\båtervandrar(e|en|es|ens|na|nas)\\b', 'återvandrare'),
#  ('återvandr', 'N3', '\\båtervandrande(|t|ts|n|ns|rnas)', 'återvandrande'),
#  ('återvandr',
#   'N1C',
#   '\\b(återvandring)s?([^(\\s|en|ar|s|ens|ars|arna|arnas)].*?)\\b',
#   'återvandringsX'),
#  ('återvandr', 'N2C', '\\b(återvandrar)([^(\\s|e)].*?)\\b', 'återvandrarX'),
#  ('återvandr', 'V1', '\\båtervandra(|r|d|de|t)\\b', 'återvandra'),
#  ('berika', 'N1', '\\bberikar(e|en|na|es|ens|nas)\\b', 'berikare'),
#  ('berika', 'N1C', '\\b(berikar)([^(\\s|en|na|s|ens|nas)].*?)\\b', 'berikarX'),
#  ('berika', 'V1', '\\bberik(a|ar|ad|ade|at|ande)\\b', 'berika'),
#  ('berika', 'N1', '\\bkulturberikar(e|en|na|es|ens|nas)\\b', 'kulturberikare'),
#  ('berika',
#   'N1C',
#   '\\b(kulturberikar)([^(\\s|en|na|es|ens|nas)].*?)\\b',
#   'kulturberikarX'),
#  ('berika', 'V1', '\\bkulturberik(a|ar|ad|ade|at|ande)\\b', 'kulturberika'),
#  ('ordning och reda i flyktingpolitiken',
#   'P1',
#   'ordning och reda i flyktingpolitiken',
#   'ordning_och_reda_i_flyktingpolitiken'),
#  ('globalist',
#   'N1',
#   '\\bglobalist(|en|er|erna|s|ens|ers|ernas)\\b',
#   'globalist'),
#  ('globalist',
#   'N1C',
#   '\\b(globalist)([^(\\s|en|er|erna|s|ens|ers|ernas|isk)].*?)\\b',
#   'globalistX'),
#  ('globalist', 'A1', '\\bgloablistisk(|a|kt)\\b', 'globalistisk'),
#  ('hjälpa.*? på plats',
#   'V1',
#   '\\bhjälp(a|er|te|t|ande)\\b på plats\\b',
#   'hjälpa_på_plats'),
#  ('hjälpa.* på plats',
#   'V2',
#   '\\bhjälp(a|er|te|t|ande)\\b .*? på plats\\b',
#   'hjälpa_X_på_plats'),
#  ('självständiga? utrikespolitik',
#   'P1',
#   '\\bsjälvständiga? utrikespolitik(|en|s|ens|er|ers|ernas)\\b',
#   'självständig_utrikespolitik')]

# %%
def dwt_counter(corpus, full_paradigm):
    t0 = time.time()
    corpus = Path(corpus)
    files = sorted(os.listdir(corpus))
    years = [year.strip(".txt") for year in files]
    roots, pos, regex, lemmas = zip(*full_paradigm)
    counter = {year: {lemma: {} for lemma in lemmas} for year in years}    
   
    paradigm = list(zip(pos, regex, lemmas))
    roots = set(roots)
    roots = re.compile(r"(" + "|".join(roots) + ")")
    
    hits = 0
   
    for k, file in enumerate(files, start=1):
        with open(corpus / file, "r") as f:
            year = file.strip(".txt")
            
            for i, line in enumerate(f):
                
#                 if hits > 5000:
#                     return counter
                
                if i % 10000 == 0:
                    print(f"{file} {k} / {len(files)}: {i}; hits = {hits}    ", end="\r")
                
                if re.search(roots, line) == None:
                    continue
                
                else:
                    hits += 1

                    for pos, regex, lemma in paradigm:
                        regex = re.compile(regex)
                        payload = re.search(regex, line)
                        if payload == None:
                            continue
                        else:
                            hit = payload.group(0)
                            
                            if hit in counter[year][lemma]:
                                counter[year][lemma][hit] += 1
                            else:
                                counter[year][lemma][hit] = 1
    
    delta_t = time.time() - t0
    m = int(delta_t / 60)
    s = int(delta_t / 60)
    
    print("Done!", f"({m} m, {s} s)")
    
    return counter

# %%
dd = dwt_counter(corpus, read_paradigm("utils/dwts.paradigm"))
# Out:
# Done! (3 m, 3 s): 3610000; hits = 75689

# %%
dd
# Out:
# {'2000': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa folket på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2001': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {},
#   'självständig_utrikespolitik': {}},
#  '2002': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {},
#   'självständig_utrikespolitik': {}},
#  '2003': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {},
#   'självständig_utrikespolitik': {}},
#  '2004': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa andra människor i världen som lider men gör det på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2005': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa dom på plats': 1,
#    'hjälpa folk på plats': 2,
#    'hjälpa de verkligt nödlidande på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2006': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa människor på plats': 2,
#    'hjälpa libaneserna på plats': 1,
#    'hjälpa packet på plats': 1,
#    'hjälpa folk i fattiga länder på plats': 1,
#    'hjälpa kan göra mkt mer effektiva saker på plats': 1,
#    'hjälpa dom främst på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2007': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa dom på plats': 2,
#    'hjälpa till under stridigheterna genom att t.ex nedgöra eventuella desertörer på plats': 2,
#    'hjälpa oändligt många fler människor på plats': 1,
#    'hjälpa personer på flykt men jag anser att dom pengarna är bättre använda på plats': 1,
#    'hjälpa fler på plats': 1,
#    'hjälpa de här människorna gör vi naturligtvis större nytta om vi på plats': 1,
#    'hjälpa ert hemland som nu håller på att återuppbyggas skulle inte ni vilja vara på plats': 1,
#    'hjälpa de på plats': 1,
#    'hjälpa dessa människor på plats': 1,
#    'hjälpa människor genom att låta ett försvinnade lite andel av världens flyktingar få livstidsförsörjning i sverige istället för att lägga pengarna på att hjäla folk på plats': 1,
#    'hjälpa folk på plats': 3,
#    'hjälpa människor på plats': 1,
#    'hjälpa dina svarta bröder att bygga upp sin krigs och svältdrabbade kontinent på plats': 1,
#    'hjälpa andra länder på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2008': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa människor i utsatta områden runt om i världen så hade vi hjälpt dem på plats': 1,
#    'hjälpa alla stackars jävlar på plats': 1,
#    'hjälpa många fler flyktingar på plats': 1,
#    'hjälpa dem på plats': 3,
#    'hjälpa till på plats': 1,
#    'hjälpa dom på plats': 4,
#    'hjälpa flyktingar på plats': 2,
#    'hjälpa folk därnere på plats': 1,
#    'hjälpa direkt på plats': 1,
#    'hjälpa dom som verkligen behöver hjälp på plats': 1,
#    'hjälpa folk på plats': 1,
#    'hjälpa de som har det svårt är det bästa att göra det på plats': 1,
#    'hjälpa fler på plats': 1,
#    'hjälpa en vän på plats': 1,
#    'hjälpa därnere på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2009': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa är att man återställer ordningen sätter kvinnor på plats': 1,
#    'hjälpa situationen här och liknande situationer om de uppstår är att man helt enkelt kan gripa och åtala samtliga som är på plats': 1,
#    'hjälpa många fler barn på plats': 1,
#    'hjälpa tio gånger fler på plats': 1,
#    'hjälpa mångdubbelt fler på plats': 1,
#    'hjälpa dem på plats': 8,
#    'hjälpa folk på plats': 4,
#    'hjälpa dem och betydligt fler på plats': 1,
#    'hjälper man bäst genom att ge dem en tillfällig tillflykt eller genom att hjälpa dem på plats': 1,
#    'hjälpa för dom pengarnadet är fan vidrigt hur man låter detta ske varför ska bara vissa ha hjälp med lyxliv i sverige när vi kunnat hjälpa så många mer på plats': 1,
#    'hjälpa fler personer på plats': 1,
#    'hjälpa mångfalt så många gånger fler på plats': 1,
#    'hjälpa kanske hundra människor på plats': 1,
#    'hjälpa dom på plats': 1,
#    'hjälpa dessa på plats': 2,
#    'hjälpa människor på plats': 1,
#    'hjälpa dem så ska vi hjälpa dem på plats': 1,
#    'hjälpa negrerna på plats': 1,
#    'hjälpa folk i andra länder så är hjälp på plats': 1,
#    'hjälpa så otroligt många fler om vi hjälper dom på plats': 1,
#    'hjälpa tusen somalier på plats': 1,
#    'hjälpa . på plats': 1,
#    'hjälpa folk i ex.vis krigshärjade länder ska man göra det på plats': 1,
#    'hjälpa negrer som har det svårt genom att flytta dem till sverige utan vi borde kanske istället hjälpa dem på plats': 1,
#    'hjälpa om man istället hade använt pengarna på plats': 1,
#    'hjälpa människor i nöd på plats': 1,
#    'hjälpa problemländer på plats': 1,
#    'hjälpa på många sättatt vara på plats': 1,
#    'hjälpa folk som verkligen behöver vår hjälp och då förslagsvis på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2010': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa barnet får du nog åka ner dit och börja undersöka på plats': 1,
#    'hjälpa till på plats': 7,
#    'hjälpa fler på plats': 8,
#    'hjälpa den stackars mannen men det beror endast på att det snabbt varkillar på plats': 1,
#    'hjälpa många många fler människor som verkligen behöver det genom att hjälpa dem på plats': 1,
#    'hjälpa tiotusentals på plats': 1,
#    'hjälpa folk på plats': 11,
#    'hjälpa invandrare men på plats': 1,
#    'hjälpa människorna på plats': 3,
#    'hjälpa det på plats': 1,
#    'hjälpa särskilt många på plats': 1,
#    'hjälpa mö na länderna genom att ta emot dem hjälp dem på plats': 1,
#    'hjälpa hans hennes landsmän på plats': 1,
#    'hjälpa dem på plats': 16,
#    'hjälpa dem i sitt hemland på plats': 1,
#    'hjälpa tiotusentals fler på plats': 1,
#    'hjälpa fler flyktingar på plats': 1,
#    'hjälpa flyktingar på plats': 8,
#    'hjälpa betydligt fler på plats': 1,
#    'hjälpa er på plats': 1,
#    'hjälpa långt fler fattigare på plats': 1,
#    'hjälpa många fler asylsökande just vid den tidpunkten på plats': 1,
#    'hjälpa äkta flyktingar på plats': 1,
#    'hjälpa dom på plats': 7,
#    'hjälpa några få få i jämförelse med antalet flyktingar i krisområdet genom att låta de komma hit tredubbla stödet för unchr fns flyktingorgan och hjälpa till på plats': 1,
#    'hjälpa invandrare nu ocksåom dom någonsin kommer få något att säga till om så kommer dom att slänga ut varenda människa med bruten näsa och att hjälpa dem på plats': 1,
#    'hjälpa flera hundra personer på plats': 1,
#    'hjälpa varandra.eftersom världen ser ut som den gör dvs med olycka och elände så drivs människor på flykt.då det i världens saknas resurser att lösa saker på plats': 1,
#    'hjälpa människor på plats': 11,
#    'hjälpa fler människor på plats': 3,
#    'hjälpa invandrarna på plats': 1,
#    'hjälpa uländerna på plats': 1,
#    'hjälpa dessa människor på plats': 2,
#    'hjälpa många människor på plats': 1,
#    'hjälper vi ytterst få människor för otroligt mycket pengar när vi kan hjälpa många fler på plats': 1,
#    'hjälpa familjen att flytta till ett närliggande land så förstörs ju hela konceptet med att hjälpa folk på plats': 1,
#    'hjälpa personer så är det absolut bästa att hjälpa människor på plats': 1,
#    'hjälpa länderna på plats': 1,
#    'hjälpa en flykting i sverige när jag för samma pengar kunde hjälpasvältande barn på plats': 1,
#    'hjälpa tusentals på plats': 1,
#    'hjälpa mångfalt fler på plats': 1,
#    'hjälpa . personer fler på plats': 1,
#    'hjälpa befolkningen på plats': 1,
#    'hjälpa en mängd andra gravida åringar direkt på plats': 1,
#    'hjälper ju fler om man satsar samma ekonomiska medel på att hjälpa dem på plats': 1,
#    'hjälpa alla flyktingar här i världen så ska man hjälpa dom på plats': 1,
#    'hjälpa mångfalt fler folk som faktiskt behöver hjälp medicin mat vatten på plats': 1,
#    'hjälpa fattiga delar av världen på plats': 1,
#    'hjälpa behövande på plats': 1,
#    'hjälpa hundratusentals på plats': 1,
#    'hjälpa irak på plats': 1,
#    'hjälpa folk som har det svårt verkligen hjälpa då är det hjälp på plats': 1,
#    'hjälpa folket på plats': 4,
#    'hjälpa åtskilliga miljoner människor på plats': 1,
#    'hjälpa de här tomtarna på plats': 1,
#    'hjälpa dom som verkligen är behövande och lidande redan på plats': 1,
#    'hjälpa de svältande på plats': 1,
#    'hjälpa den mångdubbla mängd människor i utsatta länder på plats': 1,
#    'hjälpa säg dubbelt så många på plats': 1,
#    'hjälpa varandra på plats': 1,
#    'hjälpa riktiga flyktingar på plats': 1,
#    'hjälpa tredje världen är hjälp på plats': 1,
#    'hjälpa miljontals människor med på plats': 1,
#    'hjälpa dem i sverige eller så kan man hjälpa dem på plats': 2,
#    'hjälpa alla tio på plats': 1,
#    'hjälpa folk så kan vi hjälpa dessa på plats': 1,
#    'hjälpa muslimer på plats': 1,
#    'hjälpa minst tio familjer på plats': 1,
#    'hjälpa så otroligt många fler för en mycket lägre summa med hjälp på plats': 1,
#    'hjälpa där det gör nytta d.v.s. på plats': 1,
#    'hjälpa dessa så hade vi gjort bästa att hjälpa dessa på plats': 1,
#    'hjälpa så enormt många fler på plats': 1,
#    'hjälpa hundra av riktigt utsatta och fattiga personer på plats': 1,
#    'hjälpa många fler på plats': 2,
#    'hjälpa ett större antal av dem på plats': 1,
#    'hjälpa fattiga afghanska kvinnor och barn genom att skydda dem på plats': 1,
#    'hjälpa fler om vi gör det på plats': 1,
#    'hjälpa flyktingarna på plats': 1,
#    'hjälpa flyktingar för att man har ju kommit fram till att man kan hjälpa tror de vagånger så många för samma pengar som vi lägger på våra invandrare om vi istället hjälper dom på plats': 1,
#    'hjälpa många fler i uländerna på plats': 8,
#    'hjälpa de fattiga på plats': 1,
#    'hjälpa några få rika som kan söka asyl i sverige och deras anhöriga som inte ens teoretiskt är flyktingar istället för att hjälpa fler på plats': 1,
#    'hjälpa några få som lyckats ta sig till sverige eller hjälper enormt många fler på plats': 1,
#    'hjälpa utländska på plats': 1,
#    'hjälpa människorna i den tredje världen är att hjälpa dom på plats': 1,
#    'hjälpa ungefärgånger fler på plats': 1,
#    'hjälpa till mer på plats': 1,
#    'hjälpa en större grupp människor på plats': 1,
#    'hjälpa de som lider på plats': 1,
#    'hjälpa alla som vill fly på plats': 1,
#    'hjälpa de fattiga är just på ett sätt som båda tjänar på att enbart ge bistånd och sätta dem vidare i beroendeställning har ju sannerligen inte fungerat särskilt bra för indien det var vad man gjorde under en längre tid sedan satte man på plats': 1,
#    'hjälpa flest flyktingar på plats': 1,
#    'hjälpa utsatta svenska barn med mat medicin så ska zigenarna attackera fartygen på internationellt vatten och avrätta folk på plats': 1,
#    'hjälpa flyktingar ser jag att precis som sd föreslår en utökning av biståndet på plats': 1,
#    'hjälper här i sverige som inte behöver hjälp och som inte har flyktingstatus så skulle man istället kunna hjälpaandra människor på plats': 1,
#    'hjälper hellre så många vi kan på plats': 1,
#    'hjälpa oändligt många fler på plats': 1,
#    'hjälpa men hjälpen ska ske på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2011': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa antingen y folk här hemma under ett dygn eller z pengar på plats': 1,
#    'hjälpa dem på plats': 15,
#    'hjälpa dom en bättre lösning är att hjälpa dem på plats': 1,
#    'hjälpa flera och mer effektivt på plats': 1,
#    'hjälpa människor på plats': 12,
#    'hjälpa miljontals människor på plats': 1,
#    'hjälpa detta folk på plats': 1,
#    'hjälpa människor dock kan man lägga mer resurser om man hjälper folk på plats': 1,
#    'hjälpa de på plats': 2,
#    'hjälpa folket på plats': 3,
#    'hjälpa många fler på plats': 4,
#    'hjälpa många fler av de som mest behöver det för samma pengar genom att bidra på plats': 2,
#    'hjälpa dessa människor på plats': 1,
#    'hjälpa så borde man göra det på plats': 1,
#    'hjälpa invandrare på plats': 1,
#    'hjälpa dom på plats': 8,
#    'hjälpa mångdubbelt fler människor på plats': 1,
#    'hjälpa dom att leva här kanske hjälp på plats': 1,
#    'hjälpa till på plats': 3,
#    'hjälpa alla och att hjälpa folk på plats': 1,
#    'hjälpa tiotusentals fler människor på plats': 1,
#    'hjälpa utsatta på plats': 1,
#    'hjälpa riktiga flyktingar på plats': 1,
#    'hjälpa flyktingar på plats': 9,
#    'hjälpa det utsatta folket på plats': 1,
#    'hjälpa flera tusen personer i samma situation på plats': 1,
#    'hjälpa många fler av de mest utsatta för samma pengar genom att bidra på plats': 1,
#    'hjälper ett fåtal som kommer hit istället för att hjälpa flera på plats': 1,
#    'hjälpa utsatta människor bör det göras på plats': 1,
#    'hjälpa dem är att göra det på plats': 1,
#    'hjälpa folk på plats': 12,
#    'hjälper en flykting i sverige så kan vi hjälpa ungefärpersoner på plats': 1,
#    'hjälpa potentiella framtida invandrare på plats': 1,
#    'hjälpa hundratals kanske tusentals om året på plats': 1,
#    'hjälpa varje asylfuskande lycksökare som det kostar att hjälpariktigt nödlidande verkliga flyktingar på plats': 1,
#    'hjälpa några få av alla nödställda människor här på plats': 1,
#    'hjälpa människor genom att låta de invandra kontra hjälpa de på plats': 1,
#    'hjälpa många många fler människor på plats': 1,
#    'hjälpa människor i nöd bör man hjälpa människor på plats': 1,
#    'hjälpa negrer höjer rösten och menar att man kanske hjälper dem bättre på plats': 1,
#    'hjälpa alla de utsatta på plats': 1,
#    'hjälpa människor på ett effektivare vis och det sker genom att de hjälps på plats': 1,
#    'hjälpa fler på plats': 6,
#    'hjälpa många många tusen fler människor på plats': 1,
#    'hjälpa långt fler riktiga fattiga på plats': 1,
#    'hjälpa många mer på plats': 1,
#    'hjälpa kan ge utav era egna pengar eller åka till mellanöstern eller afrika och arbeta på plats': 1,
#    'hjälpa de främmande folken på plats': 1,
#    'hjälpa fler människor på plats': 4,
#    'hjälpa alla på plats': 2,
#    'hjälpa dessa barn på plats': 1,
#    'hjälpa betydligt fler barn på plats': 1,
#    'hjälpa dom via internet lika gärna som på plats': 1,
#    'hjälpa så många fler flyktingar på plats': 1,
#    'hjälpa de invandrare som är här och sedan hjälpa flyktingar på plats': 1,
#    'hjälpa människorna på plats': 1,
#    'hjälpa många fler billigare på plats': 2,
#    'hjälpa betydligt många fler människor jag anser till skillnad från dig att även negrer är människor på plats': 1,
#    'hjälpa till men denna gång på plats': 1,
#    'hjälpa dom där på plats': 1,
#    'hjälpa det mångdubbla på plats': 1,
#    'hjälpa dem som har det svårt på plats': 1,
#    'hjälpa tusentals på plats': 2,
#    'hjälpa miljoner fler människor på plats': 1,
#    'hjälpa folk i nöd på plats': 1,
#    'hjälpa till där så behövs på plats': 1,
#    'hjälpa människor så hjälper man naturligt dessa på plats': 1,
#    'hjälpa utsatta folk varför tar man hit en familj när man skulle kunna hjälpa tiotusentals fler på plats': 1,
#    'hjälper de bäst genom att hjälpa de på plats': 1,
#    'hjälpa dessa somalier på plats': 1,
#    'hjälpa bra många tusen på plats': 1,
#    'hjälpa tusentals kanske tiotusentals gånger fler genom att fördela dessa pengar på plats': 1,
#    'hjälpa flyktingar så vet alla som är någorlunda insatta och kan räkna lite enkel matte att det är humanare att hjälpa flyktingar på plats': 1,
#    'hjälpa somalierna på plats': 1,
#    'hjälpa hundratals människor på plats': 1,
#    'hjälpa människor där hjälpen gör sig bäst dvs på plats': 1,
#    'hjälpa svältande på plats': 1,
#    'hjälpa andra behövande på plats': 1,
#    'hjälpa hemlösa sätta upp små baser prydda med symbolik ge nån form av humanitär hjälp på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa flyktingar riktiga flyktingar på plats': 1,
#    'hjälpa fler människor i utsatthet på plats': 1,
#    'hjälpa lika många på plats': 1,
#    'hjälpa fler flyktingar på plats': 1,
#    'hjälpa så oerhört många fler på plats': 1,
#    'hjälpa libyerna på plats': 1,
#    'hjälpa betydligt många fler på plats': 1,
#    'hjälpa de utsatta på plats': 1,
#    'hjälpa den försvinnande lilla mängd som faktiskt är i behov av hjälp på plats': 1,
#    'hjälpa säkert hundra gånger fler på plats': 1,
#    'hjälpa ett land i nöd ska detta ske på plats': 1,
#    'hjälpa libyska flyktingar på plats': 1,
#    'hjälpa med mat och medicin på plats': 1,
#    'hjälpa människor i nöd på plats': 1,
#    'hjälpa de caflyktingar människor som kommer till vår gräns istället för att hjälpa mångfalt fler på plats': 1,
#    'hjälpa både personochi afrika på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2012': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa . av dessa människor vi kan hjälpa många fler genom att ta dessa pengar och hjälpa dom på plats': 1,
#    'hjälpa dem på plats': 15,
#    'hjälpa flyktingar på plats': 14,
#    'hjälpa människor på plats': 20,
#    'hjälpa många fler på plats': 2,
#    'hjälpa männsiskor som har det svårt men det görs mycket bättre och effektivare på plats': 1,
#    'hjälpa dom på plats': 9,
#    'hjälper flest flyktingar att hjälpa dem i sverige med allt vad de innebär i form av migrationsärenden bidrag sfi sjukvård skola etc jämfört med att hjälpa dem på plats': 1,
#    'hjälpa fattiga folk i deras hemländer än att ta hit mera folk till sverige som leder till stora kostnader och med dom pengar vi använder för invandring kunde ha hjälp mycket mera folk utomlands på plats': 1,
#    'hjälpa några få som lyckas ta sig till vårt land istället för sjukt många fler på plats': 1,
#    'hjälpa många fler människor i minst lika svåra situationer på plats': 1,
#    'hjälpa så ofattbart många människor på plats': 1,
#    'hjälpa så många som möjligt på plats': 3,
#    'hjälpa betydligt fler om vi slutade att försöka integrera folk som inte går att integrera och istället skänka pengar till fn så de kan få hjälp på plats': 1,
#    'hjälpa fler personer genom att hjälpa dem på plats': 1,
#    'hjälpa länderna där på plats': 1,
#    'hjälpa till på plats': 6,
#    'hjälpa länder som somalia på plats': 1,
#    'hjälpa dessa länder på plats': 1,
#    'hjälpa flyktingar så måste vi hjälpa dem på plats': 1,
#    'hjälpa somalierna på plats': 2,
#    'hjälpa människor som har det svårt behövs insatser på plats': 1,
#    'hjälpa dem som verkligen har det svårt så kunde vi göra det på plats': 1,
#    'hjälpa denne på plats': 1,
#    'hjälpa dessa människor på plats': 1,
#    'hjälpa dem får ta saken i egna händer exempelvis genom välgörenhet och kanske hellre hjälpa dem på plats': 1,
#    'hjälpa flyktingar är att hjälpa så många som möjligt och tro det eller ej men det gör man inte genom att göra sverige mångkulturellt och massetniskt utan det gör man genom att rikta så stora resurser som möjligt till flyktingarna på plats': 1,
#    'hjälpa folket på plats': 3,
#    'hjälpa fler invandrare genom att hjälpa dem på plats': 1,
#    'hjälpa fler på plats': 8,
#    'hjälpa folk på plats': 12,
#    'hjälpa barn måste hålla med om detta i ljuset av det faktum att man kan hjälpa .+ behövande barn på plats': 1,
#    'hjälpa flyktingarna på plats': 2,
#    'hjälpa fler människor på plats': 3,
#    'hjälpa fler människor bättre på plats': 1,
#    'hjälpa dessa varelser flytta dit du och hjälp de på plats': 1,
#    'hjälpa de mörka varelserna på plats': 1,
#    'hjälpa så många som möjligt är det fantastiskt mycket effektivare att hjälpa folk på plats': 1,
#    'hjälpa människor då ska ju våra pengar gå till att bygga upp dessa länder på plats': 1,
#    'hjälpa barn och människor i andra länder på plats': 1,
#    'hjälper att hjälpa dom på plats': 1,
#    'hjälpa personer på plats': 3,
#    'hjälpa dom här i sverige istället för att hjälpa dom på plats': 1,
#    'hjälpa människor i nöd men resuserna kan användas på plats': 1,
#    'hjälpa dem visst vi hjälper ett fåtal men man skulle kunna göra mycket mer på plats': 1,
#    'hjälpa miljontals människor på plats': 1,
#    'hjälpa så gör man det bäst på plats': 1,
#    'hjälpa folk i första hand på plats': 1,
#    'hjälpa mer på plats': 1,
#    'hjälpa så många flyktingar som möjligt genom att ge dem ett bättre liv i sverige gentemot frågan om det inte är bättre att lägga samma resurser på att hjälpa människor på plats': 1,
#    'hjälpa alla på plats': 1,
#    'hjälpa fler personer på plats': 1,
#    'hjälpa sina muslimiska bröder och systrar på plats': 1,
#    'hjälpa människor med behov på plats': 1,
#    'hjälper man inte fler genom att hjälpa folk på plats': 1,
#    'hjälpa ett fåtal människor på plats': 1,
#    'hjälpa många fler människor på plats': 1,
#    'hjälpa flera på plats': 1,
#    'hjälpa länder med problem på plats': 1,
#    'hjälpa fattiga länder som anammar tankar på befolkningssustainability på plats': 1,
#    'hjälpa så många som möjligt och på ett så effektivt sätt som möjligt på plats': 1,
#    'hjälpa långt fler till en mindre summa på plats': 1,
#    'hjälpa fler riktiga flyktingar än de andra partierna genom sitt utökade stöd för att hjälpla på plats': 1,
#    'hjälpa så många som möjligt hade vi hjälpt flyktingar på plats': 1,
#    'hjälper hellre en enda flykting i sverige som de hoppas ska ge avkastning till sverige i framtiden än att hjälpa . på plats': 1,
#    'hjälpa så hade man hjälpt många fler på plats': 1,
#    'hjälpa dessa urtidsmänniskor på plats': 1,
#    'hjälpa flera familjer på plats': 1,
#    'hjälpa en mindre grupp människor saken är att man både kan hjälpa människor genom att hjälpa vissa på plats': 1,
#    'hjälpa många fler me samma pengar om de gjordes på plats': 1,
#    'hjälpa dessa så får det ske med egna medel och på plats': 1,
#    'hjälpa dem för om vi skulle hjälpa dem varför hjälper vi dem inte på plats': 1,
#    'hjälpa människorna på plats': 3,
#    'hjälpa till mer på plats': 2,
#    'hjälpa dem hemma på plats': 1,
#    'hjälpa många fler negrer i deras hemland då det kostar ggr mer att ta hand om en invandrare i sverige än att hjälpa en neger på plats': 1,
#    'hjälpa så räcker dessutom pengarna betydligt längre på plats': 1,
#    'hjälpa somalierna bygga upp sitt land igen på plats': 1,
#    'hjälpa de på plats': 1,
#    'hjälpa mångdubbelt fler av de mest behövande på plats': 1,
#    'hjälpa de i syrien ska vi ju göra det på plats': 1,
#    'hjälpa enormt många fler människor på plats': 1,
#    'hjälpa så många mer på plats': 1,
#    'hjälpa människor i nöd på plats': 1,
#    'hjälpa mycket fler människor genom att hjälpa dem bygga upp sina egna länder på plats': 1,
#    'hjälpa de aktuella länderna direkt på plats': 1,
#    'hjälpa ytisar på plats': 1,
#    'hjälpa flera hundra människor på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa de rika invandrare de som har råd att fly före att hjälpa människor på plats': 1,
#    'hjälpa ett folk att komma på fötter på plats': 1,
#    'hjälpa folk i oroshärdar på plats': 1,
#    'hjälpa till både på plats': 1,
#    'hjälpa så många som möjligt vilket görs bäst på plats': 1,
#    'hjälpa folk som verkligen behöver hjälp på plats': 1,
#    'hjälpa räcker våra pengar mycket längre på plats': 1,
#    'hjälpa som inte går till att vara på plats': 1,
#    'hjälpa tant agda på plats': 1,
#    'hjälpa betydligt fler människor på plats': 1,
#    'hjälpa mångdubbelt på plats': 1,
#    'hjälpa andra länder på plats': 1,
#    'hjälpande åtgärder på plats': 1,
#    'hjälpa fattiglapparna på plats': 1,
#    'hjälpa riktiga flyktingar på plats': 1,
#    'hjälper manmiljon på plats': 1,
#    'hjälper så många som möjligt genom att hjälpa dem på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2013': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa aporna på plats': 1,
#    'hjälpa så otroligt många fler människor om vi hjälpte fn att hjälpa människorna på plats': 1,
#    'hjälpa fler att överleva genom att ge bistånd på plats': 1,
#    'hjälpa folk på plats': 28,
#    'hjälpa de som svälter på plats': 1,
#    'hjälpa dem som bor där på plats': 1,
#    'hjälpa ett land som syrien är att hjälpa dem på plats': 1,
#    'hjälpa invandrare på plats': 1,
#    'hjälpa dom på plats': 9,
#    'hjälpa fattiga utsatta människor görs det på plats': 1,
#    'hjälpa dessa personer i deras hemländer när man har misslycktas något grovt på plats': 1,
#    'hjälpa handlar inget om att hjälpa dessa människor för bästa hjälpen sker på plats': 1,
#    'hjälpa dessa på plats': 4,
#    'hjälpa många på plats': 3,
#    'hjälpa i närområden på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa dom som verkligen behöver akut hjälp på plats': 1,
#    'hjälpa många fler på plats': 4,
#    'hjälpa tusentals andra människor på plats': 1,
#    'hjälpa riktiga flyktingar på plats': 2,
#    'hjälpa nån varken här eller på plats': 1,
#    'hjälper iställlet för att hjälpa ggr fler människor på plats': 1,
#    'hjälpa kvinnorna på plats': 1,
#    'hjälpa ett flyktingbarn i sverige kr dag hjälpa flyktingbarn på plats': 1,
#    'hjälpa alla dessa stackare enda sättet är att hjälpa dom på plats': 1,
#    'hjälpa till så kan man göra det ideellt genom att skänka pengar eller stödja arbeta för att organisationer som hjälper flyktingar på plats': 1,
#    'hjälpa de som har det svårast på plats': 1,
#    'hjälpa samma barn på plats': 1,
#    'hjälpa flyktingarna på plats': 4,
#    'hjälpa världens människor så måste man ge hjälp på plats': 1,
#    'hjälpa lidande folkgrupper på plats': 1,
#    'hjälpa fler på plats': 6,
#    'hjälpa betydligt många fler på plats': 1,
#    'hjälpa nödställda människor får man mångdubbelt mer nytta av pengarna om man hjälper människorna på plats': 1,
#    'hjälpa människorna på plats': 1,
#    'hjälpa flyktingbetyngda kommuner tillbaks till bättre ekonomi bygga upp ett nytt försvar ge hjälp på plats': 1,
#    'hjälpa flyktingar på plats': 8,
#    'hjälpa människor på plats': 13,
#    'hjälpa mångdubbelt fler människor på plats': 1,
#    'hjälpa typmänniskor in i sverige som sedan hamnar i utanförskap i ett miljonprogram som alla andra istället för att kunna hjälpa ännu fler och då snackar jag upp motmänniskor på plats': 1,
#    'hjälpa tio andra på plats': 1,
#    'hjälpa de svältande på plats': 1,
#    'hjälpa så många som möjligt är det effektivare att skicka pengar till unhcr fns flyktingorgan för att hjälpa fler på plats': 1,
#    'hjälpa grannländerna att ta emot dem då vi på plats': 1,
#    'hjälpa betydligt fler människor på plats': 1,
#    'hjälpa miljontals människor på plats': 1,
#    'hjälpa dem på plats': 9,
#    'hjälpa folk att bygga upp sina egna länder på plats': 1,
#    'hjälpa tals personer på plats': 1,
#    'hjälpa hundratals kanske tusentals fler personer på plats': 1,
#    'hjälpa människor för då hade man ju hjälpt så många man kan på plats': 1,
#    'hjälpa ska vi göra det tillsammans med övriga eu länder och i storlek till vårt lands befolkning riktade hjälpinsatser i den delen av världen hjälp till flyktingläger humanitär hjälp sjukvård på plats': 1,
#    'hjälpa så många fler om vi hjälpte människor på plats': 1,
#    'hjälpa till på plats': 5,
#    'hjälpa annat än på plats': 1,
#    'hjälpa många fler om vi hjälpte dem på plats': 1,
#    'hjälpa de som behöver det på plats': 1,
#    'hjälpa till att bygga upp länderna och hjälpa folk på plats': 1,
#    'hjälpa så många som möjligt på plats': 1,
#    'hjälpa fler negrer på plats': 1,
#    'hjälpa mångfaldigt fler om vi bara hjälpte människor på plats': 1,
#    'hjälpa negrerna på plats': 1,
#    'hjälpa fler människor på plats': 2,
#    'hjälpa folk här än på plats': 1,
#    'hjälpa minstmänniskor på plats': 1,
#    'hjälpa färre i sverige istället för miljontals fler på plats': 1,
#    'hjälpa de som verkligen behöver hjälp på plats': 1,
#    'hjälpa så få som möjligt fördygn i sverige i stället förkr dygn på plats': 1,
#    'hjälpa betydligt fler på plats': 1,
#    'hjälpa smutsfolket kan vi väl göra det på plats': 1,
#    'hjälpa folket på plats': 1,
#    'hjälper fler genom att hjälpa dem på plats': 1,
#    'hjälpa de på plats': 4,
#    'hjälpa otroligt många fler på plats': 1,
#    'hjälpa ska det vara på plats': 1,
#    'hjälpa varelser i nöd och då är detnejggr bättre att kanalisera deras empati ner dit till folket på plats': 1,
#    'hjälpa folk så gör man det på plats': 1,
#    'hjälpa till att lösa säkerheten på plats': 1,
#    'hjälpa tredjevärldenmänniskor så kan man hjälpa oerhört många fler på plats': 1,
#    'hjälpa krigsdrabbade folk på plats': 1,
#    'hjälpa folk där på plats': 1,
#    'hjälpa dig här på plats': 1,
#    'hjälpa dessa på traven du ser resultatet det enda som fungerar för såna här som för andra kriminella är benhårda regler tydliga strukturer och auktoriteter som sätter de på plats': 2,
#    'hjälpa är det bättre att hjälpa många flyktingar på plats': 1,
#    'hjälpa resten som är kvar där på plats': 1,
#    'hjälpa de i syrien på plats': 1,
#    'hjälpa faldt fler somalier på plats': 1,
#    'hjälpa de riktiga flyktingarna på plats': 1,
#    'hjälper direkt i de länder som har det svårt.inget fel i det att vi ska hjälpa utsatta länder men pengarna gör mer nyta på plats': 1,
#    'hjälpa många fler som dessutom har det sämre på plats': 1,
#    'hjälpa tio personer på plats': 1,
#    'hjälpa så många som möjligt skulle man kunna hjälpa långt fler på plats': 1,
#    'hjälpa många fler om man gör det på plats': 1,
#    'hjälpa dessa människor så får man betydligt större effekt att hjälpa dom på plats': 1,
#    'hjälpa folk på allvar så är det på plats': 1,
#    'hjälpa personer på plats': 2,
#    'hjälpa fiskarna tillbaka till vattnet och hjälpa dem på plats': 1,
#    'hjälpa dem som redan kommit hit att anpassa sig till det svenska samhället och de vill hjälpa dem som inte kommit hit på plats': 1,
#    'hjälpa till att bygga upp nationen somalia på plats': 1,
#    'hjälpa lika många människor på plats': 1,
#    'hjälpa ett mycket större antal på plats': 1,
#    'hjälpa en lyxturistfamilj här i sverige så kan vi hjälpa upp tillst riktigt nödställda familjer på plats': 1,
#    'hjälpa andra på plats': 1,
#    'hjälpa folk är fel fel fel felhjälp rätt människor på plats': 1,
#    'hjälpa flyktingar och bekämpa fattigdom är både effektivare enklare och framför allt billigare på plats': 1,
#    'hjälpa så många som möjligt så gör vi det bäst genom riktade insatser på plats': 1,
#    'hjälpa . av de fattiga i världen när vi skulle kunna hjälpa . av de utsatta på plats': 1,
#    'hjälpa tio gånger så många på plats': 1,
#    'hjälpa invandrare dock på ett sådant sätt att de inte börjar utgöra någon betydande andel av vår befolkning det kan ske genom ökad andel hjälp till hemländerna safe havens på plats': 1,
#    'hjälpa säkert tio gånger så många på plats': 1,
#    'hjälpa dessa flyktingar på plats': 1,
#    'hjälpa miljoner på plats': 2,
#    'hjälpa varför inte göra det på plats': 1,
#    'hjälpa upp tillggr mer människor på plats': 2,
#    'hjälpt flykting och är mera ineffektivt än att hjälpa dem på plats': 1,
#    'hjälpa till en tryggare framtid om vi hjälper de behövande på plats': 1,
#    'hjälpa i flyktinglägren på plats': 1,
#    'hjälpa människor i nöd är hedervärt och i min mening värt att eftersträva men det betyder inte att massinvandring till sverige är ett effektivt eller önskvärt tillvägagångssätt inte minst då man kan hjälpa betydligt fler på plats': 1,
#    'hjälpa på är genom att hjälpa dem på plats': 1,
#    'hjälpa dessa människor på plats': 2,
#    'hjälpa flera tiotals fattiga sjuka svaga och äldre personer på plats': 1,
#    'hjälpa fler sådana på plats': 1,
#    'hjälpa så många på plats': 1,
#    'hjälpa mera på plats': 1,
#    'hjälpa ofantligt mycket fler människor på plats': 1,
#    'hjälpa hundratals fler flyktingar på plats': 1,
#    'hjälpa mångfalt fler på plats': 1,
#    'hjälpa minstpersoner på plats': 1,
#    'hjälpa folk i krig och annat mest ?han vill hjälpa dem på plats': 1,
#    'hjälpa dem och hålla dem på plats': 1,
#    'hjälpa enormt många på plats': 2,
#    'hjälpa fler barn på plats': 1,
#    'hjälpa alla de miljoner och åter miljoner sjuka och fattiga på plats': 1,
#    'hjälpa människor så är det mycket effektivare att göra detta på plats': 1,
#    'hjälpa dom så ska vi hjälpa dom på plats': 1,
#    'hjälpa fattiga och utsatta på plats': 1,
#    'hjälpa folk mer på plats': 1,
#    'hjälpa fattiga asiater och afrikaner på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2014': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa svenskarna på plats': 1,
#    'hjälpa alla minst av allt här på plats': 1,
#    'hjälpa till sker genom projekt som tar plats i resp land på plats': 1,
#    'hjälpa rumänskor så är det bättre att hjälpa dem på plats': 1,
#    'hjälpa människor i krig och katastrof på plats': 1,
#    'hjälpa dom på plats': 8,
#    'hjälpa till på plats': 6,
#    'hjälpa folk i andra länder på plats': 1,
#    'hjälpa de på plats': 2,
#    'hjälpa folk på plats': 31,
#    'hjälpa svårt svältade människor på plats': 1,
#    'hjälpa dessa stackare på plats': 1,
#    'hjälpa de som har det svårt på plats': 1,
#    'hjälpa folket på plats': 1,
#    'hjälpa betydligt mer människor på plats': 1,
#    'hjälpa folk från denna del av världen så hjälper de fler av dem på plats': 1,
#    'hjälpa dessa människor i kris på plats': 1,
#    'hjälpa fler på plats': 15,
#    'hjälpa tusentals andra flyktingar på plats': 1,
#    'hjälpa över hundra gånger fler människor på plats': 1,
#    'hjälpa svältande på plats': 2,
#    'hjälpa en utvald familj som du pekar ut på plats': 1,
#    'hjälpa flyktingar på plats': 18,
#    'hjälpa dessa länder på på plats': 1,
#    'hjälpa dem på plats': 16,
#    'hjälpa x fler personer på plats': 1,
#    'hjälpa folk som är krisländer men man kan inte hjälpa alla och man ska hjälpa till på plats': 1,
#    'hjälpa måste hjälp på plats': 1,
#    'hjälpa x antal personer på plats': 1,
#    'hjälpa människor på plats': 20,
#    'hjälpa dessagånger fler på plats': 1,
#    'hjälpa st på plats': 1,
#    'hjälpa fler utsatta på plats': 1,
#    'hjälpa fler för samma pengar på plats': 1,
#    'hjälpa i på plats': 1,
#    'hjälpa så oerhört många fler människor på plats': 1,
#    'hjälpa fler människor på plats': 4,
#    'hjälpa de utsatta på plats': 3,
#    'hjälpa miljoner på plats': 1,
#    'hjälpa miljoner med folk på plats': 1,
#    'hjälpa de allra svagaste är på plats': 1,
#    'hjälpa nödlidande människor på plats': 1,
#    'hjälper till om fler skulle hjälpa till som sverige gör så skulle inte vi behöva ta emotom året och då skulle vi kunna lägga ännu mer pengar till att även hjälpa de på plats': 1,
#    'hjälpa araberna och negrerna på plats': 1,
#    'hjälpa många fler på plats': 4,
#    'hjälpa och hjälpadet enda jag menar är att det bättre att hjälpa människor på plats': 2,
#    'hjälpa sina medborgare på plats': 2,
#    'hjälpa romer med på plats': 2,
#    'hjälpa romerna på plats': 4,
#    'hjälpa dessa på plats': 4,
#    'hjälpa romer här och på plats': 2,
#    'hjälpa tiggarna på riktigt så skänker du istället dina pengar till röda korset i rumänien eller liknande organisationer på plats': 2,
#    'hjälpa ett fåtal genom att ge dem put eller hjälpa många fler på plats': 2,
#    'hjälpa de på dvs hjälpa dem på plats': 1,
#    'hjälpa alla utsatta grupper på plats': 1,
#    'hjälpa dem med statliga medel effektivt på plats': 1,
#    'hjälpa folk men på plats': 1,
#    'hjälpa folk hit men inte på plats': 1,
#    'hjälpa folket i ukraina på plats': 1,
#    'hjälpa hundratals kanske tusentals flyktingar på plats': 1,
#    'hjälpa mig på plats': 1,
#    'hjälpa hibo och hans familj där på plats': 1,
#    'hjälpa till med mycket mer på plats': 1,
#    'hjälpa åtskilligt fler på plats': 1,
#    'hjälpa folk i krigsländer på plats': 1,
#    'hjälpa bättre och fler på plats': 1,
#    'hjälpa flyktingarna på plats': 3,
#    'hjälpa tusen o åter tusen somalier som behöver hjälp dom kommande tjaåren tills planeten går under för dom kommer aldrig få fred där nere e det inte bättre o skicka ner mat till dom istället ?som sd säger bättre o hjälpa hundratusentals på plats': 1,
#    'hjälpa dessa människor på plats': 1,
#    'hjälpa fler för samma summa på plats': 1,
#    'hjälpa miljontals på plats': 1,
#    'hjälpa människorna på plats': 4,
#    'hjälpa folk men skicka för i helvete inte skiten hit till europa utan hjälp dom på plats': 1,
#    'hjälpa en person i sverige istället först på plats': 1,
#    'hjälpa folk i katastrofer . personer sprider information om det onlineidealister åker till platsen och bidrar med hjälp på plats': 1,
#    'hjälpa personer på plats': 1,
#    'hjälpa främlingarna på plats': 1,
#    'hjälpa mer flyktingar på plats': 1,
#    'hjälpa till med att få delegationen i arbete väl på plats': 1,
#    'hjälpa romer på plats': 2,
#    'hjälpa rumänien att stödja romerna på plats': 1,
#    'hjälpa människor så hjälper man på plats': 1,
#    'hjälpa betydligt fler på plats': 1,
#    'hjälpa andra människor så kan var man bestämma inom vilken utsträckning de vill göra det och hjälpen kommer då att ske på plats': 1,
#    'hjälpa och rädda folk på plats': 1,
#    'hjälpa bistå men på plats': 1,
#    'hjälpa fler av dem på plats': 1,
#    'hjälpa dem som är i behov på plats': 1,
#    'hjälpa alla på plats': 2,
#    'hjälpa personer i utsatta områden på plats': 1,
#    'hjälpa personerna på plats': 1,
#    'hjälpa de kristna på plats': 1,
#    'hjälpa de som verkligen behövde mest hjälp så skulle man till exempel låta folk söka asyl på plats': 1,
#    'hjälpa de som behöver hjälp genom att ta in dom men även hjälpa dom på plats': 1,
#    'hjälpa så många av dessa utsatta kvinnor som möjligt på plats': 1,
#    'hjälpa så många som möjligt på plats': 2,
#    'hjälpa människorna i syrien på plats': 1,
#    'hjälpa negrer på plats': 2,
#    'hjälpa . människor i ett fn finansierat flyktingläger på plats': 1,
#    'hjälpa till att bygga upp dessa länder på plats': 1,
#    'hjälpa många fler människor på plats': 1,
#    'hjälpa fler flyktingar på plats': 2,
#    'hjälpa dem i gränsländer eller på plats': 1,
#    'hjälpa länder på plats': 1,
#    'hjälpa många fler från att svälta ihjäl på plats': 1,
#    'hjälper några få till stor kostnad i sverige än att hjälpa många fler till samma kostnad på plats': 1,
#    'hjälpa folk på riktigt så hjälpte vi dem antingen på plats': 1,
#    'hjälpa utsatta människor på plats': 1,
#    'hjälpa till om kiev börjar agera aggressivt delvis hade de agenter på plats': 1,
#    'hjälpa till med rapporteringen på plats': 1,
#    'hjälpte judar ingen annanstans i det ockuperade europa riskerade lokalbefolkningen att avrättas för att hjälpa judar och då skulle givetsvis hela familjen även kvinnor och barn avrättas på plats': 1,
#    'hjälpa dem vare sig på plats': 2,
#    'hjälpa fler invandrare på plats': 1,
#    'hjälpa människor i nöd på plats': 1,
#    'hjälpa länderna på plats': 1,
#    'hjälpa och vi kan hjälpa miljoner fler på plats': 1,
#    'hjälpa ännu fler människor på plats': 1,
#    'hjälpa oss svenskar som e kvar så får du absolut inte tänka tanken att bjuda in oss till rumänien då hjälpa de utsatta på plats': 1,
#    'hjälpa mångdubbelt fler effektivt på plats': 1,
#    'hjälpa många på plats': 1,
#    'hjälpa ett gränslöst antal på plats': 1,
#    'hjälpa de fattigaste kvinnor och barn på plats': 1,
#    'hjälpa oerhört många mer på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa betydligt fler till betydligt lägre kostnader om vi sätter in hjälpen på plats': 1,
#    'hjälpa minstgånger så många på plats': 1,
#    'hjälpa barn på plats': 1,
#    'hjälpa hundra miljoner afrikaner på plats': 1,
#    'hjälpa tusen hibo på plats': 1,
#    'hjälpa tusen på plats': 1,
#    'hjälpa mer i närområdet till ni känslodöda monster svikeri detta ögonblick de allra svagaste människorna på plats': 1,
#    'hjälpa ett litet fåtal för dyra pengar än att hjälpa många på plats': 1,
#    'hjälpa miljontals flyktigar på plats': 1,
#    'hjälpa långt många fler människor på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2015': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa till på plats': 17,
#    'hjälpa till så gott vi kan på plats': 1,
#    'hjälpa dem här på plats': 1,
#    'hjälpa mer på plats': 9,
#    'hjälpa fler på plats': 21,
#    'hjälpa folk på plats': 68,
#    'hjälpa dem på plats': 26,
#    'hjälpa så många som möjligt på plats': 3,
#    'hjälpa människor i nöd skulle de givetvis göra det på plats': 1,
#    'hjälpa människor på plats': 22,
#    'hjälpa färre och färre på plats': 1,
#    'hjälpa flyktingarna på plats': 11,
#    'hjälpa en enormt större mängd människor på plats': 1,
#    'hjälpa flyktingar på plats': 25,
#    'hjälpa folket på plats': 2,
#    'hjälpa dom där det behövs som mest på plats': 1,
#    'hjälpa riktiga flyktingar på plats': 1,
#    'hjälpa människorna på plats': 2,
#    'hjälpa fler människor på plats': 3,
#    'hjälpa de mest utsatta på plats': 1,
#    'hjälpa romerna på plats': 1,
#    'hjälpa nödställda människor från avlägsna kulturer på plats': 1,
#    'hjälpa romer på plats': 1,
#    'hjälpa zigenarna på plats': 2,
#    'hjälpa er men det ska då göras på plats': 1,
#    'hjälpa dem en gång till på plats': 1,
#    'hjälpa mycket mer på plats': 1,
#    'hjälpa ändå på plats': 1,
#    'hjälper det ändå inte med att hjälpa dom på plats': 1,
#    'hjälpa dom på plats': 12,
#    'hjälpa så många fler på plats': 2,
#    'hjälpa mycket mer genom att investera samma pengar på plats': 1,
#    'hjälpa folk i flyktingläger eller på plats': 1,
#    'hjälpa fler flyktingar på plats': 1,
#    'hjälpa delvis på plats': 1,
#    'hjälpa många gånger fler personer på plats': 2,
#    'hjälpa folk direkt på plats': 1,
#    'hjälpa människor i nöd så gör vi det på ett ineffektivt och dyrt sätt som få har någon egentlig glädje av vi skulle kunna hjälpa så många fler om vi slutar envisas med att alla ska hjälpas på plats': 1,
#    'hjälpa så kallade flyktingar på plats': 1,
#    'hjälpa till mer på plats': 1,
#    'hjälpa och varför inte ge då till dessa organisationer som finns på plats': 1,
#    'hjälpa till och också med hjälp av gränspolissektionen och andra myndigheter som migrationsverket så kan vi få en fullgod gränskontroll där varje person som anländer snabbt kan få sitt ärende avklarat på plats': 1,
#    'hjälpa sjukt många på plats': 1,
#    'hjälpa otroligt många fler människor på plats': 1,
#    'hjälpa mångdubbelt fler på plats': 2,
#    'hjälpa människor men logiken säger att man kan hjälpa fler på plats': 1,
#    'hjälpa så många på plats': 1,
#    'hjälpa de stackars somalierna på plats': 1,
#    'hjälpa till i närområdet på plats': 1,
#    'hjälpa med bidrag på plats': 1,
# ...
#    'hjälpa romerna på plats': 1,
#    'hjälpa hundratvåhundra miljoner flyktingar på plats': 1,
#    'hjälpa till o bistå så är det bättre hjälpa fler på plats': 1,
#    'hjälpa tusentals riktiga barn på plats': 1,
#    'hjälpa dom på plats': 2,
#    'hjälpa folk så gör man det på plats': 1,
#    'hjälpa ett fåtal människor här i sverige är bättre människor än mig som vill hjälpa miljontals på plats': 1,
#    'hjälpa ett sådant land med sina problem är att hjälpa till på plats': 1,
#    'hjälpa de utvecklas på plats': 1,
#    'hjälpa med mat och sjukvård på plats': 1,
#    'hjälpa behövande på plats': 1,
#    'hjälpa en droppe i havet när man kunde hjälpt mångt fler på plats': 1,
#    'hjälpa barn på plats': 1,
#    'hjälpa många många fler på plats': 1,
#    'hjälpa pripyats barn på plats': 1,
#    'hjälpa andra på plats': 1,
#    'hjälpa både i vårt land och på plats': 1,
#    'hjälpa de som inte kan fly på plats': 1,
#    'hjälpa dessa sjuka terrorister på plats': 1,
#    'hjälpa irak att utreda och döma svenska isjihadister på plats': 1,
#    'hjälpa folk at flytta utan hjälpa folk på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa svårt utsatta exempelvis barn på plats': 1,
#    'hjälpa hundrafalt fler på plats': 1,
#    'hjälpa så mycket vi klarar på plats': 1,
#    'hjälpa afrikanerna på plats': 1,
#    'hjälpa dem som kommit hit att bli en del av vårt land och hjälpa till i humanitära krislägen på plats': 1,
#    'hjälpa solidariskt på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2018': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa flera på plats': 1,
#    'hjälpa andra helst genom hjälp till självhjälp på plats': 2,
#    'hjälpa dessa länder på plats': 2,
#    'hjälpa folk annat än på plats': 1,
#    'hjälpa till på plats': 3,
#    'hjälpa mena länder på plats': 1,
#    'hjälpa alla riktiga offer på plats': 1,
#    'hjälpa shemaleafghanen med tal krönikor och pamfletter men man är inte på plats': 1,
#    'hjälpa många ärligatals i hemlandet på plats': 1,
#    'hjälpa människor hade de bäst hjälps på plats': 1,
#    'hjälpa alla på plats': 1,
#    'hjälpa dem på plats': 8,
#    'hjälpa personer på plats': 1,
#    'hjälpa till med att införskaffa mat ge möjligheter till utbildning på plats': 1,
#    'hjälpa xxx xxx antal fler på plats': 1,
#    'hjälpa mer på plats': 1,
#    'hjälpa så många som möjligt så är det mest effektivt att hjälpa dem på plats': 1,
#    'hjälpa utomeuropéerna så står det dig fritt att flytta ner dit och hjälpa de på plats': 1,
#    'hjälpa fler på plats': 2,
#    'hjälpa folk på plats': 5,
#    'hjälpa dom på plats': 2,
#    'hjälpa flyktingar det hade i såfall skett på plats': 1,
#    'hjälpa människorna på plats': 1,
#    'hjälpa hjälp på plats': 1,
#    'hjälpa andra dock helst på plats': 1,
#    'hjälpa tusentals på plats': 1,
#    'hjälpa flyktingar på plats': 10,
#    'hjälpa så många som möjligt på plats': 1,
#    'hjälpa de nödställda på plats': 1,
#    'hjälpa ett outvecklat folk på plats': 1,
#    'hjälpa fler genom att hjälpa behövande på plats': 1,
#    'hjälper man inte lokalt när man kan hjälpast på plats': 1,
#    'hjälpa många fler riktiga flyktingar på plats': 1,
#    'hjälpa människor i nöd så borde du verka för att de som lider störst nöd blir hjälpta helst på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa till i deras strävanden men de skulle varit lite mer kyliga och väntat tills huvudnumret med talen var klar för att sedan sätta folkförrädarna på plats': 1,
#    'hjälpa fler hjälpbehövande på plats': 1,
#    'hjälpa mest på plats': 1,
#    'hjälpa kanske . personer på plats': 1,
#    'hjälpa människor i nöd på plats': 1,
#    'hjälpa fler människor på plats': 1,
#    'hjälpa människor på plats': 2,
#    'hjälpa verkligt nödlidande särskilt kvinnor och barn på plats': 1,
#    'hjälpa så många som möjligt då hade man förespråkat hjälp på plats': 1,
#    'hjälpa mueller att få ihop händelseförloppet och då faller allt på plats': 1,
#    'hjälpa människorna bort från dessa områden istället för att försöka hjälpa dem på plats': 1,
#    'hjälpa mer folk på plats': 1,
#    'hjälpa de fördrivna palestinierna på plats': 1,
#    'hjälpa de på plats': 1,
#    'hjälpa de allra mest utsatta på plats': 1,
#    'hjälpa så många flyktingar som möjligt t.ex. på plats': 1,
#    'hjälpa fler med hjälp på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2019': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa människor på plats': 4,
#    'hjälpa dem på plats': 8,
#    'hjälpa många många fler och mer behövande flyktingar på plats': 1,
#    'hjälpa var bra så länge vi hjälpte på avstånd på plats': 1,
#    'hjälpa dem som är mest utsatta och i störst behov av hjälp när vi istället kan hjälpa män som är starka nog att korsa kontinenter för att nå den svenska idyllen män som hade behövts på plats': 1,
#    'hjälpa långt fler än de som lyckas ta sig till sverige om pengarna använda på plats': 1,
#    'hjälpa folk på plats': 10,
#    'hjälpa fler på plats': 1,
#    'hjälpa sin familj på plats': 1,
#    'hjälpa folk varför hjälper man inte folk på plats': 1,
#    'hjälpa folket på plats': 1,
#    'hjälpa dessa invånare på plats': 1,
#    'hjälpa dessa folk ska det ske på plats': 1,
#    'hjälpa exempelvis somalier på plats': 1,
#    'hjälpa dem humanitärt på plats': 1,
#    'hjälpa flyktingar här istället för på plats': 1,
#    'hjälpa kvinnor och barn på plats': 1,
#    'hjälpa dem här eller på plats': 1,
#    'hjälpa till på plats': 4,
#    'hjälpa människor som de säger sig vilja så skulle pengarna som nu slösas bort kunnat användas på betydligt effektivare sätt på plats': 1,
#    'hjälpa människor kan denne åka till afghanistan och hjälpa folk på plats': 1,
#    'hjälpa behövande på plats': 1,
#    'hjälpa invandrare att slippa krig är endast lösningen att göra det på plats': 1,
#    'hjälpa i afrika på plats': 1,
#    'hjälpa sitt eget folk med utbildning på plats': 1,
#    'hjälpa henne på plats': 1,
#    'hjälpa lite på plats': 1,
#    'hjälpa länder på plats': 1,
#    'hjälpt om de spenderats på att hjälpa personerna på plats': 1,
#    'hjälpa flyktingar på plats': 3,
#    'hjälpa på ett reellt och verkligt sätt på plats': 1,
#    'hjälpa svenska emigranter redan på plats': 1,
#    'hjälpa jättebilligare på plats': 1,
#    'hjälpa fem gånger så många människor på plats': 1,
#    'hjälpa familjen alls men föräldrarna träffa en förre detta amerikansk elit soldat på plats': 1,
#    'hjälpa dem främst på plats': 1,
#    'hjälpa till med att ta hand om barnen för då hade hon stannat även om det fanns journalister på plats': 1,
#    'hjälpa andra människor så kan de gott få hjälp på plats': 1,
#    'hjälpa så många flyktingar det bara går och då är det just genom att hjälpa dem där de är på plats': 1,
#    'hjälpa de på plats': 1,
#    'hjälpa flyktingar gör det på plats': 1,
#    'hjälpa många fler på plats': 1,
#    'hjälpa flyktingar på riktigt är att hjälpa dem på plats': 1,
#    'hjälpa dessa utsatta grupper på plats': 1,
#    'hjälpa miljontals på plats': 1,
#    'hjälpa våldtäktsbenägna på plats': 1,
#    'hjälpa invandrare på plats': 1,
#    'hjälpa migranter redan på plats': 1,
#    'hjälpa långt många fler att överleva på plats': 1,
#    'hjälpa långt många fler på plats': 1,
#    'hjälper det föga hela eller åtminstone halva afrika och mellanöstern skulle behöva flytta till europa det handlar om ytterligaremiljoner därför är det bättre att hjälpa de på plats': 1,
#    'hjälpa vår miljö skulle vi satsa på att de flesta människor som befinner sig i fara kunde få hjälp på plats': 1,
#    'hjälpa miljontals människor på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2020': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa till på plats': 4,
#    'hjälpa till att administrera och sköta rättegången på plats': 1,
#    'hjälpa svenskar på plats': 1,
#    'hjälpa dem på plats': 3,
#    'hjälpa till med uppbyggnad av ndra välfungerande samhällen på plats': 1,
#    'hjälpa barnen på plats': 1,
#    'hjälpa hundratals människor på plats': 1,
#    'hjälpa massor av flyktingar på plats': 1,
#    'hjälpa någon på plats': 1,
#    'hjälpa andra länder på plats': 2,
#    'hjälpa somalierna på plats': 1,
#    'hjälpa länder som är i nöd på plats': 1,
#    'hjälpa länder på plats': 2,
#    'hjälpa folk på plats': 7,
#    'hjälpa andra länder direkt på plats': 1,
#    'hjälpa fler och bygga upp lander på plats': 1,
#    'hjälpa hjälp på plats': 1,
#    'hjälpa flyktingar på plats': 8,
#    'hjälpa fler på plats': 3,
#    'hjälpa araber och afrikaner att bygga välfärd på plats': 1,
#    'hjälpa långt fler människor på plats': 1,
#    'hjälpa andra fattiga och utsatta länder utan det ska manmen man ska alltid hjälpa i deras hemland på plats': 1,
#    'hjälpa dessa länder på plats': 1,
#    'hjälpa människor på plats': 3,
#    'hjälpa de som kan hjälpas på plats': 1,
#    'hjälpa så många människor som möjligt på plats': 1,
#    'hjälpa flyktingarna på plats': 1,
#    'hjälpa folk i nöd så skulle det ju vara effektivast och billigast att hjälpa dem på plats': 1,
#    'hjälpa sin åriga pojke på plats': 1,
#    'hjälpa honom på plats': 1,
#    'hjälpa de starkaste som kan ta sig hit bör vi hjälpa de svagaste på plats': 1,
#    'hjälpa lidande på plats': 1,
#    'hjälpa fattiga länder på plats': 1,
#    'hjälpa alla svältande på plats': 1,
#    'hjälpa människor hade man kunnat hjälpa fler med samma resurser på plats': 1,
#    'hjälpa dig utan där är försäkringsbolag först på plats': 1,
#    'hjälpa flera miljoner på plats': 1,
#    'hjälpa migranterna på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2021': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa flyktingar på plats': 6,
#    'hjälpa folk på plats': 7,
#    'hjälpa till mer effektivt på plats': 1,
#    'hjälpa dem far till afghanistan och hjälp de på plats': 1,
#    'hjälpa fler människor på plats': 1,
#    'hjälpa fler på plats': 2,
#    'hjälpa till så måste man göra det i deras hemländer och alldrig ta hit dom det kommer alltid att finnas fattiga i världen och lösningen är inte att ta dom hit utan hjälpa dom utvecklas på plats': 1,
#    'hjälpa betydligt fler på plats': 1,
#    'hjälpa dem är det effektivast på plats': 1,
#    'hjälpa maximalt antal flyktingar för samma summa är det effektivare med hjälp på plats': 1,
#    'hjälpa hjälper man väl alla på plats': 1,
#    'hjälpa drabbade personer på plats': 1,
#    'hjälpa fattiga länder ekonomiskt inte bara genom att skicka bidrag till dem som man redan gör till exempelvis afrikanska länder men att också ta in hundratusentals afrikaner till sverige och utbilda dem här på plats': 1,
#    'hjälpa mobilt på plats': 1,
#    'hjälpa folk så gör man det såklart på plats': 1,
#    'hjälpa klimatflyktingarna på plats': 1,
#    'hjälpa behövande på plats': 1,
#    'hjälpa till på plats': 3,
#    'hjälpa dem på plats': 1,
#    'hjälpa esbjörn att eftersöka ledsagaren om denne nu inte var på plats': 1,
#    'hjälpa betydligt fler människor i närområdet eller på plats': 1,
#    'hjälpa andra människor på plats': 1,
#    'hjälpa flera miljoner fler människor på plats': 1,
#    'hjälpa sina egna först innan man börjar hjälpa andra särskilt såsom sverige gjort hade räckt med hjälp på plats': 1,
#    'hjälpa ett fåtal män i sverige istället för att försöka göra världen bättre på plats': 1,
#    'hjälpa människor på plats': 2,
#    'hjälpa folk det handlade om hjälp på plats': 1,
#    'hjälpa till med antingen trupp på plats': 1,
#    'hjälpa dessa stackare på plats': 1,
#    'hjälpa dessa stackars familjer på plats': 1,
#    'hjälpa till med utbygganden av den obrutna kylkedja som måste till för att kunna genomföra covid vaccineringen men det går långsamt och även med den på plats': 1,
#    'hjälpa henne med att flytta möbler så kan jag bara göra det på plats': 1,
#    'hjälpa mer på plats': 1,
#    'hjälpa oss här på plats': 1,
#    'hjälpa afghanistan på plats': 1,
#    'hjälpa till ska man skicka en slant till ideella organisationer som hjälper till att starta upp business på plats': 1,
#    'hjälpa mycket mer effektivt och billigt på plats': 1},
#   'självständig_utrikespolitik': {}},
#  '2022': {'förortsgäng': {},
#   'förortsgängX': {},
#   'återvandring': {},
#   'återvandrare': {},
#   'återvandrande': {},
#   'återvandringsX': {},
#   'återvandrarX': {},
#   'återvandra': {},
#   'berikare': {},
#   'berikarX': {},
#   'berika': {},
#   'kulturberikare': {},
#   'kulturberikarX': {},
#   'kulturberika': {},
#   'ordning_och_reda_i_flyktingpolitiken': {},
#   'globalist': {},
#   'globalistX': {},
#   'globalistisk': {},
#   'hjälpa_på_plats': {},
#   'hjälpa_X_på_plats': {'hjälpa dem på plats': 4,
#    'hjälpa afrikaner mm är det bra med ekonomiskt bistånd på plats': 1,
#    'hjälpa dessa grannar på plats': 1,
#    'hjälpa ukraina med lite bistånd på plats': 1,
#    'hjälpa folk på plats': 2,
#    'hjälpa dom såklart både dom som tar sig hit och på plats': 1,
#    'hjälper väldigt få flyktingar eftersom det är dyrt att hjälpa dem på plats': 1,
#    'hjälpa dessa brottslingar vore på plats': 1,
#    'hjälpa så många fler på plats': 1,
#    'hjälpa de länder som har det mindre bra ställt men på plats': 1,
#    'hjälpa till på plats': 7,
#    'hjälpa människor på plats': 2,
#    'hjälpa civilbefolkningen både på plats': 1,
#    'hjälpa ukraina på plats': 2,
#    'hjälpa dom på plats': 2,
#    'hjälpa ukraina nu med militär på plats': 1,
#    'hjälpa ukrainare så tryck på den svenska regeringen att ta emot flyktingarna istället så kan vi hjälpa dom här på plats': 1,
#    'hjälpa barn på plats': 1,
#    'hjälpa oss militärt på plats': 1,
#    'hjälpa till med utredningen även ngos som human rights watch är på plats': 1,
#    'hjälpa de som flydde is och muslimextremisterna som startar krig överallt på plats': 1,
#    'hjälpa till att utreda de ryska krigsbrotten norr om kiev på plats': 1,
#    'hjälpa till och att sätta ryssland på plats': 1,
#    'hjälpa till då du som är så mogen och duktig och vet att sätta alla andra på plats': 1,
#    'hjälpa civila på plats': 1,
#    'hjälpa till ekonomiskt och hjälpa till med att få en ordnad demokrati på plats': 1,
#    'hjälpa slaver på plats': 1,
#    'hjälpa ryssland eller de illegala s.k. statsbildningarna i östra ukraina får väl åka dit och hjälpa till på plats': 1,
#    'hjälpa flyktingar på plats': 3,
#    'hjälpa och den huvudsakliga hjälpen bör ges på plats': 1,
#    'hjälpa och stödja på plats': 1,
#    'hjälpa människor på flykt på plats': 1,
#    'hjälpa dem och att vi kulturellt ligger närmre ukraina är afghanistan det är självklart men sds paradgren och det man tjatar om i sju är är hjälp på plats': 1,
#    'hjälpa de på plats': 1,
#    'hjälpa till om det är någon katastrof fast på plats': 1,
#    'hjälpa mer på plats': 1},
#   'självständig_utrikespolitik': {}}}

# %%
with open(output_dir / "radical3.json", "w") as f:
    f.write(json.dumps(dd))

# %%
for year in dd.keys():
    print(year)
    for lemma in dd[year].keys():
        tot = sum(dd[year][lemma].values())
        if tot > 0:
            print(lemma.upper(), f"(n={tot})")
            for word, count in dd[year][lemma].items():
                print("\t", word, count)
