# %%
import xml.etree.ElementTree as ET
import re
from string import punctuation
from os.path import exists, getsize
from os import listdir, remove
from pathlib import Path
import json
import time
import tracemalloc

# %% [markdown]
# https://www.geeksforgeeks.org/monitoring-memory-usage-of-a-running-python-program/

# %%
file_path = "/home/max/datasets/flashback-mat.xml"

# %% [markdown]
# #### Structure 1

# %%
threshold = 200
with open(file_path, "r") as f:
    for i, line in enumerate(f):
        if i < threshold:
            print(line.strip("\n"))
        else:
            break
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <!--
# Sparv version: 5.1.1dev0
# Annotation date: '2023-01-18'
# -->
# <corpus id="flashback-mat">
#   <forum id="109" title="Mat, dryck &amp; tobak &gt; Tobak" url="https://www.flashback.org/f109">
#     <thread id="1940381" lastpost="2012-08-21 17:28" postcount="132" title="28 år gammal nekad att köpa tobak trots leg." url="https://www.flashback.org/t1940381">
#       <text _id="36208d5" blingbring="|brunt:56.256|inskränkning:46.572|billighet:44.019|" date="2012-08-17 10:22" datefrom="20120817" dateto="20120817" id="38875452" lix="47.29" nk="0.97" ovix="70.62" swefn="|Control:729.062|Committing_crime:333.79|Adjusting:213.853|" timefrom="102200" timeto="102259" url="https://www.flashback.org/p38875452#p38875452" userid="343908" username="Terrarie">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3623b529">
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="+A" lemma="|istället|" lex="|istället..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="1" sense="|i_stället..1:-1.000|" swefn="|" ufeats="|">Istället</token>
#             <token _tail="\s\s" blingbring="|kraftmedel|nytta|" complemgram="|" compwf="|" dephead="8" deprel="MS" lemma="|fungera|" lex="|fungera..vb.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|fungera..1:0.798|fungera..2:0.174|fungera..3:0.028|" sentiment_label="positive" sentiment_score="1" swefn="|Being_operational|" ufeats="|VerbForm=Inf|Voice=Act|">fungera</token>
#             <token _tail="\s" blingbring="|inskränkning|ledning|motstånd|prövning|skydd|" complemgram="|kont..nn.1+roll..nn.1:1.938e-13|kont..nn.1+roller..nn.1:1.938e-13|" compwf="|kont+rollerna|" dephead="2" deprel="SS" lemma="|kontroll|" lex="|kontroll..nn.2|" msd="NN.UTR.PLU.DEF.NOM" msd_annotator="stanza" pos="NN" ref="3" sense="|kontroll..2:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Control|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Plur|">kontrollerna</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SP" lemma="|" lex="|" msd="KN" msd_annotator="stanza" pos="KN" ref="4" sense="|" swefn="|" ufeats="|">som</token>
#             <token _tail="\s" blingbring="|enhetlighet|grad|identitet|likhet|riktighet|rätt|särskildhet|" complemgram="|" compwf="|" dephead="6" deprel="CA" lemma="|just|" lex="|just..ab.1|just..av.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="5" sense="|just..1:0.590|schyst..1:0.310|just..2:0.100|" swefn="|" ufeats="|">just</token>
#             <token blingbring="|inskränkning|ledning|motstånd|prövning|skydd|" complemgram="|kont..nn.1+roll..nn.1:5.546e-13|kont..nn.1+roller..nn.1:5.546e-13|" compwf="|kont+roller|" dephead="4" deprel="UA" lemma="|kontroll|" lex="|kontroll..nn.2|" msd="NN.UTR.PLU.IND.NOM" msd_annotator="stanza" pos="NN" ref="6" sense="|kontroll..2:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Control|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Plur|">kontroller</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IK" lemma="|" lex="|" msd="MID" msd_annotator="stanza" pos="MID" ref="7" sense="|" swefn="|" ufeats="|">,</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" deprel="ROOT" lemma="|och|" lex="|och..kn.1|" msd="KN" msd_annotator="stanza" pos="KN" ref="8" sense="|och..1:-1.000|" swefn="|" ufeats="|">och</token>
#             <token _tail="\s" blingbring="|kallblodighet|kvarhållande|raskhet|seghet|vanlighet|varaktighet|vidröring|övertygelse|" complemgram="|håll..nn.1+le..vb.1:1.366e-11|hål..nn.1+le..vb.1:6.026e-12|håla..nn.1+le..vb.1:6.026e-12|hålla..vb.1+le..vb.1:1.674e-13|håla..vb.1+le..vb.1:9.414e-22|" compwf="|håll+ler|hål+ler|" dephead="8" deprel="+F" lemma="|hålla|" lex="|hålla..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="9" sense="|hålla..1:0.321|hålla..3:0.225|hålla..7:0.176|hålla..6:0.084|hålla..2:0.059|hålla..5:0.054|hålla..8:0.046|hålla..4:0.035|" sentiment_label="neutral" sentiment_score="0" swefn="|Manipulation|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">håller</token>
#             <token _tail="\s" blingbring="|förening|inbegrepp|människa|" complemgram="|person..nn.1+al..nn.1:5.741e-12|" compwf="|person+alen|per+son+alen|" dephead="9" deprel="OO" lemma="|personal|" lex="|personal..nn.1|personal..nn.2|" msd="NN.UTR.SIN.DEF.NOM" msd_annotator="stanza" pos="NN" ref="10" sense="|personal..1:0.609|personal..2:0.391|" sentiment_label="neutral" sentiment_score="0" swefn="|Employing|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">personalen</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="9" deprel="RA" lemma="|på|på alerten|" lex="|på..pp.1|på_alerten..avm.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="11" sense="|på..1:-1.000|på_alerten..1:-1.000|" swefn="|" ufeats="|">på</token>
#             <token _tail="\s" blingbring="|" complemgram="|al..nn.1+era..nn.1+ten..nn.1:3.300e-26|" compwf="|al+er+ten|" dephead="11" deprel="PA" lemma="|på alerten:11|" lex="|på_alerten..avm.1:11|" msd="NN.UTR.SIN.DEF.NOM" msd_annotator="stanza" pos="NN" ref="12" sense="|på_alerten..1:11:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">alerten</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="9" deprel="CA" lemma="|" lex="|" msd="AB.AN" msd_annotator="stanza" pos="AB" ref="13" sense="|" swefn="|" ufeats="|Abbr=Yes|">ang.</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="15" deprel="DT" lemma="|" lex="|" msd="NN.AN" msd_annotator="stanza" pos="NN" ref="14" sense="|" swefn="|" ufeats="|Abbr=Yes|">leg.</token>
#             <token blingbring="|inskränkning|ledning|motstånd|prövning|skydd|" complemgram="|kont..nn.1+roll..nn.1:5.546e-13|kont..nn.1+roller..nn.1:5.546e-13|" compwf="|kont+roller|" dephead="9" deprel="OO" lemma="|kontroll|" lex="|kontroll..nn.2|" msd="NN.UTR.PLU.IND.NOM" msd_annotator="stanza" pos="NN" ref="15" sense="|kontroll..2:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Control|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Plur|">kontroller</token>
#             <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="8" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="16" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="198812" lastpost="2005-04-16 15:28" postcount="48" title="Vackra, rökande människor?" url="https://www.flashback.org/t198812">
#       <text _id="3629998" blingbring="|fördunstning:62.505|växtriket:32.471|magi:20.116|" date="2005-04-08 11:57" datefrom="20050408" dateto="20050408" id="2085780" lix="28.87" nk="0.32" ovix="46.36" swefn="|Ingest_substance:320.132|Addiction:285.83|Reasoning:69.796|" timefrom="115700" timeto="115759" url="https://www.flashback.org/p2085780#p2085780" userid="72881" username="Beldaran">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362b12fd">
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SS" lemma="|jag|" lex="|jag..pn.1|" msd="PN.UTR.SIN.DEF.SUB" msd_annotator="stanza" pos="PN" ref="1" sense="|jag..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">Jag</token>
#             <token _tail="\s" blingbring="|besittning|egendom|frändskap|inre väsen|misshag|" complemgram="|" compwf="|" deprel="ROOT" lemma="|ha|" lex="|ha..vb.1|" msd="VB.PRT.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|ha..3:0.524|ha..1:0.476|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Mood=Ind|Tense=Past|VerbForm=Fin|Voice=Act|">hade</token>
#             <token _tail="\s" blingbring="|behag|kärlek|smaklighet|vänskap|åtrå|" complemgram="|" compwf="|" dephead="2" deprel="VG" lemma="|tycka|tycka om|" lex="|tycka..vb.1|tycka_om..vbm.1|" msd="VB.SUP.AKT" msd_annotator="stanza" pos="VB" ref="3" sense="|tycka..1:-1.000|tycka_om..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Experiencer_focus|" ufeats="|VerbForm=Sup|Voice=Act|">tyckt</token>
#             <token _tail="\s" blingbring="|identitet|jämförelse|" complemgram="|" compwf="|" dephead="5" deprel="AA" lemma="|lika|" lex="|lika..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="4" sense="|lika..1:-1.000|" swefn="|" ufeats="|">lika</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="AA" lemma="|" lex="|" msd="AB" msd_annotator="stanza" pos="AB" ref="5" sense="|" swefn="|" ufeats="|">illa</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="OA" lemma="|om|" lex="|om..pp.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="6" sense="|om..1:-1.000|om..5:-1.000|" swefn="|" ufeats="|">om</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="6" deprel="PA" lemma="|rökning|" lex="|rökning..nn.1|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="7" sense="|rökning..1:0.969|rökning..2:0.031|" swefn="|Ingest_substance|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">rökning</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="AA" lemma="|om|tycka om:3|" lex="|om..sn.1|tycka_om..vbm.1:3|" msd="SN" msd_annotator="stanza" pos="SN" ref="8" sense="|om..2:-1.000|om..3:-1.000|tycka_om..1:3:-1.000|" swefn="|" ufeats="|">om</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="10" deprel="SS" lemma="|jag|" lex="|jag..pn.1|" msd="PN.UTR.SIN.DEF.SUB" msd_annotator="stanza" pos="PN" ref="9" sense="|jag..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">jag</token>
#             <token _tail="\s" blingbring="|alstring|höjning|längd|storhet|tilltagande|utvidgning|vidd|växt|växtriket|övergång|" complemgram="|" compwf="|" dephead="8" deprel="UA" lemma="|växa|växa upp|" lex="|växa..vb.1|växa_upp..vbm.1|" msd="VB.SUP.AKT" msd_annotator="stanza" pos="VB" ref="10" sense="|växa..1:0.936|växa..2:0.054|växa..3:0.010|växa_upp..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Expansion_mod|" ufeats="|VerbForm=Sup|Voice=Act|">växt</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="10" deprel="PL" lemma="|upp|växa upp:10|" lex="|upp..ab.1|växa_upp..vbm.1:10|" msd="PL" msd_annotator="stanza" pos="PL" ref="11" sense="|upp..1:-1.000|växa_upp..1:10:-1.000|" swefn="|" ufeats="|">upp</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="10" deprel="RA" lemma="|i|" lex="|i..pp.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="12" sense="|i..2:-1.000|" swefn="|" ufeats="|">i</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="14" deprel="DT" lemma="|en|" lex="|en..al.1|" msd="DT.UTR.SIN.IND" msd_annotator="stanza" pos="DT" ref="13" sense="|den..1:-1.000|en..2:-1.000|" swefn="|" ufeats="|Definite=Ind|Gender=Com|Number=Sing|">en</token>
#             <token _tail="\s" blingbring="|alstring|frändskap|förening|härkomst|klass|människa|samling|" complemgram="|" compwf="|" dephead="12" deprel="PA" lemma="|familj|" lex="|familj..nn.1|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="14" sense="|familj..1:0.988|familj..2:0.012|" sentiment_label="neutral" sentiment_score="0" swefn="|Kinship|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">familj</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="17" deprel="RA" lemma="|där|" lex="|där..ab.1|" msd="HA" msd_annotator="stanza" pos="HA" ref="15" sense="|där..1:-1.000|" swefn="|" ufeats="|">där</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="17" deprel="SS" lemma="|ingen|" lex="|ingen..pn.1|" msd="PN.UTR.SIN.IND.SUB+OBJ" msd_annotator="stanza" pos="PN" ref="16" sense="|ingen..1:-1.000|" swefn="|" ufeats="|Case=Acc,Nom|Definite=Ind|Gender=Com|Number=Sing|">ingen</token>
#             <token blingbring="|fördunstning|inrymning|njutning|smakstyrka|värme|" complemgram="|" compwf="|" dephead="14" deprel="ET" lemma="|röka|" lex="|röka..vb.1|" msd="VB.PRT.AKT" msd_annotator="stanza" pos="VB" ref="17" sense="|röka..1:0.973|röka..2:0.027|" sentiment_label="neutral" sentiment_score="0" swefn="|Ingest_substance|" ufeats="|Mood=Ind|Tense=Past|VerbForm=Fin|Voice=Act|">rökte</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="18" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="655616" lastpost="2010-06-11 08:21" postcount="80" title="Snus - förbjudet i finland" url="https://www.flashback.org/t655616">
#       <text _id="362f9e9" blingbring="|vettlöshet:85.173|löjlighet:67.968|betingelse:45.57|" date="2009-05-20 22:07" datefrom="20090520" dateto="20090520" id="16768916" lix="31.22" nk="0.17" ovix="inf" swefn="|Arranging:475.348|Likelihood:54.755|Intentionally_act:29.381|" timefrom="220700" timeto="220759" url="https://www.flashback.org/p16768916#p16768916" userid="242678" username="Attjagorkar">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362639c9">
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SS" lemma="|den|" lex="|den..pn.1|" msd="PN.NEU.SIN.DEF.SUB+OBJ" msd_annotator="stanza" pos="PN" ref="1" sense="|den..2:-1.000|" swefn="|" ufeats="|Case=Acc,Nom|Definite=Def|Gender=Neut|Number=Sing|">Det</token>
#             <token _tail="\s" blingbring="|förtid|långvarighet|varaktighet|" complemgram="|" compwf="|" deprel="ROOT" lemma="|vara|" lex="|vara..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|vara..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Existence|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">är</token>
#             <token _tail="\s" blingbring="|ental|grad|obetydlighet|uteslutning|" complemgram="|" compwf="|" dephead="2" deprel="CA" lemma="|bara|" lex="|bara..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="3" sense="|bara..1:-1.000|" swefn="|" ufeats="|">bara</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="VG" lemma="|fixa|" lex="|fixa..vb.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="4" sense="|fixa..1:0.811|fixa..3:0.081|fixa..2:0.064|fixa..4:0.044|" swefn="|Arranging|" ufeats="|VerbForm=Inf|Voice=Act|">fixa</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="6" deprel="DT" lemma="|en|" lex="|en..al.1|" msd="DT.UTR.SIN.IND" msd_annotator="stanza" pos="DT" ref="5" sense="|den..1:-1.000|en..2:-1.000|" swefn="|" ufeats="|Definite=Ind|Gender=Com|Number=Sing|">en</token>
#             <token blingbring="|" complemgram="|post..nn.1+kran..nn.1:1.860e-11|post..nn.2+kran..nn.1:1.860e-11|post..sxc.1+kran..nn.1:1.860e-11|" compwf="|post+kran|" dephead="4" deprel="OO" lemma="|postkran|" lex="|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="6" sense="|" swefn="|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">postkran</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="4" deprel="IK" lemma="|" lex="|" msd="MID" msd_annotator="stanza" pos="MID" ref="7" sense="|" swefn="|" ufeats="|">,</token>
#             <token _tail="\s" blingbring="|betingelse|framtid|möjlighet|omständighet|ovisshet|slump|tidsförhållande|" complemgram="|" compwf="|" dephead="9" deprel="AA" lemma="|eventuell|" lex="|eventuell..av.1|" msd="AB.POS" msd_annotator="stanza" pos="AB" ref="8" sense="|eventuell..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Likelihood|" ufeats="|Degree=Pos|">eventuellt</token>
#             <token _tail="\s" blingbring="|anvisning|arbete|bekräftelse|bevis|göromål|räkning|viktighet|" complemgram="|" compwf="|" dephead="2" deprel="MS" lemma="|göra|" lex="|göra..vb.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="9" sense="|göra..1:0.575|göra..3:0.271|göra..2:0.154|" sentiment_label="neutral" sentiment_score="0" swefn="|Intentionally_act|" ufeats="|VerbForm=Inf|Voice=Act|">göra</token>
#             <token blingbring="|avvikelse|besittning|egendom|inre väsen|löjlighet|sinnesart|särskildhet|söndring|vettlöshet|" complemgram="|" compwf="|" dephead="9" deprel="OO" lemma="|egen|" lex="|egen..av.1|" msd="JJ.POS.NEU.SIN.IND+DEF.NOM" msd_annotator="stanza" pos="JJ" ref="10" sense="|egen..1:0.933|egen..2:0.067|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Case=Nom|Definite=Def,Ind|Degree=Pos|Gender=Neut|Number=Sing|">eget</token>
#             <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="11" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1844691" lastpost="2012-04-15 23:19" postcount="14" title="Köpt en stock Knox, väldigt torrt?" url="https://www.flashback.org/t1844691">
#       <text _id="3626cd0" blingbring="|osmak:259.873|grundhet:244.904|ringaktning:163.179|" date="2012-04-12 18:33" datefrom="20120412" dateto="20120412" id="36775856" lix="49.86" nk="0.50" ovix="inf" swefn="|Typicality:202.141|Measurable_attributes:142.499|" timefrom="183300" timeto="183359" url="https://www.flashback.org/p36775856#p36775856" userid="528383" username="Jugdish">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362b58b3">
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SS" lemma="|" lex="|" msd="PM.NOM" msd_annotator="stanza" pos="PM" ref="1" sense="|" swefn="|" ufeats="|Case=Nom|">Knox</token>
#             <token _tail="\s" blingbring="|" complemgram="|in..ab.1+hålla..vb.1:3.728e-08|in..ab.1+håll..nn.1+le..vb.1:8.135e-16|in..ab.1+hål..nn.1+le..vb.1:3.589e-16|in..ab.1+håla..nn.1+le..vb.1:3.589e-16|in..ab.1+hålla..vb.1+le..vb.1:2.018e-20|in..ab.1+håla..vb.1+le..vb.1:1.135e-28|" compwf="|in+håller|in+håll+ler|in+hål+ler|" deprel="ROOT" lemma="|inhålla|" lex="|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|" swefn="|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">inhåller</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="5" deprel="DT" lemma="|en|" lex="|en..al.1|" msd="DT.UTR.SIN.IND" msd_annotator="stanza" pos="DT" ref="3" sense="|den..1:-1.000|en..2:-1.000|" swefn="|" ufeats="|Definite=Ind|Gender=Com|Number=Sing|">en</token>
#             <token _tail="\s" blingbring="|botten|grundhet|hopkrympning|ljudsvaghet|obehag|osmak|oviktighet|plebej|ringaktning|sänkning|underlägsenhet|utsträckning|" complemgram="|" compwf="|" dephead="5" deprel="AT" lemma="|låg|" lex="|låg..av.1|" msd="JJ.KOM.UTR+NEU.SIN+PLU.IND+DEF.NOM" msd_annotator="stanza" pos="JJ" ref="4" sense="|låg..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Measurable_attributes|" ufeats="|Case=Nom|Definite=Def,Ind|Degree=Cmp|Gender=Com,Neut|Number=Plur,Sing|">lägre</token>
#             <token _tail="\s" blingbring="|" complemgram="|fukt..nn.1+halt..nn.1:2.579e-12|fukt..nn.1+halt..nn.2:2.579e-12|fukta..vb.1+halt..nn.1:3.022e-21|fukta..vb.1+halt..nn.2:3.022e-21|" compwf="|fukt+halt|" dephead="2" deprel="OO" lemma="|fukthalt|" lex="|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="5" sense="|" swefn="|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">fukthalt</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="5" deprel="ET" lemma="|" lex="|" msd="KN" msd_annotator="stanza" pos="KN" ref="6" sense="|" swefn="|" ufeats="|">än</token>
#             <token blingbring="|fullkomlighet|gott|hälsa|inre väsen|måttfullhet|ordning|tillräcklighet|vana|vett|överensstämmelse|" complemgram="|" compwf="|" dephead="6" deprel="UA" lemma="|normal|" lex="|normal..av.1|" msd="AB.POS" msd_annotator="stanza" pos="AB" ref="7" sense="|normal..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Typicality|" ufeats="|Degree=Pos|">normalt</token>
#             <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="8" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3490934" lastpost="2022-12-10 17:07" postcount="410" title="EU föreslår skattechock för snus  priset kan dubblas" url="https://www.flashback.org/t3490934">
#       <text _id="362c02b" blingbring="|stank:181.859|utskärning:70.838|formvidrighet:65.57|" date="2022-11-27 19:16" datefrom="20221127" dateto="20221127" id="82559492" lix="36.14" nk="1.14" ovix="105.34" swefn="|Being_rotted:1439.027|Manner_of_life:240.281|Musical_instruments:106.047|" timefrom="191600" timeto="191659" url="https://www.flashback.org/p82559492#p82559492" userid="1140074" username="Gulblendkarringen">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362bebb6">
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SS" lemma="|Ni|ni|" lex="|Ni..pn.1|ni..pn.1|" msd="PN.UTR.SIN.DEF.SUB" msd_annotator="stanza" pos="PN" ref="1" sense="|ni..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">Ni</token>
#             <token _tail="\s" blingbring="|framtid|synsinne|" complemgram="|" compwf="|" deprel="ROOT" lemma="|se|se ut|" lex="|se..vb.1|se_ut..vbm.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|ses..1:0.333|se..4:0.192|se..5:0.135|se..1:0.132|se..2:0.106|se..6:0.057|se..3:0.044|se_ut..1:-1.000|se_ut..2:-1.000|se_ut..3:-1.000|se_ut..4:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">ser</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="XA" lemma="|för|" lex="|för..pp.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="3" sense="|för..1:-1.000|för..5:-1.000|för..6:-1.000|för..7:-1.000|för..9:-1.000|" swefn="|" ufeats="|">för</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="5" deprel="AA" lemma="|" lex="|" msd="AB" msd_annotator="stanza" pos="AB" ref="4" sense="|" swefn="|" ufeats="|">jävla</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="OP" lemma="|panta|pantad|" lex="|panta..vb.1|pantad..av.1|" msd="PC.PRF.UTR+NEU.PLU.IND+DEF.NOM" msd_annotator="stanza" pos="PC" ref="5" sense="|panta..1:0.567|pantad..1:0.314|pantad..2:0.119|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Case=Nom|Definite=Def,Ind|Gender=Com,Neut|Number=Plur|Tense=Past|VerbForm=Part|">pantade</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="PL" lemma="|ut|se ut:2|" lex="|ut..ab.1|se_ut..vbm.1:2|" msd="PL" msd_annotator="stanza" pos="PL" ref="6" sense="|ut..1:0.810|ut..2:0.190|se_ut..1:2:-1.000|se_ut..2:2:-1.000|se_ut..3:2:-1.000|se_ut..4:2:-1.000|" swefn="|" ufeats="|">ut</token>
#             <token blingbring="|vidfogning|" complemgram="|" compwf="|" dephead="2" deprel="+A" lemma="|också|" lex="|också..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="7" sense="|också..1:-1.000|" swefn="|" ufeats="|">också</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="8" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3495409" lastpost="2022-12-30 22:35" postcount="307" title="Snusare dör i förtid !!" url="https://www.flashback.org/t3495409">
#       <text _id="362a607" blingbring="|glupskhet:162.367|oförvägenhet:37.783|misstydning:34.604|" date="2022-12-17 16:28" datefrom="20221217" dateto="20221217" id="82792403" lix="36.96" nk="1.00" ovix="112.57" swefn="|Intoxicants:110.322|Run_risk:90.487|Cotheme:53.778|" timefrom="162800" timeto="162859" url="https://www.flashback.org/p82792403#p82792403" userid="637216" username="Triremer">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362591c1">
#             <token _tail="\s" blingbring="|avstånd|fortsättning|framåtskridande|sammanhang|vidfogning|" complemgram="|" compwf="|" dephead="2" deprel="+A" lemma="|vid|vidare|" lex="|vid..av.1|vidare..ab.1|" msd="AB.KOM" msd_annotator="stanza" pos="AB" ref="1" sense="|vidare..1:0.846|vid..2:0.154|" swefn="|" ufeats="|Degree=Cmp|">Vidare</token>
#             <token _tail="\s" blingbring="|antagande|betydelse|eftertanke|förhoppning|sannolikhet|troslära|visshet|övertygelse|" complemgram="|" compwf="|" deprel="ROOT" lemma="|tro|" lex="|tro..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|tro..1:0.943|tro..3:0.057|" sentiment_label="neutral" sentiment_score="0" swefn="|Awareness|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">tror</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="SS" lemma="|jag|" lex="|jag..pn.1|" msd="PN.UTR.SIN.DEF.SUB" msd_annotator="stanza" pos="PN" ref="3" sense="|jag..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">jag</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="OO" lemma="|att|" lex="|att..sn.1|" msd="SN" msd_annotator="stanza" pos="SN" ref="4" sense="|att..1:-1.000|" swefn="|" ufeats="|">att</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="7" deprel="SS" lemma="|" lex="|" msd="NN.UTR.PLU.IND.NOM" msd_annotator="stanza" pos="NN" ref="5" sense="|" swefn="|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Plur|">snusare</token>
#             <token _tail="\s" blingbring="|upprepning|" complemgram="|" compwf="|" dephead="7" deprel="TA" lemma="|ofta|" lex="|ofta..ab.1|" msd="AB.KOM" msd_annotator="stanza" pos="AB" ref="6" sense="|ofta..1:-1.000|" swefn="|Frequency|" ufeats="|Degree=Cmp|">oftare</token>
#             <token _tail="\s" blingbring="|bevis|bevisföring|företeelse|meddelande|riktighet|ögonskenlighet|" complemgram="|upp..ab.1+visa..vb.1:2.183e-08|" compwf="|upp+visar|" dephead="4" deprel="UA" lemma="|uppvisa|" lex="|uppvisa..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="7" sense="|uppvisa..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Cause_to_perceive|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">uppvisar</token>
#             <token blingbring="|betydenhet|dyrhet|glupskhet|missbelåtenhet|omåttlighet|saknad av samhörighet|övermått|överskridande|" complemgram="|" compwf="|" dephead="7" deprel="OO" lemma="|omåttlighet|" lex="|omåttlighet..nn.1|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="8" sense="|omåttlighet..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">omåttlighet</token>
#             <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="9" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2946580" lastpost="2020-03-21 10:32" postcount="9" title="Köpa skoal,copenhagen och grizzly osv?" url="https://www.flashback.org/t2946580">
#       <text _id="362443d" blingbring="|ofruktbarhet:35.486|fattigdom:31.057|försäljning:30.739|" date="2018-06-04 08:23" datefrom="20180604" dateto="20180604" id="64236108" lix="37.42" nk="0.27" ovix="120.78" swefn="|Wealthiness:153.677|Commerce_sell:68.659|Residence:54.393|" timefrom="082300" timeto="082359" url="https://www.flashback.org/p64236108#p64236108" userid="1093519" username="2560p">
#         <paragraph _geocontext="|Göteborg;SE;57.70716;11.96679|">
#           <sentence _geocontext="|" id="362861ab">
#             <token _tail="\s" blingbring="|" complemgram="|hem..ab.1+sida..nn.1:4.200e-11|" compwf="|hem+sidan|" dephead="2" deprel="SS" lemma="|hemsida|" lex="|hemsida..nn.1|" msd="NN.UTR.SIN.DEF.NOM" msd_annotator="stanza" pos="NN" ref="1" sense="|hemsida..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">Hemsidan</token>
#             <token _tail="\s" blingbring="|förtid|långvarighet|varaktighet|" complemgram="|" compwf="|" dephead="6" deprel="MS" lemma="|vara|" lex="|vara..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="2" sense="|vara..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Existence|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">är</token>
#             <token _tail="\s" blingbring="|jämförelse|obetydlighet|" complemgram="|" compwf="|" dephead="4" deprel="AA" lemma="|lite|" lex="|lite..ab.1|" msd="AB.POS" msd_annotator="stanza" pos="AB" ref="3" sense="|lite..1:-1.000|" swefn="|Degree|" ufeats="|Degree=Pos|">lite</token>
#             <token blingbring="|fattigdom|förlust|försämring|nedtryckning|obetydlighet|ofruktbarhet|ofullkomlighet|otillräcklighet|oviktighet|plebej|" complemgram="|" compwf="|" dephead="2" deprel="SP" lemma="|fattig|" lex="|fattig..av.1|" msd="JJ.POS.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="JJ" ref="4" sense="|fattig..1:0.713|fattig..2:0.287|" sentiment_label="negative" sentiment_score="-1" swefn="|Wealthiness|" ufeats="|Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing|">fattig</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IK" lemma="|" lex="|" msd="MID" msd_annotator="stanza" pos="MID" ref="5" sense="|" swefn="|" ufeats="|">,</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" deprel="ROOT" lemma="|men|" lex="|men..kn.1|" msd="KN" msd_annotator="stanza" pos="KN" ref="6" sense="|men..1:-1.000|" swefn="|" ufeats="|">men</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="8" deprel="SS" lemma="|du|" lex="|du..pn.1|" msd="PN.UTR.SIN.DEF.SUB" msd_annotator="stanza" pos="PN" ref="7" sense="|du..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">du</token>
#             <token _tail="\s" blingbring="|förmåga|kunnighet|skicklighet|styrka|" complemgram="|" compwf="|" dephead="6" deprel="MS" lemma="|kunna|" lex="|kunna..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="8" sense="|kunna..1:0.343|kunna..2:0.270|kunna..3:0.264|kunna..4:0.123|" sentiment_label="neutral" sentiment_score="0" swefn="|Capability|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">kan</token>
#             <token _tail="\s" blingbring="|bekräftelse|" complemgram="|" compwf="|" dephead="8" deprel="MA" lemma="|ju|" lex="|ju..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="9" sense="|ju..1:-1.000|" swefn="|" ufeats="|">ju</token>
#             <token _tail="\s" blingbring="|anfall|begäran|framgång|infall|jordbruk|klang|krigföring|kval|ljudstöt|ont|skakning|smicker|upprördhet|våldsamhet|ömhetsbetygelse|" complemgram="|" compwf="|" dephead="8" deprel="VG" lemma="|slå|slå en signal|" lex="|slå..vb.1|slå_en_signal..vbm.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="10" sense="|slå..1:0.696|slå..3:0.109|slå..8:0.079|slå..2:0.041|slå..5:0.032|slå..4:0.026|slå..9:0.018|slå_en_signal..1:-1.000|" sentiment_label="negative" sentiment_score="-1" swefn="|Impact|" ufeats="|VerbForm=Inf|Voice=Act|">slå</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="10" deprel="IO" lemma="|de|" lex="|de..pn.1|" msd="PN.UTR+NEU.PLU.DEF.SUB+OBJ" msd_annotator="stanza" pos="PN" ref="11" sense="|de..1:-1.000|" swefn="|" ufeats="|Case=Acc,Nom|Definite=Def|Gender=Com,Neut|Number=Plur|">dom</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="13" deprel="DT" lemma="|en|slå en signal:10|" lex="|en..al.1|slå_en_signal..vbm.1:10|" msd="DT.UTR.SIN.IND" msd_annotator="stanza" pos="DT" ref="12" sense="|den..1:-1.000|en..2:-1.000|slå_en_signal..1:10:-1.000|" swefn="|" ufeats="|Definite=Ind|Gender=Com|Number=Sing|">en</token>
#             <token _tail="\s" blingbring="|befallning|beteckning|krigföring|meddelande|tidsförhållande|varning|" complemgram="|" compwf="|" dephead="10" deprel="OO" lemma="|signal|slå en signal:10|" lex="|signal..nn.1|slå_en_signal..vbm.1:10|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="13" sense="|signal..1:-1.000|slå_en_signal..1:10:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">signal</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="6" deprel="++" lemma="|och|" lex="|och..kn.1|" msd="KN" msd_annotator="stanza" pos="KN" ref="14" sense="|och..1:-1.000|" swefn="|" ufeats="|">och</token>
#             <token _tail="\s" blingbring="|framtid|synsinne|" complemgram="|" compwf="|" dephead="14" deprel="+F" lemma="|se|se om|" lex="|se..vb.1|se_om..vbm.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="15" sense="|ses..1:0.247|se..4:0.204|se..2:0.200|se..5:0.158|se..1:0.129|se..3:0.056|se..6:0.006|se_om..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|VerbForm=Inf|Voice=Act|">se</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="15" deprel="OO" lemma="|om|se om:15|" lex="|om..sn.1|se_om..vbm.1:15|" msd="SN" msd_annotator="stanza" pos="SN" ref="16" sense="|om..2:-1.000|om..3:-1.000|se_om..1:15:-1.000|" swefn="|" ufeats="|">om</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="19" deprel="SS" lemma="|de|" lex="|de..pn.1|" msd="PN.UTR+NEU.PLU.DEF.SUB" msd_annotator="stanza" pos="PN" ref="17" sense="|de..1:-1.000|" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com,Neut|Number=Plur|">de</token>
#             <token _tail="\s" blingbring="|fortsättning|nutid|" complemgram="|" compwf="|" dephead="19" deprel="TA" lemma="|fortfarande|" lex="|fortfarande..ab.1|" msd="AB" msd_annotator="stanza" pos="AB" ref="18" sense="|fortfarande..1:-1.000|" swefn="|Continued_state_of_affairs|" ufeats="|">fortfarande</token>
#             <token blingbring="|avtal|försäljning|handel|pris|utbyte|" complemgram="|" compwf="|" dephead="16" deprel="UA" lemma="|sälja|" lex="|sälja..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="19" sense="|sälja..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Commerce_sell|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">säljer</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="16" deprel="IQ" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="20" sense="|" swefn="|" ufeats="|">:</token>
#             <ne ex="NUMEX" name="http://www.pipcenter.se/" subtype="WEB" type="MSR">
#               <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="19" deprel="AA" lemma="|" lex="|" msd="AB.AN" msd_annotator="stanza" pos="AB" ref="21" sense="|" swefn="|" ufeats="|Abbr=Yes|">http://www.pipcenter.se/</token>
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3490934" lastpost="2022-12-10 17:07" postcount="410" title="EU föreslår skattechock för snus  priset kan dubblas" url="https://www.flashback.org/t3490934">
#       <text _id="36273e5" blingbring="|brunt:195.855|äretecken:91.064|rov:77.983|" date="2022-11-27 11:51" datefrom="20221127" dateto="20221127" id="82554869" lix="32.50" nk="2.00" ovix="82.65" swefn="|Amassing:22838.882|Cause_change_of_position_on_a_scale_increase:249.473|Intoxicants:129.391|" timefrom="115100" timeto="115159" url="https://www.flashback.org/p82554869#p82554869" userid="1160632" username="thunderbow">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362f5ff1">
#             <ne ex="ENAMEX" name="Leif GW" subtype="HUM" type="PRS">
#               <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="SS" lemma="|Leif|" lex="|Leif..pm.1|" msd="PM.NOM" msd_annotator="stanza" pos="PM" ref="1" sense="|Leif..1:-1.000|" swefn="|" ufeats="|Case=Nom|">Leif</token>
#               <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="1" deprel="HD" lemma="|" lex="|" msd="PM.NOM" msd_annotator="stanza" pos="PM" ref="2" sense="|" swefn="|" ufeats="|Case=Nom|">GW</token>
#             </ne>
#             <token _tail="\s" blingbring="|beredelse|bestämmelse|bundenhet|förfarande|handledning|ledning|ofrivillighet|plikt|skicklighet|undervisningsanstalt|" complemgram="|" compwf="|" deprel="ROOT" lemma="|skola|" lex="|skola..vb.2|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="3" sense="|skola..4:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Desirable_event|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">ska</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="VG" lemma="|hamstra|" lex="|hamstra..vb.1|" msd="VB.INF.AKT" msd_annotator="stanza" pos="VB" ref="4" sense="|hamstra..1:-1.000|" swefn="|Amassing|" ufeats="|VerbForm=Inf|Voice=Act|">hamstra</token>
#             <token _tail="\s" blingbring="|brunt|njutning|ogillande|smakstyrka|varning|" complemgram="|" compwf="|" dephead="4" deprel="OO" lemma="|snus|" lex="|snus..nn.1|" msd="NN.NEU.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="5" sense="|snus..1:-1.000|" swefn="|Intoxicants|" ufeats="|Case=Nom|Definite=Ind|Gender=Neut|Number=Sing|">snus</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="4" deprel="AA" lemma="|inför|" lex="|inför..pp.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="6" sense="|inför..1:-1.000|" swefn="|" ufeats="|">inför</token>
#             <token _tail="\s" blingbring="|betingelse|framtid|möjlighet|omständighet|ovisshet|slump|tidsförhållande|" complemgram="|" compwf="|" dephead="8" deprel="AT" lemma="|eventuell|" lex="|eventuell..av.1|" msd="JJ.POS.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="JJ" ref="7" sense="|eventuell..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Likelihood|" ufeats="|Case=Nom|Definite=Ind|Degree=Pos|Gender=Com|Number=Sing|">eventuell</token>
#             <token blingbring="|" complemgram="|pris..nn.1+höjning..nn.1:2.709e-10|pris..nn.2+höjning..nn.1:2.709e-10|pris..nn.3+höjning..nn.1:2.709e-10|pris..nn.4+höjning..nn.1:2.709e-10|prisa..vb.1+höjning..nn.1:1.400e-20|" compwf="|pris+höjning|" dephead="6" deprel="PA" lemma="|prishöjning|" lex="|prishöjning..nn.1|" msd="NN.UTR.SIN.IND.NOM" msd_annotator="stanza" pos="NN" ref="8" sense="|prishöjning..1:-1.000|" swefn="|Cause_change_of_position_on_a_scale_increase|" ufeats="|Case=Nom|Definite=Ind|Gender=Com|Number=Sing|">prishöjning</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="3" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="9" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1481328" lastpost="2011-06-13 17:38" postcount="33" title="Hur har snus påverkat era liv?" url="https://www.flashback.org/t1481328">
#       <text _id="3623505" blingbring="|sparsamhet:87.66|overklighet:61.084|lycka:49.677|" date="2011-03-13 19:46" datefrom="20110313" dateto="20110313" id="29451116" lix="45.33" nk="0.67" ovix="inf" swefn="|Economy:265.559|Quantified_mass:104.019|Degree:19.648|" timefrom="194600" timeto="194659" url="https://www.flashback.org/p29451116#p29451116" userid="430624" username="Markmag">
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3628c4aa">
#             <token _tail="\s" blingbring="|begriplighet|bekräftelse|stränghet|talförhållande|tillvaro|överensstämmelse|övertygelse|" complemgram="|" compwf="|" dephead="2" deprel="MS" lemma="|positiv|" lex="|positiv..av.1|" msd="JJ.POS.NEU.SIN.IND.NOM" msd_annotator="stanza" pos="JJ" ref="1" sense="|positiv..8:0.890|positiv..1:0.062|positiv..7:0.022|positiv..6:0.017|positiv..2:0.008|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Case=Nom|Definite=Ind|Degree=Pos|Gender=Neut|Number=Sing|">Positivt</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" deprel="ROOT" lemma="|för|" lex="|för..kn.1|" msd="KN" msd_annotator="stanza" pos="KN" ref="2" sense="|för..2:-1.000|" swefn="|" ufeats="|">för</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="4" deprel="SS" lemma="|den|" lex="|den..pn.1|" msd="PN.NEU.SIN.DEF.SUB+OBJ" msd_annotator="stanza" pos="PN" ref="3" sense="|den..2:-1.000|" swefn="|" ufeats="|Case=Acc,Nom|Definite=Def|Gender=Neut|Number=Sing|">det</token>
#             <token _tail="\s" blingbring="|förtid|långvarighet|varaktighet|" complemgram="|" compwf="|" dephead="2" deprel="MS" lemma="|vara|" lex="|vara..vb.1|" msd="VB.PRS.AKT" msd_annotator="stanza" pos="VB" ref="4" sense="|vara..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Existence|" ufeats="|Mood=Ind|Tense=Pres|VerbForm=Fin|Voice=Act|">är</token>
#             <token blingbring="|betydenhet|lycka|" complemgram="|" compwf="|" dephead="7" deprel="CJ" lemma="|god|gott|" lex="|god..av.1|gott..av.1|" msd="JJ.POS.NEU.SIN.IND.NOM" msd_annotator="stanza" pos="JJ" ref="5" sense="|gott..1:0.524|god..1:0.424|god..3:0.038|god..2:0.014|" sentiment_label="neutral" sentiment_score="0" swefn="|Quantified_mass|" ufeats="|Case=Nom|Definite=Ind|Degree=Pos|Gender=Neut|Number=Sing|">gott</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="7" deprel="IK" lemma="|" lex="|" msd="MID" msd_annotator="stanza" pos="MID" ref="6" sense="|" swefn="|" ufeats="|">,</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="4" deprel="SP" lemma="|men|" lex="|men..kn.1|" msd="KN" msd_annotator="stanza" pos="KN" ref="7" sense="|men..1:-1.000|" swefn="|" ufeats="|">men</token>
#             <token _tail="\s" blingbring="|betydenhet|förmåga|mängd|storhet|styrka|" complemgram="|" compwf="|" dephead="9" deprel="AA" lemma="|väldig|" lex="|väldig..av.1|" msd="AB.POS" msd_annotator="stanza" pos="AB" ref="8" sense="|väldig..1:-1.000|" sentiment_label="neutral" sentiment_score="0" swefn="|Degree|" ufeats="|Degree=Pos|">väldigt</token>
#             <token _tail="\s" blingbring="|förnekelse|intighet|motsats|obetydlighet|overklighet|talförhållande|" complemgram="|" compwf="|" dephead="7" deprel="+F" lemma="|negativ|" lex="|negativ..av.1|" msd="JJ.POS.NEU.SIN.IND.NOM" msd_annotator="stanza" pos="JJ" ref="9" sense="|negativ..5:0.955|negativ..1:0.038|negativ..2:0.004|negativ..4:0.003|" sentiment_label="negative" sentiment_score="-1" swefn="|" ufeats="|Case=Nom|Definite=Ind|Degree=Pos|Gender=Neut|Number=Sing|">negativt</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="4" deprel="RA" lemma="|på|" lex="|på..pp.1|" msd="PP" msd_annotator="stanza" pos="PP" ref="10" sense="|på..1:-1.000|" swefn="|" ufeats="|">på</token>
#             <token _tail="\s" blingbring="|" complemgram="|" compwf="|" dephead="13" deprel="DT" lemma="|den|en|" lex="|den..pn.1|en..al.1|" msd="DT.UTR.SIN.DEF" msd_annotator="stanza" pos="DT" ref="11" sense="|den..1:-1.000|den..2:-1.000|en..2:-1.000|" swefn="|" ufeats="|Definite=Def|Gender=Com|Number=Sing|">den</token>
#             <token _tail="\s" blingbring="|anskaffning|förfarande|ledning|skicklighet|sparsamhet|" complemgram="|" compwf="|" dephead="13" deprel="AT" lemma="|ekonomisk|" lex="|ekonomisk..av.1|ekonomisk..av.2|" msd="JJ.POS.UTR+NEU.SIN.DEF.NOM" msd_annotator="stanza" pos="JJ" ref="12" sense="|ekonomisk..1:0.647|ekonomisk..2:0.185|ekonomisk..3:0.168|" sentiment_label="neutral" sentiment_score="0" swefn="|Economy|" ufeats="|Case=Nom|Definite=Def|Degree=Pos|Gender=Com,Neut|Number=Sing|">ekonomiska</token>
#             <token blingbring="|bok|sidoläge|tryckning|uppvaknande|" complemgram="|" compwf="|" dephead="10" deprel="PA" lemma="|sida|" lex="|sida..nn.1|" msd="NN.UTR.SIN.DEF.NOM" msd_annotator="stanza" pos="NN" ref="13" sense="|sida..4:0.726|sida..1:0.115|sida..3:0.102|sida..2:0.058|" sentiment_label="neutral" sentiment_score="0" swefn="|" ufeats="|Case=Nom|Definite=Def|Gender=Com|Number=Sing|">sidan</token>
#             <token _tail="\n" blingbring="|" complemgram="|" compwf="|" dephead="2" deprel="IP" lemma="|" lex="|" msd="MAD" msd_annotator="stanza" pos="MAD" ref="14" sense="|" swefn="|" ufeats="|">.</token>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2145656" lastpost="2013-05-19 17:20" postcount="7" title="Risk för lungcancer ?" url="https://www.flashback.org/t2145656">
#       <text _id="362b04a" blingbring="|fördunstning:456.77|otro:209.518|irrlära:183.345|" date="2013-05-18 19:47" datefrom="20130518" dateto="20130518" id="43490032" lix="85.33" nk="0.53" ovix="59.61" swefn="|Ingest_substance:584.856|Intoxicants:134.367|Certainty:29.114|" timefrom="194700" timeto="194759" url="https://www.flashback.org/p43490032#p43490032" userid="429467" username="MaryJaneInMeBrain">
#         <paragraph _geocontext="|">

# %% [markdown]
# **Structure:**

# %% [markdown]
# ```
# corpus
#     thread
#         text #date
#             paragraph
#                 sentence
#                     token
# ```

# %% [markdown]
# #### Structure 2

# %%
threshold = 1000
with open(file_path, "r") as f:
    for i, line in enumerate(f):
        if i < threshold:
            if "<token" not in line:
                if "<text" in line:
                    print(re.sub("<text.*?>", "<text>", line.strip("\n")))
                else:
                    print(line.strip("\n"))
        else:
            break
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <!--
# Sparv version: 5.1.1dev0
# Annotation date: '2023-01-18'
# -->
# <corpus id="flashback-mat">
#   <forum id="109" title="Mat, dryck &amp; tobak &gt; Tobak" url="https://www.flashback.org/f109">
#     <thread id="1940381" lastpost="2012-08-21 17:28" postcount="132" title="28 år gammal nekad att köpa tobak trots leg." url="https://www.flashback.org/t1940381">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3623b529">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="198812" lastpost="2005-04-16 15:28" postcount="48" title="Vackra, rökande människor?" url="https://www.flashback.org/t198812">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362b12fd">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="655616" lastpost="2010-06-11 08:21" postcount="80" title="Snus - förbjudet i finland" url="https://www.flashback.org/t655616">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362639c9">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1844691" lastpost="2012-04-15 23:19" postcount="14" title="Köpt en stock Knox, väldigt torrt?" url="https://www.flashback.org/t1844691">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362b58b3">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3490934" lastpost="2022-12-10 17:07" postcount="410" title="EU föreslår skattechock för snus  priset kan dubblas" url="https://www.flashback.org/t3490934">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362bebb6">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3495409" lastpost="2022-12-30 22:35" postcount="307" title="Snusare dör i förtid !!" url="https://www.flashback.org/t3495409">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362591c1">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2946580" lastpost="2020-03-21 10:32" postcount="9" title="Köpa skoal,copenhagen och grizzly osv?" url="https://www.flashback.org/t2946580">
#       <text>
#         <paragraph _geocontext="|Göteborg;SE;57.70716;11.96679|">
#           <sentence _geocontext="|" id="362861ab">
#             <ne ex="NUMEX" name="http://www.pipcenter.se/" subtype="WEB" type="MSR">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3490934" lastpost="2022-12-10 17:07" postcount="410" title="EU föreslår skattechock för snus  priset kan dubblas" url="https://www.flashback.org/t3490934">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362f5ff1">
#             <ne ex="ENAMEX" name="Leif GW" subtype="HUM" type="PRS">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1481328" lastpost="2011-06-13 17:38" postcount="33" title="Hur har snus påverkat era liv?" url="https://www.flashback.org/t1481328">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3628c4aa">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2145656" lastpost="2013-05-19 17:20" postcount="7" title="Risk för lungcancer ?" url="https://www.flashback.org/t2145656">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3620e8c6">
#             <ne ex="TIMEX" name="om dagen" subtype="DAT" type="TME">
#             </ne>
#             <ne ex="TIMEX" name="i 9 månader" subtype="DAT" type="TME">
#             </ne>
#             <ne ex="NUMEX" name="dagligen" subtype="FRQ" type="MSR">
#             </ne>
#             <ne ex="TIMEX" name="om dagen" subtype="DAT" type="TME">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1734201" lastpost="2016-11-06 23:25" postcount="55" title="Hade tråkigt, köpte snus. Vad är gott med det?" url="https://www.flashback.org/t1734201">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362addac">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="208663" lastpost="2005-06-03 13:23" postcount="93" title="Rökare sparkas i USA" url="https://www.flashback.org/t208663">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362ae507">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3495409" lastpost="2022-12-30 22:35" postcount="307" title="Snusare dör i förtid !!" url="https://www.flashback.org/t3495409">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362e4ebc">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="514055" lastpost="2007-07-19 00:06" postcount="19" title="Panik.." url="https://www.flashback.org/t514055">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36264ea0">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1734201" lastpost="2016-11-06 23:25" postcount="55" title="Hade tråkigt, köpte snus. Vad är gott med det?" url="https://www.flashback.org/t1734201">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36222bde">
#             <ne ex="TIMEX" name="de första veckorna" subtype="DAT" type="TME">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3495409" lastpost="2022-12-30 22:35" postcount="307" title="Snusare dör i förtid !!" url="https://www.flashback.org/t3495409">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3626d342">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1550695" lastpost="2012-08-02 19:54" postcount="126" title="Brukar ni dricka något när ni snusar?" url="https://www.flashback.org/t1550695">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36271840">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="347967" lastpost="2006-07-20 15:50" postcount="11" title="Var köpa rullmaskin?" url="https://www.flashback.org/t347967">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362fdefd">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="655616" lastpost="2010-06-11 08:21" postcount="80" title="Snus - förbjudet i finland" url="https://www.flashback.org/t655616">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362d025e">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2329680" lastpost="2014-03-03 20:10" postcount="7" title="nikotinfri E cigg" url="https://www.flashback.org/t2329680">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3628178c">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1940381" lastpost="2012-08-21 17:28" postcount="132" title="28 år gammal nekad att köpa tobak trots leg." url="https://www.flashback.org/t1940381">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3629c346">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="135206" lastpost="2004-07-21 10:14" postcount="38" title="Rökförbud" url="https://www.flashback.org/t135206">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36224109">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2943069" lastpost="2018-05-20 22:03" postcount="4" title="Lagligt att sälja cigaretter på Blocket/Citiboard och Tradera??" url="https://www.flashback.org/t2943069">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36289aba">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="135752" lastpost="2011-09-18 01:48" postcount="135" title="Snuspriser" url="https://www.flashback.org/t135752">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3624a38c">
#             <ne ex="ENAMEX" name="Sthlm" subtype="GPL" type="LOC">
#             </ne>
#             <ne ex="NUMEX" name="25 kr" subtype="CUR" type="MSR">
#             </ne>
#             <ne ex="NUMEX" name="23 kr" subtype="CUR" type="MSR">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="3495409" lastpost="2022-12-30 22:35" postcount="307" title="Snusare dör i förtid !!" url="https://www.flashback.org/t3495409">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36212913">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2549081" lastpost="2015-04-03 21:09" postcount="12" title="börja med tobak, men vad?" url="https://www.flashback.org/t2549081">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36272f14">
#             <ne ex="TIMEX" name="Nu" subtype="DAT" type="TME">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1732181" lastpost="2011-12-08 19:12" postcount="6" title="Elcigg från DealExtreme" url="https://www.flashback.org/t1732181">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3620358a">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="655616" lastpost="2010-06-11 08:21" postcount="80" title="Snus - förbjudet i finland" url="https://www.flashback.org/t655616">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362bc74b">
#             <ne ex="ENAMEX" name="sverige" subtype="PPL" type="LOC">
#             </ne>
#             <ne ex="ENAMEX" name="sverige" subtype="PPL" type="LOC">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="135752" lastpost="2011-09-18 01:48" postcount="135" title="Snuspriser" url="https://www.flashback.org/t135752">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362f1369">
#             <ne ex="ENAMEX" name="Gustavus" subtype="HUM" type="PRS">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="561650" lastpost="2018-11-17 20:59" postcount="42" title="Billiga cigaretter i Malmö" url="https://www.flashback.org/t561650">
#       <text>
#         <paragraph _geocontext="|Malmö;SE;55.60587;13.00073|">
#           <sentence _geocontext="|Malmö;SE;55.60587;13.00073|" id="362e701c">
#             <ne ex="ENAMEX" name="Malmö" subtype="PPL" type="LOC">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="598196" lastpost="2008-12-19 23:34" postcount="27" title="För gammal snus!" url="https://www.flashback.org/t598196">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3624ac15">
#             <ne ex="TIMEX" name="Sedan dess" subtype="DAT" type="TME">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1531264" lastpost="2011-05-09 17:52" postcount="24" title="Att röka på lekplatser" url="https://www.flashback.org/t1531264">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3626206a">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1061627" lastpost="2009-11-26 01:11" postcount="10" title="Nya GR - hemsk?" url="https://www.flashback.org/t1061627">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362e5998">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1947108" lastpost="2012-08-26 11:23" postcount="17" title="Snus till Finland" url="https://www.flashback.org/t1947108">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36234d20">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="135206" lastpost="2004-07-21 10:14" postcount="38" title="Rökförbud" url="https://www.flashback.org/t135206">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36294672">
#             <ne ex="TIMEX" name="2004-07-20" subtype="DAT" type="TME">
#             </ne>
#             <ne ex="NUMEX" name="http://www.gp.se/gp/jsp/Crosslink.jsp?d=113&amp;a=173789" subtype="WEB" type="MSR">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="617353" lastpost="2013-04-14 03:01" postcount="14" title="Falska marlboro" url="https://www.flashback.org/t617353">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36276716">
#             <ne ex="TIMEX" name="under denna vecka" subtype="DAT" type="TME">
#             </ne>
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1370018" lastpost="2010-11-26 23:35" postcount="10" title="Nytt utseende på röda lacket?" url="https://www.flashback.org/t1370018">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3621740f">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="655616" lastpost="2010-06-11 08:21" postcount="80" title="Snus - förbjudet i finland" url="https://www.flashback.org/t655616">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3626cdab">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1550695" lastpost="2012-08-02 19:54" postcount="126" title="Brukar ni dricka något när ni snusar?" url="https://www.flashback.org/t1550695">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362d7a90">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="1163442" lastpost="2010-04-15 22:55" postcount="31" title="Morsan rökt i 10 år i smyg" url="https://www.flashback.org/t1163442">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="3622cec7">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="135752" lastpost="2011-09-18 01:48" postcount="135" title="Snuspriser" url="https://www.flashback.org/t135752">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36260101">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2714558" lastpost="2016-05-17 21:00" postcount="87" title="Är detta slutet för vår kära snus?" url="https://www.flashback.org/t2714558">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="362e2b85">
#           </sentence>
#         </paragraph>
#       </text>
#     </thread>
#     <thread id="2274367" lastpost="2019-11-11 21:48" postcount="84" title="E-Juice tråden - din favorit juice" url="https://www.flashback.org/t2274367">
#       <text>
#         <paragraph _geocontext="|">
#           <sentence _geocontext="|" id="36255fb5">
#             <ne ex="NUMEX" name="12 mg" subtype="WMU" type="MSR">

# %% [markdown]
# #### Simple sentence per paragraph counter

# %%
t0 = time.time()
interval = 100000
n_sent = 0
spp_counter = {}
n = 0

threshold = None
with open(file_path, "r") as f:
    for i, line in enumerate(f):
        
        if threshold != None:
            if i > threshold:
                break
                
        if i % interval == 0:
            
            t_delta = time.time() - t0
            m = int(t_delta / 60)
            s = t_delta % 60            
            print(f"Process: {i} lines, {m} m., {s:.0f} s.", end= "\r")

        if "<sentence" in line:
            n+=1
            n_sent+=1
        
        if "</paragraph>" in line:
            if n > 1:
                if n in spp_counter:
                    spp_counter[n] += 1
                else: 
                    spp_counter[n] = 1
            n = 0
            continue

print()
print("Sent per paragraph counter:", spp_counter)
print("No. of sentences:", n_sent)
# Out:
# Process: 119000000 lines, 4 m., 25 s.
# Sent per paragraph counter: {2: 599}
# No. of sentences: 5351136

# %% [markdown]
# Of 5 351 136 sentences, there are 599 cases where a paragraph contains two sentences. No paragraph contains more than two sentences.

# %% [markdown]
# #### File runnner

# %% [raw]
# def file_runner(file_path):
#     t0 = time.time()
#
#     tracemalloc.start()
#     memory0 = (0, 0)
#     with open(file_path, "r") as xml:
#
#         for i, line in enumerate(xml):
#
#             if i % 1000000 == 0:
#                 t = time.time() - t0
#                 m = int(t / 60)
#                 s = t % 60
#                 memory1 = tracemalloc.get_traced_memory()
#                 memory  = round(memory1[0]/1000, 1)
#                 memory_delta = round((memory1[0]-memory0[0])/1000, 1)
#                 memory0 = memory1
#                 print(f"{i} lines processed so far. {m} minutes and {s:.1f} seconds have passed. Memory={memory} KB (+{memory_delta} KB)", end = "\r")
#     print()
#     print("Lines, total:", i)
#     print("Done!")
#     tracemalloc.stop()

# %% [raw]
# file_runner(file_path)

# %%
# 119 000 000 lines passed in 4 minutes and 19 seconds.

# %% [markdown]
# #### Year finder

# %% [raw]
# def year_finder(xml_file_path):
#     t0 = time.time()
#
#     tracemalloc.start()
#     memory0 = (0, 0)
#
#     xml_parser = ET.XMLPullParser(['start'])
#     years = set()
#
#     with open(file_path, "r") as xml:
#
#         for i, line in enumerate(xml):
#
#             if i % 1000000 == 0:
#                 del xml_parser
#
#                 t = time.time() - t0
#                 m = int(t / 60)
#                 s = t % 60
#                 memory1 = tracemalloc.get_traced_memory()
#                 memory  = round(memory1[0]/1000000, 1)
#                 memory_delta = round((memory1[0]-memory0[0])/1000000, 1)
#                 memory0 = memory1
#
#                 xml_parser = ET.XMLPullParser(['start'])
#
#                 print(f"{i} lines processed so far. {m} minutes and {s:.1f} seconds have passed. Memory={memory} MB (+{memory_delta} MB)", end = "\r")
#
#             if re.search("<text.*?>", line) != None:
#
#                 xml_parser.feed(line)
#                 #xml_parser.read_events()
#                 #date = [tag for _, tag in xml_parser.read_events()][0].attrib["date"]
#                 for _, tag in xml_parser.read_events():
#                     date = tag.attrib["date"]
#                     tag.clear()
#
#                 year = date.split()[0].split("-")[0] # "2012-08-17 10:22"
#                 years.add(year)
#
#
#
#     print()
#     print("Lines, total:", i)
#
#     tracemalloc.stop()
#
#     return sorted(list(years))

# %% [raw]
# year_finder(file_path)

# %%
# from 2000 to 2022

# %% [markdown]
# #### "Real" code

# %%
stopwords_path = Path("utils/stopwords-sv.txt")
with open(stopwords_path, mode = "r") as f:
    stopwords = [stopword.strip("\n") for stopword in f.readlines()]

# %%
def inititialize(directory, start_year, stop_year, suffix):
    """
    Creates a set of files to populate with examples.
    WARNING: replaces existing files with empty ones.
    """
    
    directory = Path(directory)
    
    for year in range(start_year, stop_year + 1):
        filename = f"{year}.txt" if suffix == "" else f"{year}_suffix.txt"
        f = open(directory / filename, mode = "w")
        f.close()

# %%
def save_sentences(batch, directory, suffix):
    """
    Saves an example to the .txt file of its year.
    Assumes initiation by `inititialize()`.
    """
    
    directory = Path(directory)
    
    for year, example_str in batch:
        filename  = f"{year}.txt" if suffix == "" else f"{year}_{suffix}.txt"

        with open(directory/filename, mode="a") as f:
            f.write(example_str + "\n")

# %%
def clean_up(directory):
    """
    Removes empty files.
    """
    
    for file in listdir(directory):
        if getsize(directory / file) == 0:
            remove(directory / file)

# %%
def preprocess(example,
               remove_stopwords = False,
               stopwords = None,
               remove_numbers = True,
               remove_urls = True,
               remove_punctuations = True,
               min_tok_utterances = None,
               lower = True):
    """ 
    Preprocess a list of words and returns a string.
    """
    
    if remove_stopwords:
        assert isinstance(stopwords, list) or isinstance(stopwords, set), "You have selected to use stopwords, but no stopword list is provided."

        example = [word for word in example if word not in stopwords]
        
    if remove_punctuations:
        example = [token for token in example if not token in punctuation]
        
    if min_tok_utterances != None:
        if len(example) <= min_tok_utterances:
            return []
        
    example = " ".join(example)
    
    if lower:
        example = example.lower()
    
    if remove_numbers:
        example = re.sub(r"[0-9]+", "", example)
    
    if remove_urls:
        example = re.sub(r"https?://.*", "", example)
        example = re.sub(r"www\..*", "", example)

    return example

# %%
def build_temporal_corpus(xml_file_path, 
                          directory_out, 
                          stop = 400,
                          interval = 100000,
                          start_year = 2000, 
                          end_year = 2022,
                          buffer_limit = 500, 
                          suffix = ""):
    """
    Builds temporal corpus from xml-file; one file per year.
    """
    
    t0 = time.time()
    tracemalloc.start()
    memory0 = (0,0)

    xml_parser = ET.XMLPullParser(['start'])    
    
    directory_out = Path(directory_out)

    collector = []

    counter = {str(year): {"examples": 0, "word_tokens": 0} for year in range(start_year, end_year + 1)}
    
    inititialize(directory_out, start_year, end_year, suffix)

    with open(xml_file_path, "r") as xml:
        
        for i, line in enumerate(xml):
            
            if i % interval == 0:
                
                t = time.time() - t0
                m = int(t / 60)
                s = t % 60
                
                norm, unit = (1000000, "MB")
                memory1 = tracemalloc.get_traced_memory()
                memory  = round(memory1[0]/norm, 1)
                memory_delta = round((memory1[0]-memory0[0])/norm, 1)
                memory0 = memory1                
                
                print(f"{i} lines; in {m} m, {s:.1f} s; memory={memory} {unit} (+{memory_delta} {unit}) ", end = "\r")
                
                # this manouver is to avoid memory explosion
                del xml_parser
                xml_parser = ET.XMLPullParser(['start'])                

            if stop != None:
                if i > stop:
                    break
            
            if re.search("<text.*?>", line) != None:
                xml_parser.feed(line)
                date = [tag for _, tag in xml_parser.read_events()][0].attrib["date"]
                year = date.split()[0].split("-")[0] # "2012-08-17 10:22"
                continue
            
#             if restricted_to_year != None:
#                 if year != restricted_to_year:
#                     continue
            
            if re.search("<sentence.*?>", line) != None:
                raw = list()
                #lem = list() # some inspection suggests that lemmas does not work that well; some very strange cases
                #pos = list()
                continue

            if re.search("<token.*?>", line) != None:
                #print(line)
                xml_parser.feed("<root>"+line) # fake root to avoid ParseError
                tag = [tag for _, tag in xml_parser.read_events()][-1]
                #print(tag.text)
                raw.append(tag.text)
                #lem.append(re.sub(r"\|", "", tag.attrib["lemma"]))
                #pos.append(tag.attrib["pos"])
                continue

            if re.search("</sentence>", line) != None:
                #print(raw)
                example = preprocess(raw)    # consider other parameters: pos, lemmas
                if example == []:
                    continue
                counter[year]["examples"] += 1
                counter[year]["word_tokens"] += len(example.split())
                collector.append((year, example))

            if len(collector) == buffer_limit:      
                save_sentences(batch = collector, directory = directory_out, suffix = suffix)
                collector.clear()
            
            # Without collector there will be alot of opening and closenings :|    
            # Also, to use `with open()` for multiple files would require too many files open 

    if collector != []:
        save_sentences(batch = collector, directory = directory_out, suffix = suffix)
        
    
    counter = {year: counts for year, counts in counter.items() if sum(counts.values()) != 0}
    with open("counter.log", "w") as log:
        log.write(json.dumps(counter))
    
    clean_up(directory_out)
    
    print()
    print("Lines, total:", i)
    print("Done!")
    
    tracemalloc.stop()

# %%
build_temporal_corpus(xml_file_path = file_path, 
                      directory_out = "diamat1",
                      stop=None)

# %%
# -preprocessing -saving 6M lines: 01:51

# %% [markdown]
# ### Old code for `build_temporal_corpus`
# Old code implements `xml.etree.ElementTree.iterparse()`, but this seems not to be a proper iterator. The computer gets parlyzed by memory overload.

# %% [raw]
# def build_temporal_corpus(xml_file_path,
#                           directory_out,
#                           stop = 400,
#                           buffer_limit = 1000,
#                           start_year = 1990,
#                           end_year = 2023,
#                           suffix = ""):
#     """
#     Builds temporal corpus from xml-file; one file per year.
#     """
#
#     t0 = time.time()
#
#     directory_out = Path(directory_out)
#
#     collector = []
#
#     inititialize(directory_out, start_year, end_year, suffix)
#
#     counter = {str(year): {"examples": 0, "word_tokens": 0} for year in range(start_year, end_year + 1)}
#
#     #collect = False
#     for i, (event, tag) in enumerate(ET.iterparse(xml_file_path, events = ["start", "end"])):
#
#         if i % 10000 == 0:
#             t = time.time() - t0
#             m = int(t / 60)
#             s = t % 60
#             print(f"{i} events processed so far. {m} minutes and {s:.1f} seconds have passed.", end = "\r")
#
#
#         if stop != None:
#             if i > stop:
#                 break
#
#         if event == "start" and tag.tag == "text":
#             date = tag.attrib["date"]
#             year = date.split()[0].split("-")[0] # "2012-08-17 10:22"
#             continue
#
#         if event == "start" and tag.tag == "sentence":
#             raw = list()
#             #lem = list() # some inspection suggests that lemmas does not work that well; some very strange cases
#             #pos = list()
#             continue
#
#         if event == "end" and tag.tag == "token":
#             raw.append(tag.text)
#             #lem.append(re.sub(r"\|", "", tag.attrib["lemma"]))
#             #pos.append(tag.attrib["pos"])
#             continue
#
#         if event == "end" and tag.tag == "sentence":
#             example = preprocess(raw)    # consider other parameters: pos, lemmas
#             counter[year]["examples"] += 1
#             counter[year]["word_tokens"] += len(example.split())
#             collector.append((year, example))
#
#         if len(collector) == buffer_limit:
#             save_sentences(batch = collector, directory = directory_out, suffix = suffix)
#             collector.clear()
#
#         # Otherwise there will be alot of opening and closenings :|
#         # To use with open for multiple files would require too many files open
#
#     if collector != []:
#         save_sentences(batch = collector, directory = directory_out, suffix = suffix)
#
#     clean_up(directory_out)
#     counter = {year: counts for year, counts in counter.items() if sum(counts.values()) != 0}
#     with open("counter.log", "w") as log:
#         log.write(json.dumps(counter))
#
#     print()
#     print("Done!")
